# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.modules import StudentTOutput

from TsT import TsTEstimator

# %%
dataset = get_dataset("exchange_rate_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = TsTEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=3,
    dim=32,
    patch_size=(4, 4),
    patch_reverse_mapping_layer = "mlp",
    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda", max_epochs=100),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type     | Params
# -----------------------------------
# 0 | model | TsTModel | 24.6 K
# -----------------------------------
# 23.7 K    Trainable params
# 960       Non-trainable params
# 24.6 K    Total params
# 0.099     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -2.74648 (best -2.74648), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -2.99926 (best -2.99926), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -3.17833 (best -3.17833), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -3.30091 (best -3.30091), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -3.38766 (best -3.38766), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -3.42236 (best -3.42236), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -3.44865 (best -3.44865), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -3.46947 (best -3.46947), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -3.48941 (best -3.48941), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -3.50138 (best -3.50138), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -3.51260 (best -3.51260), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -3.53293 (best -3.53293), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -3.54070 (best -3.54070), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached -3.55383 (best -3.55383), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' was not in top 1
# Epoch 15, global step 1600: 'train_loss' reached -3.58206 (best -3.58206), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' was not in top 1
# Epoch 17, global step 1800: 'train_loss' was not in top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.59234 (best -3.59234), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' was not in top 1
# Epoch 20, global step 2100: 'train_loss' reached -3.60131 (best -3.60131), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' reached -3.60687 (best -3.60687), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' reached -3.60942 (best -3.60942), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=22-step=2300.ckpt' as top 1
# Epoch 23, global step 2400: 'train_loss' reached -3.62319 (best -3.62319), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.63252 (best -3.63252), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' was not in top 1
# Epoch 26, global step 2700: 'train_loss' was not in top 1
# Epoch 27, global step 2800: 'train_loss' reached -3.63309 (best -3.63309), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=27-step=2800.ckpt' as top 1
# Epoch 28, global step 2900: 'train_loss' reached -3.63783 (best -3.63783), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=28-step=2900.ckpt' as top 1
# Epoch 29, global step 3000: 'train_loss' reached -3.66085 (best -3.66085), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=29-step=3000.ckpt' as top 1
# Epoch 30, global step 3100: 'train_loss' was not in top 1
# Epoch 31, global step 3200: 'train_loss' was not in top 1
# Epoch 32, global step 3300: 'train_loss' was not in top 1
# Epoch 33, global step 3400: 'train_loss' was not in top 1
# Epoch 34, global step 3500: 'train_loss' was not in top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.66775 (best -3.66775), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' reached -3.66923 (best -3.66923), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=36-step=3700.ckpt' as top 1
# Epoch 37, global step 3800: 'train_loss' reached -3.67550 (best -3.67550), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=37-step=3800.ckpt' as top 1
# Epoch 38, global step 3900: 'train_loss' reached -3.68613 (best -3.68613), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=38-step=3900.ckpt' as top 1
# Epoch 39, global step 4000: 'train_loss' was not in top 1
# Epoch 40, global step 4100: 'train_loss' was not in top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' was not in top 1
# Epoch 43, global step 4400: 'train_loss' reached -3.69593 (best -3.69593), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=43-step=4400.ckpt' as top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' reached -3.70302 (best -3.70302), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=47-step=4800.ckpt' as top 1
# Epoch 48, global step 4900: 'train_loss' was not in top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' reached -3.70825 (best -3.70825), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=50-step=5100.ckpt' as top 1
# Epoch 51, global step 5200: 'train_loss' was not in top 1
# Epoch 52, global step 5300: 'train_loss' reached -3.71883 (best -3.71883), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=52-step=5300.ckpt' as top 1
# Epoch 53, global step 5400: 'train_loss' was not in top 1
# Epoch 54, global step 5500: 'train_loss' was not in top 1
# Epoch 55, global step 5600: 'train_loss' was not in top 1
# Epoch 56, global step 5700: 'train_loss' was not in top 1
# Epoch 57, global step 5800: 'train_loss' reached -3.72589 (best -3.72589), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=57-step=5800.ckpt' as top 1
# Epoch 58, global step 5900: 'train_loss' reached -3.73207 (best -3.73207), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=58-step=5900.ckpt' as top 1
# Epoch 59, global step 6000: 'train_loss' was not in top 1
# Epoch 60, global step 6100: 'train_loss' reached -3.73574 (best -3.73574), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=60-step=6100.ckpt' as top 1
# Epoch 61, global step 6200: 'train_loss' was not in top 1
# Epoch 62, global step 6300: 'train_loss' reached -3.74003 (best -3.74003), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=62-step=6300.ckpt' as top 1
# Epoch 63, global step 6400: 'train_loss' was not in top 1
# Epoch 64, global step 6500: 'train_loss' was not in top 1
# Epoch 65, global step 6600: 'train_loss' reached -3.74831 (best -3.74831), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=65-step=6600.ckpt' as top 1
# Epoch 66, global step 6700: 'train_loss' was not in top 1
# Epoch 67, global step 6800: 'train_loss' was not in top 1
# Epoch 68, global step 6900: 'train_loss' was not in top 1
# Epoch 69, global step 7000: 'train_loss' was not in top 1
# Epoch 70, global step 7100: 'train_loss' reached -3.74962 (best -3.74962), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=70-step=7100.ckpt' as top 1
# Epoch 71, global step 7200: 'train_loss' reached -3.75899 (best -3.75899), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=71-step=7200.ckpt' as top 1
# Epoch 72, global step 7300: 'train_loss' reached -3.76660 (best -3.76660), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=72-step=7300.ckpt' as top 1
# Epoch 73, global step 7400: 'train_loss' was not in top 1
# Epoch 74, global step 7500: 'train_loss' was not in top 1
# Epoch 75, global step 7600: 'train_loss' was not in top 1
# Epoch 76, global step 7700: 'train_loss' was not in top 1
# Epoch 77, global step 7800: 'train_loss' reached -3.76743 (best -3.76743), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=77-step=7800.ckpt' as top 1
# Epoch 78, global step 7900: 'train_loss' was not in top 1
# Epoch 79, global step 8000: 'train_loss' reached -3.77728 (best -3.77728), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=79-step=8000.ckpt' as top 1
# Epoch 80, global step 8100: 'train_loss' was not in top 1
# Epoch 81, global step 8200: 'train_loss' was not in top 1
# Epoch 82, global step 8300: 'train_loss' reached -3.77860 (best -3.77860), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=82-step=8300.ckpt' as top 1
# Epoch 83, global step 8400: 'train_loss' was not in top 1
# Epoch 84, global step 8500: 'train_loss' was not in top 1
# Epoch 85, global step 8600: 'train_loss' reached -3.78511 (best -3.78511), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=85-step=8600.ckpt' as top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' was not in top 1
# Epoch 88, global step 8900: 'train_loss' was not in top 1
# Epoch 89, global step 9000: 'train_loss' reached -3.79170 (best -3.79170), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=89-step=9000.ckpt' as top 1
# Epoch 90, global step 9100: 'train_loss' was not in top 1
# Epoch 91, global step 9200: 'train_loss' was not in top 1
# Epoch 92, global step 9300: 'train_loss' was not in top 1
# Epoch 93, global step 9400: 'train_loss' was not in top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' was not in top 1
# Epoch 96, global step 9700: 'train_loss' reached -3.79618 (best -3.79618), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=96-step=9700.ckpt' as top 1
# Epoch 97, global step 9800: 'train_loss' reached -3.79679 (best -3.79679), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=97-step=9800.ckpt' as top 1
# Epoch 98, global step 9900: 'train_loss' was not in top 1
# Epoch 99, global step 10000: 'train_loss' reached -3.80606 (best -3.80606), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_11\\checkpoints\\epoch=99-step=10000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 5it [00:00, 74.82it/s]
# Running evaluation: 5it [00:00, 80.87it/s]
# Running evaluation: 5it [00:00, 86.43it/s]
# Running evaluation: 5it [00:00, 87.90it/s]
# Running evaluation: 5it [00:00, 94.59it/s]
# Running evaluation: 5it [00:00, 94.59it/s]
# Running evaluation: 5it [00:00, 94.53it/s]
# Running evaluation: 5it [00:00, 115.50it/s]
# Running evaluation: 5it [00:00, 94.23it/s]

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.012701253908333533
# CRPS: 0.013165102905364615
# QL50: 0.017157140683110247
# QL90: 0.006328209502356641
# MSIS: 21.21383180403131
# NRMSE: 0.02946479299940549
# sMAPE: 0.020936121689155696
# MASE: 2.7424689820042754

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
