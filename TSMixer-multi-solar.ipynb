# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from TSMixer import TSMixerEstimator

# %%
dataset = get_dataset("solar_nips", regenerate=False)
train_grouper = MultivariateGrouper(max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)),
                                   max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
print(dataset.metadata.prediction_length)
# Out:
# 24

# %%
estimator = TSMixerEstimator(
    #distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*2,
    freq=dataset.metadata.freq,
    scaling="std",
    
    depth=2,
    dim=32,

    batch_size=128,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda", max_epochs=1)
)

# %%
predictor = estimator.train(
    training_data=dataset_train, 
    cache_data=True, 
    shuffle_buffer_length=1024, 
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type         | Params
# ---------------------------------------
# 0 | model | TSMixerModel | 36.7 K
# ---------------------------------------
# 36.7 K    Trainable params
# 0         Non-trainable params
# 36.7 K    Total params
# 0.147     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached 4.90070 (best 4.90070), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_108\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=1` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                                 predictor=predictor,
                                                 num_samples=100)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:],
                                  target_agg_funcs={'sum': np.sum})

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 42.23it/s]
# Running evaluation: 7it [00:00, 50.86it/s]
# Running evaluation: 7it [00:00, 53.28it/s]
# Running evaluation: 7it [00:00, 69.83it/s]
# Running evaluation: 7it [00:00, 60.45it/s]
# Running evaluation: 7it [00:00, 69.97it/s]
# Running evaluation: 7it [00:00, 70.17it/s]
# Running evaluation: 7it [00:00, 74.54it/s]
# Running evaluation: 7it [00:00, 89.35it/s]
# Running evaluation: 7it [00:00, 45.40it/s]
# Running evaluation: 7it [00:00, 53.40it/s]
# Running evaluation: 7it [00:00, 41.54it/s]
# Running evaluation: 7it [00:00, 41.75it/s]
# Running evaluation: 7it [00:00, 50.60it/s]
# Running evaluation: 7it [00:00, 56.39it/s]
# Running evaluation: 7it [00:00, 64.14it/s]
# Running evaluation: 7it [00:00, 64.33it/s]
# Running evaluation: 7it [00:00, 63.55it/s]
# Running evaluation: 7it [00:00, 29.49it/s]
# Running evaluation: 7it [00:00, 70.71it/s]
# Running evaluation: 7it [00:00, 71.44it/s]
# Running evaluation: 7it [00:00, 67.86it/s]
# Running evaluation: 7it [00:00, 69.24it/s]
# Running evaluation: 7it [00:00, 66.21it/s]
# Running evaluation: 7it [00:00, 68.49it/s]
# Running evaluation: 7it [00:00, 56.42it/s]
# Running evaluation: 7it [00:00, 66.24it/s]
# Running evaluation: 7it [00:00, 72.39it/s]
# Running evaluation: 7it [00:00, 67.33it/s]
# Running evaluation: 7it [00:00, 41.22it/s]
# Running evaluation: 7it [00:00, 38.04it/s]
# Running evaluation: 7it [00:00, 41.98it/s]
# Running evaluation: 7it [00:00, 43.06it/s]
# Running evaluation: 7it [00:00, 45.28it/s]
# Running evaluation: 7it [00:00, 49.08it/s]
# Running evaluation: 7it [00:00, 47.42it/s]
# Running evaluation: 7it [00:00, 53.99it/s]
# Running evaluation: 7it [00:00, 45.28it/s]
# Running evaluation: 7it [00:00, 53.99it/s]
# Running evaluation: 7it [00:00, 50.13it/s]
# Running evaluation: 7it [00:00, 63.79it/s]
# Running evaluation: 7it [00:00, 59.48it/s]
# Running evaluation: 7it [00:00, 76.26it/s]
# Running evaluation: 7it [00:00, 73.11it/s]
# Running evaluation: 7it [00:00, 78.86it/s]
# Running evaluation: 7it [00:00, 83.56it/s]
# Running evaluation: 7it [00:00, 77.97it/s]
# Running evaluation: 7it [00:00, 77.13it/s]
# Running evaluation: 7it [00:00, 88.88it/s]
# Running evaluation: 7it [00:00, 81.61it/s]
# Running evaluation: 7it [00:00, 63.81it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 64.39it/s]
# Running evaluation: 7it [00:00, 67.49it/s]
# Running evaluation: 7it [00:00, 68.14it/s]
# Running evaluation: 7it [00:00, 73.88it/s]
# Running evaluation: 7it [00:00, 74.64it/s]
# Running evaluation: 7it [00:00, 71.62it/s]
# Running evaluation: 7it [00:00, 78.86it/s]
# Running evaluation: 7it [00:00, 71.60it/s]
# Running evaluation: 7it [00:00, 61.57it/s]
# Running evaluation: 7it [00:00, 71.62it/s]
# Running evaluation: 7it [00:00, 55.27it/s]
# Running evaluation: 7it [00:00, 64.99it/s]
# Running evaluation: 7it [00:00, 58.98it/s]
# Running evaluation: 7it [00:00, 56.15it/s]
# Running evaluation: 7it [00:00, 63.23it/s]
# Running evaluation: 7it [00:00, 73.85it/s]
# Running evaluation: 7it [00:00, 76.29it/s]
# Running evaluation: 7it [00:00, 75.47it/s]
# Running evaluation: 7it [00:00, 69.47it/s]
# Running evaluation: 7it [00:00, 82.58it/s]
# Running evaluation: 7it [00:00, 74.67it/s]
# Running evaluation: 7it [00:00, 82.58it/s]
# Running evaluation: 7it [00:00, 81.58it/s]
# Running evaluation: 7it [00:00, 70.16it/s]
# Running evaluation: 7it [00:00, 78.86it/s]
# Running evaluation: 7it [00:00, 67.47it/s]
# Running evaluation: 7it [00:00, 60.49it/s]
# Running evaluation: 7it [00:00, 65.60it/s]
# Running evaluation: 7it [00:00, 53.17it/s]
# Running evaluation: 7it [00:00, 33.42it/s]
# Running evaluation: 7it [00:00, 22.50it/s]
# Running evaluation: 7it [00:00, 39.43it/s]
# Running evaluation: 7it [00:00, 46.79it/s]
# Running evaluation: 7it [00:00, 56.60it/s]
# Running evaluation: 7it [00:00, 64.39it/s]
# Running evaluation: 7it [00:00, 63.81it/s]
# Running evaluation: 7it [00:00, 56.60it/s]
# Running evaluation: 7it [00:00, 62.10it/s]
# Running evaluation: 7it [00:00, 61.55it/s]
# Running evaluation: 7it [00:00, 74.85it/s]
# Running evaluation: 7it [00:00, 68.12it/s]
# Running evaluation: 7it [00:00, 53.58it/s]
# Running evaluation: 7it [00:00, 49.43it/s]
# Running evaluation: 7it [00:00, 57.06it/s]
# Running evaluation: 7it [00:00, 59.48it/s]
# Running evaluation: 7it [00:00, 58.47it/s]
# Running evaluation: 7it [00:00, 67.49it/s]
# Running evaluation: 7it [00:00, 72.35it/s]
# Running evaluation: 7it [00:00, 76.28it/s]
# Running evaluation: 7it [00:00, 77.03it/s]
# Running evaluation: 7it [00:00, 73.11it/s]
# Running evaluation: 7it [00:00, 74.67it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 89.98it/s]
# Running evaluation: 7it [00:00, 94.80it/s]
# Running evaluation: 7it [00:00, 104.76it/s]
# Running evaluation: 7it [00:00, 92.35it/s]
# Running evaluation: 7it [00:00, 96.15it/s]
# Running evaluation: 7it [00:00, 85.60it/s]
# Running evaluation: 7it [00:00, 91.15it/s]
# Running evaluation: 7it [00:00, 96.15it/s]
# Running evaluation: 7it [00:00, 97.51it/s]
# Running evaluation: 7it [00:00, 101.77it/s]
# Running evaluation: 7it [00:00, 79.76it/s]
# Running evaluation: 7it [00:00, 101.73it/s]
# Running evaluation: 7it [00:00, 96.15it/s]
# Running evaluation: 7it [00:00, 87.73it/s]
# Running evaluation: 7it [00:00, 92.31it/s]
# Running evaluation: 7it [00:00, 98.86it/s]
# Running evaluation: 7it [00:00, 101.67it/s]
# Running evaluation: 7it [00:00, 100.27it/s]
# Running evaluation: 7it [00:00, 94.81it/s]
# Running evaluation: 7it [00:00, 100.22it/s]
# Running evaluation: 7it [00:00, 100.27it/s]
# Running evaluation: 7it [00:00, 104.70it/s]
# Running evaluation: 7it [00:00, 101.72it/s]
# Running evaluation: 7it [00:00, 104.71it/s]
# Running evaluation: 7it [00:00, 89.95it/s]
# Running evaluation: 7it [00:00, 84.56it/s]
# Running evaluation: 7it [00:00, 100.27it/s]
# Running evaluation: 7it [00:00, 104.71it/s]
# Running evaluation: 7it [00:00, 91.15it/s]
# Running evaluation: 7it [00:00, 81.62it/s]
# Running evaluation: 7it [00:00, 97.44it/s]
# Running evaluation: 7it [00:00, 96.15it/s]
# Running evaluation: 7it [00:00, 68.14it/s]

# %%
print("CRPS: {}".format(agg_metric['mean_wQuantileLoss']))
print("ND: {}".format(agg_metric['ND']))
print("NRMSE: {}".format(agg_metric['NRMSE']))
print("MSE: {}".format(agg_metric['MSE']))
# Out:
# CRPS: 0.3967405713213606
# ND: 0.5301556111119646
# NRMSE: 1.0254258740021622
# MSE: 997.4389663420495

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
