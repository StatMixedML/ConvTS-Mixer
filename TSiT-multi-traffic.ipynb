# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.modules import StudentTOutput

from TSiT import TSiTEstimator
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
dataset = get_dataset("traffic_nips", regenerate=False)
train_grouper = MultivariateGrouper(max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)), 
                                   max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = TSiTEstimator(
    #distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*2,
    freq=dataset.metadata.freq,
    scaling="std",
    
    depth=4,
    dim=64,
    patch_size=(3,20),

    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda")
)

# %%
predictor = estimator.train(
    training_data=dataset_train, 
    cache_data=True, 
    shuffle_buffer_length=1024,
)
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type      | Params
# ------------------------------------
# 0 | model | TSiTModel | 164 K
# ------------------------------------
# 115 K     Trainable params
# 49.2 K    Non-trainable params
# 164 K     Total params
# 0.659     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -1.93082 (best -1.93082), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -2.43314 (best -2.43314), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -2.66374 (best -2.66374), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -2.71985 (best -2.71985), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -2.76409 (best -2.76409), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -2.78176 (best -2.78176), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -2.80642 (best -2.80642), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -2.82241 (best -2.82241), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -2.82773 (best -2.82773), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -2.83298 (best -2.83298), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -2.84957 (best -2.84957), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -2.85284 (best -2.85284), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -2.85920 (best -2.85920), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached -2.86160 (best -2.86160), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached -2.87220 (best -2.87220), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' reached -2.87458 (best -2.87458), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' was not in top 1
# Epoch 17, global step 1800: 'train_loss' reached -2.87992 (best -2.87992), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' was not in top 1
# Epoch 19, global step 2000: 'train_loss' reached -2.88375 (best -2.88375), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' was not in top 1
# Epoch 21, global step 2200: 'train_loss' reached -2.88552 (best -2.88552), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' reached -2.89643 (best -2.89643), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=22-step=2300.ckpt' as top 1
# Epoch 23, global step 2400: 'train_loss' reached -2.89702 (best -2.89702), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_100/checkpoints/epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' was not in top 1
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:54: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                             predictor=predictor,
                                             num_samples=100)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:],
                                  target_agg_funcs={'sum': np.sum})

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 68.59it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.48it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 111.42it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.79it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 111.24it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 111.13it/s]
#
# Running evaluation: 7it [00:00, 107.12it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 111.02it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 111.02it/s]
#
# Running evaluation: 7it [00:00, 110.86it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.03it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 89.01it/s]
#
# Running evaluation: 7it [00:00, 108.58it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 111.33it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 111.28it/s]
#
# Running evaluation: 7it [00:00, 111.28it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 111.10it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 111.44it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 110.31it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 110.39it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 111.61it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 111.33it/s]
#
# Running evaluation: 7it [00:00, 111.51it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 111.47it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 111.34it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 110.81it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 111.24it/s]
#
# Running evaluation: 7it [00:00, 111.25it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.24it/s]
#
# Running evaluation: 7it [00:00, 111.26it/s]
#
# Running evaluation: 7it [00:00, 111.02it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 111.49it/s]
#
# Running evaluation: 7it [00:00, 111.13it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 111.48it/s]
#
# Running evaluation: 7it [00:00, 111.67it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.89it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 112.63it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.83it/s]
#
# Running evaluation: 7it [00:00, 111.98it/s]
#
# Running evaluation: 7it [00:00, 111.56it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 112.18it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 109.95it/s]
#
# Running evaluation: 7it [00:00, 100.07it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.34it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.34it/s]
#
# Running evaluation: 7it [00:00, 111.72it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.72it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 112.47it/s]
#
# Running evaluation: 7it [00:00, 111.70it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 111.49it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 111.83it/s]
#
# Running evaluation: 7it [00:00, 112.45it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.13it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 107.98it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 112.58it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 111.98it/s]
#
# Running evaluation: 7it [00:00, 111.61it/s]
#
# Running evaluation: 7it [00:00, 111.51it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 111.51it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 110.04it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 111.79it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 112.30it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 112.04it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.47it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 111.60it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
#
# Running evaluation: 7it [00:00, 111.86it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 111.08it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 111.34it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 111.01it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.39it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 111.12it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 111.08it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 108.87it/s]
#
# Running evaluation: 7it [00:00, 111.01it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 92.31it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.33it/s]
#
# Running evaluation: 7it [00:00, 112.53it/s]
#
# Running evaluation: 7it [00:00, 112.04it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 111.13it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.28it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.52it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 112.22it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.83it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.79it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 111.44it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 111.82it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 111.98it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 101.06it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
# Running evaluation: 7it [00:00, 109.86it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 107.28it/s]
#
# Running evaluation: 7it [00:00, 109.28it/s]
#
# Running evaluation: 7it [00:00, 109.87it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 111.86it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 109.15it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 109.78it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 109.94it/s]
#
# Running evaluation: 7it [00:00, 110.30it/s]
#
# Running evaluation: 7it [00:00, 106.73it/s]
#
# Running evaluation: 7it [00:00, 103.26it/s]
#
# Running evaluation: 7it [00:00, 109.27it/s]
#
# Running evaluation: 7it [00:00, 109.91it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 107.65it/s]
#
# Running evaluation: 7it [00:00, 109.95it/s]
#
# Running evaluation: 7it [00:00, 108.94it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 111.61it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 107.74it/s]
#
# Running evaluation: 7it [00:00, 110.81it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 110.47it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 112.58it/s]
#
# Running evaluation: 7it [00:00, 111.72it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 112.00it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.03it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 112.35it/s]
#
# Running evaluation: 7it [00:00, 110.97it/s]
#
# Running evaluation: 7it [00:00, 111.67it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 111.86it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 111.54it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 94.38it/s]
#
# Running evaluation: 7it [00:00, 109.21it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 111.89it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 112.09it/s]
#
# Running evaluation: 7it [00:00, 112.41it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 111.67it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.70it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 111.60it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.75it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 112.51it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 111.24it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 111.83it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 112.00it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 112.59it/s]
#
# Running evaluation: 7it [00:00, 111.61it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.56it/s]
#
# Running evaluation: 7it [00:00, 111.74it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 108.65it/s]
#
# Running evaluation: 7it [00:00, 111.60it/s]
#
# Running evaluation: 7it [00:00, 111.48it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 111.10it/s]
#
# Running evaluation: 7it [00:00, 112.25it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 112.10it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 112.11it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 111.56it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 112.11it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 112.43it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 108.41it/s]
#
# Running evaluation: 7it [00:00, 108.54it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.74it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 110.39it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.14it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.81it/s]
#
# Running evaluation: 7it [00:00, 110.39it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.25it/s]
#
# Running evaluation: 7it [00:00, 111.15it/s]
#
# Running evaluation: 7it [00:00, 110.47it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 106.95it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 112.42it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 112.25it/s]
#
# Running evaluation: 7it [00:00, 112.21it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 111.56it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 111.48it/s]
#
# Running evaluation: 7it [00:00, 112.09it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 107.74it/s]
#
# Running evaluation: 7it [00:00, 108.09it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 112.45it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 112.48it/s]
#
# Running evaluation: 7it [00:00, 112.36it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 112.38it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 112.41it/s]
#
# Running evaluation: 7it [00:00, 112.10it/s]
#
# Running evaluation: 7it [00:00, 112.21it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 112.41it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 111.49it/s]
#
# Running evaluation: 7it [00:00, 111.80it/s]
#
# Running evaluation: 7it [00:00, 111.89it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 108.74it/s]
#
# Running evaluation: 7it [00:00, 111.86it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 108.40it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 110.22it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 112.22it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 112.15it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.88it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.25it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 111.70it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 111.72it/s]
#
# Running evaluation: 7it [00:00, 112.42it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 111.28it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.31it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 111.48it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.79it/s]
#
# Running evaluation: 7it [00:00, 112.62it/s]
#
# Running evaluation: 7it [00:00, 112.23it/s]
#
# Running evaluation: 7it [00:00, 112.04it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 111.97it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.31it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.19it/s]
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 112.50it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 112.07it/s]
#
# Running evaluation: 7it [00:00, 112.31it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 112.42it/s]
#
# Running evaluation: 7it [00:00, 109.90it/s]
#
# Running evaluation: 7it [00:00, 111.01it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 111.82it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.55it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 13.98it/s]
#
# Running evaluation: 7it [00:00, 113.09it/s]
#
# Running evaluation: 7it [00:00, 111.32it/s]
#
# Running evaluation: 7it [00:00, 111.33it/s]
#
# Running evaluation: 7it [00:00, 112.17it/s]
#
# Running evaluation: 7it [00:00, 111.89it/s]
#
# Running evaluation: 7it [00:00, 112.43it/s]
#
# Running evaluation: 7it [00:00, 111.79it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 111.67it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 112.76it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 111.98it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 111.52it/s]
#
# Running evaluation: 7it [00:00, 112.56it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 106.37it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 112.19it/s]
#
# Running evaluation: 7it [00:00, 112.72it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 112.34it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 111.52it/s]
#
# Running evaluation: 7it [00:00, 112.18it/s]
#
# Running evaluation: 7it [00:00, 112.11it/s]
#
# Running evaluation: 7it [00:00, 112.38it/s]
#
# Running evaluation: 7it [00:00, 111.54it/s]
#
# Running evaluation: 7it [00:00, 111.46it/s]
#
# Running evaluation: 7it [00:00, 112.47it/s]
#
# Running evaluation: 7it [00:00, 112.53it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 106.36it/s]
#
# Running evaluation: 7it [00:00, 111.12it/s]
#
# Running evaluation: 7it [00:00, 111.44it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 112.19it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 111.26it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 109.93it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 112.10it/s]
#
# Running evaluation: 7it [00:00, 109.73it/s]
#
# Running evaluation: 7it [00:00, 102.28it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 112.39it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 112.68it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 112.22it/s]
#
# Running evaluation: 7it [00:00, 111.39it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.44it/s]
#
# Running evaluation: 7it [00:00, 112.10it/s]
#
# Running evaluation: 7it [00:00, 112.49it/s]
#
# Running evaluation: 7it [00:00, 112.21it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 112.23it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 112.00it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 112.15it/s]
#
# Running evaluation: 7it [00:00, 112.44it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 112.21it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 111.77it/s]
#
# Running evaluation: 7it [00:00, 111.54it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 112.64it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 111.66it/s]
#
# Running evaluation: 7it [00:00, 111.75it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 112.25it/s]
#
# Running evaluation: 7it [00:00, 111.90it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.63it/s]
#
# Running evaluation: 7it [00:00, 112.00it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.34it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 112.12it/s]
#
# Running evaluation: 7it [00:00, 112.04it/s]
#
# Running evaluation: 7it [00:00, 111.62it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.39it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 111.89it/s]
#
# Running evaluation: 7it [00:00, 112.42it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 112.51it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 111.51it/s]
#
# Running evaluation: 7it [00:00, 111.59it/s]
#
# Running evaluation: 7it [00:00, 111.98it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 112.56it/s]
#
# Running evaluation: 7it [00:00, 112.47it/s]
#
# Running evaluation: 7it [00:00, 112.63it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 112.11it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 112.30it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.05it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 111.96it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 111.71it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 112.19it/s]
#
# Running evaluation: 7it [00:00, 112.33it/s]
#
# Running evaluation: 7it [00:00, 111.44it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 111.50it/s]
#
# Running evaluation: 7it [00:00, 106.38it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 112.21it/s]
#
# Running evaluation: 7it [00:00, 111.82it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 112.15it/s]
#
# Running evaluation: 7it [00:00, 112.04it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 111.87it/s]
#
# Running evaluation: 7it [00:00, 112.09it/s]
#
# Running evaluation: 7it [00:00, 112.23it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 112.30it/s]
#
# Running evaluation: 7it [00:00, 112.29it/s]
#
# Running evaluation: 7it [00:00, 111.54it/s]
#
# Running evaluation: 7it [00:00, 112.03it/s]
#
# Running evaluation: 7it [00:00, 112.27it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 112.01it/s]
#
# Running evaluation: 7it [00:00, 112.20it/s]
#
# Running evaluation: 7it [00:00, 112.47it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 112.45it/s]
#
# Running evaluation: 7it [00:00, 112.10it/s]
#
# Running evaluation: 7it [00:00, 111.95it/s]
#
# Running evaluation: 7it [00:00, 111.49it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 112.34it/s]
#
# Running evaluation: 7it [00:00, 111.69it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 111.67it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 111.83it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 111.94it/s]
#
# Running evaluation: 7it [00:00, 111.60it/s]
#
# Running evaluation: 7it [00:00, 111.76it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 111.78it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 112.06it/s]
#
# Running evaluation: 7it [00:00, 110.71it/s]
#
# Running evaluation: 7it [00:00, 64.82it/s]

# %%
print("CRPS: {}".format(agg_metric['mean_wQuantileLoss']))
print("ND: {}".format(agg_metric['ND']))
print("NRMSE: {}".format(agg_metric['NRMSE']))
print("MSE: {}".format(agg_metric['MSE']))
# Out:
# CRPS: 0.20399959246862942
# ND: 0.26769644551146027
# NRMSE: 0.5373356317396341
# MSE: 0.0007918963440047035

# %%
print("CRPS: {}".format(agg_metric['mean_wQuantileLoss']))
print("ND: {}".format(agg_metric['ND']))
print("NRMSE: {}".format(agg_metric['NRMSE']))
print("MSE: {}".format(agg_metric['MSE']))
# Out:
# CRPS: 0.20586276151444743
# ND: 0.2687752385189626
# NRMSE: 0.5425743141699111
# MSE: 0.0008074125905029147

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
