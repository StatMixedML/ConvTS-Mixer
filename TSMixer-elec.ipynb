# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator, aggregate_valid

from TSMixer import TSMixerEstimator
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
dataset = get_dataset("electricity_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = TSMixerEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=2,
    dim=32,
    expansion_factor=2,
    batch_size=32,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda", max_epochs=100),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type         | Params
# ---------------------------------------
# 0 | model | TSMixerModel | 36.7 K
# ---------------------------------------
# 36.7 K    Trainable params
# 0         Non-trainable params
# 36.7 K    Total params
# 0.147     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached 4.94100 (best 4.94100), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached 4.51196 (best 4.51196), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached 4.38143 (best 4.38143), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached 4.30935 (best 4.30935), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached 4.27092 (best 4.27092), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached 4.22003 (best 4.22003), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached 4.20107 (best 4.20107), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached 4.17213 (best 4.17213), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached 4.15735 (best 4.15735), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached 4.13340 (best 4.13340), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached 4.12377 (best 4.12377), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached 4.11490 (best 4.11490), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached 4.10849 (best 4.10849), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached 4.08933 (best 4.08933), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' was not in top 1
# Epoch 15, global step 1600: 'train_loss' reached 4.07198 (best 4.07198), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' reached 4.06596 (best 4.06596), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' was not in top 1
# Epoch 18, global step 1900: 'train_loss' reached 4.05470 (best 4.05470), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_160/checkpoints/epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' was not in top 1

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)
evaluator.aggregation_strategy = aggregate_valid

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 75.24it/s]
#
# Running evaluation: 7it [00:00, 115.44it/s]
#
# Running evaluation: 7it [00:00, 114.47it/s]
#
# Running evaluation: 7it [00:00, 114.64it/s]
#
# Running evaluation: 7it [00:00, 114.75it/s]
#
# Running evaluation: 7it [00:00, 113.92it/s]
#
# Running evaluation: 7it [00:00, 114.18it/s]
#
# Running evaluation: 7it [00:00, 114.20it/s]
#
# Running evaluation: 7it [00:00, 114.20it/s]
#
# Running evaluation: 7it [00:00, 114.44it/s]
#
# Running evaluation: 7it [00:00, 114.51it/s]
#
# Running evaluation: 7it [00:00, 114.68it/s]
#
# Running evaluation: 7it [00:00, 114.32it/s]
#
# Running evaluation: 7it [00:00, 114.44it/s]
#
# Running evaluation: 7it [00:00, 113.82it/s]
#
# Running evaluation: 7it [00:00, 114.55it/s]
#
# Running evaluation: 7it [00:00, 114.36it/s]
#
# Running evaluation: 7it [00:00, 113.28it/s]
#
# Running evaluation: 7it [00:00, 113.50it/s]
#
# Running evaluation: 7it [00:00, 113.41it/s]
#
# Running evaluation: 7it [00:00, 113.83it/s]
#
# Running evaluation: 7it [00:00, 114.00it/s]
#
# Running evaluation: 7it [00:00, 114.30it/s]
#
# Running evaluation: 7it [00:00, 114.27it/s]
#
# Running evaluation: 7it [00:00, 114.17it/s]
#
# Running evaluation: 7it [00:00, 113.91it/s]
#
# Running evaluation: 7it [00:00, 114.16it/s]
#
# Running evaluation: 7it [00:00, 114.48it/s]
#
# Running evaluation: 7it [00:00, 114.08it/s]
#
# Running evaluation: 7it [00:00, 114.26it/s]
#
# Running evaluation: 7it [00:00, 114.23it/s]
#
# Running evaluation: 7it [00:00, 114.24it/s]
#
# Running evaluation: 7it [00:00, 113.54it/s]
#
# Running evaluation: 7it [00:00, 114.05it/s]
#
# Running evaluation: 7it [00:00, 113.98it/s]
#
# Running evaluation: 7it [00:00, 113.87it/s]
#
# Running evaluation: 7it [00:00, 113.77it/s]
#
# Running evaluation: 7it [00:00, 114.24it/s]
#
# Running evaluation: 7it [00:00, 113.81it/s]
#
# Running evaluation: 7it [00:00, 114.30it/s]
#
# Running evaluation: 7it [00:00, 113.63it/s]
#
# Running evaluation: 7it [00:00, 113.73it/s]
#
# Running evaluation: 7it [00:00, 113.95it/s]
#
# Running evaluation: 7it [00:00, 114.64it/s]
#
# Running evaluation: 7it [00:00, 113.88it/s]
#
# Running evaluation: 7it [00:00, 114.44it/s]
#
# Running evaluation: 7it [00:00, 112.83it/s]
#
# Running evaluation: 7it [00:00, 114.07it/s]
#
# Running evaluation: 7it [00:00, 113.24it/s]
#
# Running evaluation: 7it [00:00, 111.92it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 114.10it/s]
#
# Running evaluation: 7it [00:00, 113.73it/s]
#
# Running evaluation: 7it [00:00, 113.77it/s]
#
# Running evaluation: 7it [00:00, 113.85it/s]
#
# Running evaluation: 7it [00:00, 114.30it/s]
#
# Running evaluation: 7it [00:00, 113.02it/s]
#
# Running evaluation: 7it [00:00, 114.03it/s]
#
# Running evaluation: 7it [00:00, 113.47it/s]
#
# Running evaluation: 7it [00:00, 113.57it/s]
#
# Running evaluation: 7it [00:00, 113.84it/s]
#
# Running evaluation: 7it [00:00, 113.77it/s]
#
# Running evaluation: 7it [00:00, 113.83it/s]
#
# Running evaluation: 7it [00:00, 113.41it/s]
#
# Running evaluation: 7it [00:00, 113.30it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 113.58it/s]
#
# Running evaluation: 7it [00:00, 113.66it/s]
#
# Running evaluation: 7it [00:00, 113.33it/s]
#
# Running evaluation: 7it [00:00, 112.89it/s]
#
# Running evaluation: 7it [00:00, 113.04it/s]
#
# Running evaluation: 7it [00:00, 113.05it/s]
#
# Running evaluation: 7it [00:00, 112.93it/s]
#
# Running evaluation: 7it [00:00, 113.46it/s]
#
# Running evaluation: 7it [00:00, 113.40it/s]
#
# Running evaluation: 7it [00:00, 113.35it/s]
#
# Running evaluation: 7it [00:00, 113.79it/s]
#
# Running evaluation: 7it [00:00, 113.23it/s]
#
# Running evaluation: 7it [00:00, 113.88it/s]
#
# Running evaluation: 7it [00:00, 113.06it/s]
#
# Running evaluation: 7it [00:00, 113.43it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 112.95it/s]
#
# Running evaluation: 7it [00:00, 105.87it/s]
#
# Running evaluation: 7it [00:00, 112.68it/s]
#
# Running evaluation: 7it [00:00, 113.49it/s]
#
# Running evaluation: 7it [00:00, 113.59it/s]
#
# Running evaluation: 7it [00:00, 113.95it/s]
#
# Running evaluation: 7it [00:00, 112.80it/s]
#
# Running evaluation: 7it [00:00, 109.38it/s]
#
# Running evaluation: 7it [00:00, 113.53it/s]
#
# Running evaluation: 7it [00:00, 113.45it/s]
#
# Running evaluation: 7it [00:00, 113.38it/s]
#
# Running evaluation: 7it [00:00, 114.01it/s]
#
# Running evaluation: 7it [00:00, 113.71it/s]
#
# Running evaluation: 7it [00:00, 113.68it/s]
#
# Running evaluation: 7it [00:00, 113.88it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 113.83it/s]
#
# Running evaluation: 7it [00:00, 113.93it/s]
#
# Running evaluation: 7it [00:00, 113.84it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 114.16it/s]
#
# Running evaluation: 7it [00:00, 113.91it/s]
#
# Running evaluation: 7it [00:00, 114.20it/s]
#
# Running evaluation: 7it [00:00, 113.70it/s]
#
# Running evaluation: 7it [00:00, 113.76it/s]
#
# Running evaluation: 7it [00:00, 114.04it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 113.57it/s]
#
# Running evaluation: 7it [00:00, 113.68it/s]
#
# Running evaluation: 7it [00:00, 111.93it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 113.18it/s]
#
# Running evaluation: 7it [00:00, 113.54it/s]
#
# Running evaluation: 7it [00:00, 113.79it/s]
#
# Running evaluation: 7it [00:00, 113.09it/s]
#
# Running evaluation: 7it [00:00, 113.95it/s]
#
# Running evaluation: 7it [00:00, 112.67it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 113.39it/s]
#
# Running evaluation: 7it [00:00, 113.54it/s]
#
# Running evaluation: 7it [00:00, 113.67it/s]
#
# Running evaluation: 7it [00:00, 113.48it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 112.94it/s]
#
# Running evaluation: 7it [00:00, 113.43it/s]
#
# Running evaluation: 7it [00:00, 113.19it/s]
#
# Running evaluation: 7it [00:00, 113.53it/s]
#
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 113.35it/s]
#
# Running evaluation: 7it [00:00, 113.85it/s]
#
# Running evaluation: 7it [00:00, 113.62it/s]
#
# Running evaluation: 7it [00:00, 113.67it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 113.60it/s]
#
# Running evaluation: 7it [00:00, 112.53it/s]
#
# Running evaluation: 7it [00:00, 113.82it/s]
#
# Running evaluation: 7it [00:00, 113.32it/s]
#
# Running evaluation: 7it [00:00, 113.55it/s]
#
# Running evaluation: 7it [00:00, 113.58it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.20it/s]
#
# Running evaluation: 7it [00:00, 113.26it/s]
#
# Running evaluation: 7it [00:00, 112.70it/s]
#
# Running evaluation: 7it [00:00, 112.93it/s]
#
# Running evaluation: 7it [00:00, 113.47it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 113.51it/s]
#
# Running evaluation: 7it [00:00, 113.33it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 113.05it/s]
#
# Running evaluation: 7it [00:00, 113.37it/s]
#
# Running evaluation: 7it [00:00, 112.99it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.36it/s]
#
# Running evaluation: 7it [00:00, 112.16it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.70it/s]
#
# Running evaluation: 7it [00:00, 113.61it/s]
#
# Running evaluation: 7it [00:00, 112.13it/s]
#
# Running evaluation: 7it [00:00, 113.15it/s]
#
# Running evaluation: 7it [00:00, 113.40it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 113.02it/s]
#
# Running evaluation: 7it [00:00, 113.06it/s]
#
# Running evaluation: 7it [00:00, 113.62it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 113.02it/s]
#
# Running evaluation: 7it [00:00, 113.51it/s]
#
# Running evaluation: 7it [00:00, 113.43it/s]
#
# Running evaluation: 7it [00:00, 113.52it/s]
#
# Running evaluation: 7it [00:00, 113.93it/s]
#
# Running evaluation: 7it [00:00, 113.32it/s]
#
# Running evaluation: 7it [00:00, 113.45it/s]
#
# Running evaluation: 7it [00:00, 112.97it/s]
#
# Running evaluation: 7it [00:00, 113.14it/s]
#
# Running evaluation: 7it [00:00, 113.39it/s]
#
# Running evaluation: 7it [00:00, 113.93it/s]
#
# Running evaluation: 7it [00:00, 113.42it/s]
#
# Running evaluation: 7it [00:00, 113.46it/s]
# Running evaluation: 7it [00:00, 113.44it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 113.34it/s]
#
# Running evaluation: 7it [00:00, 113.82it/s]
#
# Running evaluation: 7it [00:00, 113.61it/s]
#
# Running evaluation: 7it [00:00, 113.46it/s]
#
# Running evaluation: 7it [00:00, 113.52it/s]
#
# Running evaluation: 7it [00:00, 113.41it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 113.66it/s]
#
# Running evaluation: 7it [00:00, 113.63it/s]
#
# Running evaluation: 7it [00:00, 113.70it/s]
#
# Running evaluation: 7it [00:00, 113.62it/s]
#
# Running evaluation: 7it [00:00, 113.57it/s]
#
# Running evaluation: 7it [00:00, 113.17it/s]
#
# Running evaluation: 7it [00:00, 112.96it/s]
#
# Running evaluation: 7it [00:00, 113.65it/s]
#
# Running evaluation: 7it [00:00, 113.31it/s]
#
# Running evaluation: 7it [00:00, 113.36it/s]
#
# Running evaluation: 7it [00:00, 112.83it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 113.27it/s]
#
# Running evaluation: 7it [00:00, 113.28it/s]
#
# Running evaluation: 7it [00:00, 113.46it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 112.63it/s]
#
# Running evaluation: 7it [00:00, 112.95it/s]
#
# Running evaluation: 7it [00:00, 114.01it/s]
#
# Running evaluation: 7it [00:00, 113.69it/s]
#
# Running evaluation: 7it [00:00, 112.77it/s]
#
# Running evaluation: 7it [00:00, 113.31it/s]
#
# Running evaluation: 7it [00:00, 113.32it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 113.05it/s]
#
# Running evaluation: 7it [00:00, 112.92it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 112.69it/s]
#
# Running evaluation: 7it [00:00, 112.44it/s]
#
# Running evaluation: 7it [00:00, 113.53it/s]
#
# Running evaluation: 7it [00:00, 113.01it/s]
#
# Running evaluation: 7it [00:00, 113.03it/s]
#
# Running evaluation: 7it [00:00, 113.21it/s]
#
# Running evaluation: 7it [00:00, 113.06it/s]
#
# Running evaluation: 7it [00:00, 113.22it/s]
#
# Running evaluation: 7it [00:00, 112.66it/s]
#
# Running evaluation: 7it [00:00, 112.76it/s]
#
# Running evaluation: 7it [00:00, 112.76it/s]
#
# Running evaluation: 7it [00:00, 112.66it/s]
#
# Running evaluation: 7it [00:00, 113.55it/s]
#
# Running evaluation: 7it [00:00, 112.74it/s]
#
# Running evaluation: 7it [00:00, 113.03it/s]
#
# Running evaluation: 7it [00:00, 113.39it/s]
#
# Running evaluation: 7it [00:00, 113.23it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 112.24it/s]
#
# Running evaluation: 7it [00:00, 113.16it/s]
#
# Running evaluation: 7it [00:00, 112.37it/s]
#
# Running evaluation: 7it [00:00, 113.00it/s]
#
# Running evaluation: 7it [00:00, 113.81it/s]
#
# Running evaluation: 7it [00:00, 112.94it/s]
#
# Running evaluation: 7it [00:00, 113.28it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 112.79it/s]
#
# Running evaluation: 7it [00:00, 113.17it/s]
#
# Running evaluation: 7it [00:00, 113.07it/s]
#
# Running evaluation: 7it [00:00, 113.48it/s]
#
# Running evaluation: 7it [00:00, 113.20it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 113.02it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 111.72it/s]
#
# Running evaluation: 7it [00:00, 112.49it/s]
#
# Running evaluation: 7it [00:00, 112.48it/s]
#
# Running evaluation: 7it [00:00, 112.45it/s]
#
# Running evaluation: 7it [00:00, 107.64it/s]
#
# Running evaluation: 7it [00:00, 112.02it/s]
#
# Running evaluation: 7it [00:00, 112.35it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 112.52it/s]
#
# Running evaluation: 7it [00:00, 112.87it/s]
#
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 112.78it/s]
#
# Running evaluation: 7it [00:00, 112.75it/s]
#
# Running evaluation: 7it [00:00, 112.95it/s]
#
# Running evaluation: 7it [00:00, 112.62it/s]
#
# Running evaluation: 7it [00:00, 112.57it/s]
#
# Running evaluation: 7it [00:00, 112.70it/s]
#
# Running evaluation: 7it [00:00, 112.69it/s]
#
# Running evaluation: 7it [00:00, 112.76it/s]
#
# Running evaluation: 7it [00:00, 112.50it/s]
#
# Running evaluation: 7it [00:00, 112.73it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 112.41it/s]
#
# Running evaluation: 7it [00:00, 112.57it/s]
#
# Running evaluation: 7it [00:00, 112.72it/s]
#
# Running evaluation: 7it [00:00, 112.32it/s]
#
# Running evaluation: 7it [00:00, 113.11it/s]
#
# Running evaluation: 7it [00:00, 112.34it/s]
#
# Running evaluation: 7it [00:00, 113.17it/s]
#
# Running evaluation: 7it [00:00, 113.55it/s]
#
# Running evaluation: 7it [00:00, 113.01it/s]
#
# Running evaluation: 7it [00:00, 113.33it/s]
#
# Running evaluation: 7it [00:00, 113.70it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 88.76it/s]
#
# Running evaluation: 7it [00:00, 106.37it/s]
#
# Running evaluation: 7it [00:00, 113.60it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.94it/s]
#
# Running evaluation: 7it [00:00, 113.15it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.97it/s]
#
# Running evaluation: 7it [00:00, 113.38it/s]
#
# Running evaluation: 7it [00:00, 113.80it/s]
#
# Running evaluation: 7it [00:00, 113.89it/s]
#
# Running evaluation: 7it [00:00, 113.20it/s]
#
# Running evaluation: 7it [00:00, 112.69it/s]
#
# Running evaluation: 7it [00:00, 112.98it/s]
#
# Running evaluation: 7it [00:00, 112.82it/s]
#
# Running evaluation: 7it [00:00, 112.84it/s]
#
# Running evaluation: 7it [00:00, 113.08it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 113.85it/s]
#
# Running evaluation: 7it [00:00, 113.31it/s]
#
# Running evaluation: 7it [00:00, 113.59it/s]
#
# Running evaluation: 7it [00:00, 113.56it/s]
#
# Running evaluation: 7it [00:00, 113.79it/s]
#
# Running evaluation: 7it [00:00, 113.16it/s]
#
# Running evaluation: 7it [00:00, 113.44it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 113.80it/s]
#
# Running evaluation: 7it [00:00, 113.38it/s]
#
# Running evaluation: 7it [00:00, 113.45it/s]
#
# Running evaluation: 7it [00:00, 113.33it/s]
#
# Running evaluation: 7it [00:00, 113.36it/s]
#
# Running evaluation: 7it [00:00, 113.62it/s]
#
# Running evaluation: 7it [00:00, 112.28it/s]
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:513: RuntimeWarning: divide by zero encountered in scalar divide
#   totals["NRMSE"] = totals["RMSE"] / totals["abs_target_mean"]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:514: RuntimeWarning: divide by zero encountered in scalar divide
#   totals["ND"] = totals["abs_error"] / totals["abs_target_sum"]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:518: RuntimeWarning: divide by zero encountered in scalar divide
#   totals[f"QuantileLoss[{quantile}]"] / totals["abs_target_sum"]
#
# Running evaluation: 7it [00:00, 105.11it/s]
#
# Running evaluation: 7it [00:00, 112.70it/s]
#
# Running evaluation: 7it [00:00, 113.89it/s]
#
# Running evaluation: 7it [00:00, 113.59it/s]
#
# Running evaluation: 7it [00:00, 113.32it/s]
#
# Running evaluation: 7it [00:00, 113.73it/s]
#
# Running evaluation: 7it [00:00, 112.76it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 113.45it/s]
#
# Running evaluation: 7it [00:00, 113.72it/s]
#
# Running evaluation: 7it [00:00, 114.05it/s]
#
# Running evaluation: 7it [00:00, 113.29it/s]
#
# Running evaluation: 7it [00:00, 113.44it/s]
#
# Running evaluation: 7it [00:00, 113.68it/s]
#
# Running evaluation: 7it [00:00, 113.46it/s]
#
# Running evaluation: 7it [00:00, 113.41it/s]
#
# Running evaluation: 7it [00:00, 113.69it/s]
#
# Running evaluation: 7it [00:00, 114.07it/s]
#
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 112.46it/s]
#
# Running evaluation: 7it [00:00, 112.14it/s]
#
# Running evaluation: 7it [00:00, 112.87it/s]
#
# Running evaluation: 7it [00:00, 112.67it/s]
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 112.71it/s]
#
# Running evaluation: 7it [00:00, 112.59it/s]
#
# Running evaluation: 7it [00:00, 112.40it/s]
#
# Running evaluation: 7it [00:00, 112.71it/s]
#
# Running evaluation: 7it [00:00, 112.43it/s]
#
# Running evaluation: 7it [00:00, 112.55it/s]
#
# Running evaluation: 7it [00:00, 112.63it/s]
#
# Running evaluation: 7it [00:00, 112.49it/s]
#
# Running evaluation: 7it [00:00, 112.90it/s]
#
# Running evaluation: 7it [00:00, 111.75it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 112.26it/s]
#
# Running evaluation: 7it [00:00, 112.40it/s]
#
# Running evaluation: 7it [00:00, 113.25it/s]
#
# Running evaluation: 7it [00:00, 113.65it/s]
#
# Running evaluation: 7it [00:00, 112.08it/s]
#
# Running evaluation: 7it [00:00, 112.88it/s]
#
# Running evaluation: 7it [00:00, 112.78it/s]
#
# Running evaluation: 7it [00:00, 113.91it/s]
#
# Running evaluation: 7it [00:00, 113.39it/s]
#
# Running evaluation: 7it [00:00, 113.40it/s]
#
# Running evaluation: 7it [00:00, 113.41it/s]
#
# Running evaluation: 7it [00:00, 84.02it/s]

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.021945012376732333
# CRPS: 0.05130171125913943
# QL50: 0.06654023500199412
# QL90: 0.03268838021217765
# MSIS: 7.69540990042319
# NRMSE: 0.5157309131702883
# sMAPE: 0.11442386569524787
# MASE: 0.8970123403935949

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
# Out:
# [rank: 0] Received SIGTERM: 15
# [rank: 0] Received SIGTERM: 15
