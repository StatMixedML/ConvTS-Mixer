# %%
from itertools import islice
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

# %%
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from gluonts.torch.distributions import NegativeBinomialOutput
from gluonts.torch.modules.loss import NegativeLogLikelihood

from TSMixer import TSMixerEstimator
# Out:
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\gluonts\json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
dataset = get_dataset("solar-energy", regenerate=False)

# %%
estimator = TSMixerEstimator(
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length,
    freq=dataset.metadata.freq,
    scaling="std",

    # hidden_size=64,
    K=4,
    
    batch_size=128,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="gpu",
                        max_epochs=50)
)

# %%
predictor = estimator.train(
    training_data=dataset.train, 
    cache_data=True, 
    shuffle_buffer_length=1024, 
    validation_data=dataset.test
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type         | Params
# ---------------------------------------
# 0 | model | TSMixerModel | 3.0 K
# ---------------------------------------
# 3.0 K     Trainable params
# 0         Non-trainable params
# 3.0 K     Total params
# 0.012     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'val_loss' reached 4.80171 (best 4.80171), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 1, global step 200: 'val_loss' reached 4.65634 (best 4.65634), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=1-step=200.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 2, global step 300: 'val_loss' reached 4.42455 (best 4.42455), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=2-step=300.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 3, global step 400: 'val_loss' reached 3.98851 (best 3.98851), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=3-step=400.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 4, global step 500: 'val_loss' reached 3.69733 (best 3.69733), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=4-step=500.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 5, global step 600: 'val_loss' reached 3.64127 (best 3.64127), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=5-step=600.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 6, global step 700: 'val_loss' reached 3.58448 (best 3.58448), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=6-step=700.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 7, global step 800: 'val_loss' reached 3.54777 (best 3.54777), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=7-step=800.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 8, global step 900: 'val_loss' reached 3.50441 (best 3.50441), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=8-step=900.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 9, global step 1000: 'val_loss' reached 3.48037 (best 3.48037), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=9-step=1000.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 10, global step 1100: 'val_loss' reached 3.45662 (best 3.45662), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=10-step=1100.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 11, global step 1200: 'val_loss' reached 3.41903 (best 3.41903), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=11-step=1200.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 12, global step 1300: 'val_loss' reached 3.40178 (best 3.40178), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=12-step=1300.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 13, global step 1400: 'val_loss' reached 3.39638 (best 3.39638), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=13-step=1400.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 14, global step 1500: 'val_loss' reached 3.37344 (best 3.37344), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=14-step=1500.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 15, global step 1600: 'val_loss' reached 3.34156 (best 3.34156), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=15-step=1600.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 16, global step 1700: 'val_loss' reached 3.32728 (best 3.32728), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=16-step=1700.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 17, global step 1800: 'val_loss' reached 3.31267 (best 3.31267), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=17-step=1800.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 18, global step 1900: 'val_loss' reached 3.29746 (best 3.29746), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=18-step=1900.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 19, global step 2000: 'val_loss' reached 3.28314 (best 3.28314), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=19-step=2000.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 20, global step 2100: 'val_loss' reached 3.26817 (best 3.26817), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=20-step=2100.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 21, global step 2200: 'val_loss' reached 3.24946 (best 3.24946), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=21-step=2200.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 22, global step 2300: 'val_loss' reached 3.23606 (best 3.23606), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=22-step=2300.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 23, global step 2400: 'val_loss' reached 3.23506 (best 3.23506), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=23-step=2400.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 24, global step 2500: 'val_loss' reached 3.20757 (best 3.20757), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=24-step=2500.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 25, global step 2600: 'val_loss' reached 3.19544 (best 3.19544), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=25-step=2600.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 26, global step 2700: 'val_loss' reached 3.18692 (best 3.18692), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=26-step=2700.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 27, global step 2800: 'val_loss' reached 3.16004 (best 3.16004), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=27-step=2800.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 28, global step 2900: 'val_loss' reached 3.14322 (best 3.14322), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=28-step=2900.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 29, global step 3000: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 30, global step 3100: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 31, global step 3200: 'val_loss' reached 3.08289 (best 3.08289), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=31-step=3200.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 32, global step 3300: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 33, global step 3400: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 34, global step 3500: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 35, global step 3600: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 36, global step 3700: 'val_loss' reached 3.02147 (best 3.02147), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_14\\checkpoints\\epoch=36-step=3700.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 37, global step 3800: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 38, global step 3900: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 39, global step 4000: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 40, global step 4100: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 41, global step 4200: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 42, global step 4300: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 43, global step 4400: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 44, global step 4500: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 45, global step 4600: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 46, global step 4700: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 47, global step 4800: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 48, global step 4900: 'val_loss' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 49, global step 5000: 'val_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,
    predictor=predictor,
)

# %%
forecasts = list(forecast_it)

# %%
tss = list(ts_it)

# %%
evaluator = Evaluator()

# %%
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 959it [00:40, 23.76it/s]

# %%
agg_metrics
# Out:
# {'MSE': 1189.9435908894675,
#  'abs_error': 371402.82251930237,
#  'abs_target_sum': 708873.5020904541,
#  'abs_target_mean': 30.799161543728452,
#  'seasonal_error': 13.175128459742648,
#  'MASE': 1.2301554795399638,
#  'MAPE': 2.104335520506581,
#  'sMAPE': 1.3985082913406368,
#  'MSIS': 15.63897351955425,
#  'QuantileLoss[0.1]': 207067.7321448326,
#  'Coverage[0.1]': 0.07177615571776155,
#  'QuantileLoss[0.2]': 281843.1813133613,
#  'Coverage[0.2]': 0.1960809871393813,
#  'QuantileLoss[0.3]': 322061.13251562865,
#  'Coverage[0.3]': 0.4392161974278763,
#  'QuantileLoss[0.4]': 353717.45603585243,
#  'Coverage[0.4]': 0.5845498783454987,
#  'QuantileLoss[0.5]': 371402.8215525672,
#  'Coverage[0.5]': 0.7041623218630517,
#  'QuantileLoss[0.6]': 366930.06458915176,
#  'Coverage[0.6]': 0.7700729927007299,
#  'QuantileLoss[0.7]': 338669.3871361017,
#  'Coverage[0.7]': 0.8195603058741744,
#  'QuantileLoss[0.8]': 305288.36080946325,
#  'Coverage[0.8]': 0.8757820646506778,
#  'QuantileLoss[0.9]': 240773.95249704717,
#  'Coverage[0.9]': 0.9227493917274939,
#  'RMSE': 34.49555900242041,
#  'NRMSE': 1.1200161716559665,
#  'ND': 0.5239338491621462,
#  'wQuantileLoss[0.1]': 0.29210815686323993,
#  'wQuantileLoss[0.2]': 0.3975930550122289,
#  'wQuantileLoss[0.3]': 0.4543280734374704,
#  'wQuantileLoss[0.4]': 0.4989852984950722,
#  'wQuantileLoss[0.5]': 0.5239338477983837,
#  'wQuantileLoss[0.6]': 0.5176241790772009,
#  'wQuantileLoss[0.7]': 0.47775715432636756,
#  'wQuantileLoss[0.8]': 0.43066691011749464,
#  'wQuantileLoss[0.9]': 0.3396571486831,
#  'mean_absolute_QuantileLoss': 309750.45428822294,
#  'mean_wQuantileLoss': 0.43696153597895093,
#  'MAE_Coverage': 0.4227493917274939,
#  'OWA': nan}

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * dataset.metadata.prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()
