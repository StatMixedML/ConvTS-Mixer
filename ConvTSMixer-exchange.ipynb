# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

# from pts.modules import StudentTOutput

from ConvTSMixer import ConvTSMixerEstimator

# %%
dataset = get_dataset("exchange_rate_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = ConvTSMixerEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=3,
    patch_size=(4, 4),
    kernel_size=4,
    patch_reverse_mapping_layer="mlp",
    dim=32,
    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda", max_epochs=100),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | ConvTSMixerModel | 9.5 K
# -------------------------------------------
# 9.5 K     Trainable params
# 0         Non-trainable params
# 9.5 K     Total params
# 0.038     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\torch\nn\modules\conv.py:459: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\Convolution.cpp:1004.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0, global step 100: 'train_loss' reached -2.60426 (best -2.60426), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -3.05785 (best -3.05785), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -3.31931 (best -3.31931), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -3.45079 (best -3.45079), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -3.50324 (best -3.50324), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -3.51741 (best -3.51741), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -3.56908 (best -3.56908), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -3.59550 (best -3.59550), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -3.60897 (best -3.60897), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -3.61104 (best -3.61104), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -3.63976 (best -3.63976), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -3.66648 (best -3.66648), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' was not in top 1
# Epoch 13, global step 1400: 'train_loss' reached -3.68822 (best -3.68822), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached -3.70720 (best -3.70720), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' was not in top 1
# Epoch 16, global step 1700: 'train_loss' reached -3.71563 (best -3.71563), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' reached -3.71809 (best -3.71809), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.72175 (best -3.72175), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached -3.72917 (best -3.72917), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' reached -3.74067 (best -3.74067), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' reached -3.74608 (best -3.74608), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' reached -3.74966 (best -3.74966), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=22-step=2300.ckpt' as top 1
# Epoch 23, global step 2400: 'train_loss' was not in top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.76537 (best -3.76537), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' was not in top 1
# Epoch 26, global step 2700: 'train_loss' reached -3.78004 (best -3.78004), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=26-step=2700.ckpt' as top 1
# Epoch 27, global step 2800: 'train_loss' was not in top 1
# Epoch 28, global step 2900: 'train_loss' was not in top 1
# Epoch 29, global step 3000: 'train_loss' was not in top 1
# Epoch 30, global step 3100: 'train_loss' reached -3.79356 (best -3.79356), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=30-step=3100.ckpt' as top 1
# Epoch 31, global step 3200: 'train_loss' reached -3.79869 (best -3.79869), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=31-step=3200.ckpt' as top 1
# Epoch 32, global step 3300: 'train_loss' was not in top 1
# Epoch 33, global step 3400: 'train_loss' was not in top 1
# Epoch 34, global step 3500: 'train_loss' was not in top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.79949 (best -3.79949), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' reached -3.81162 (best -3.81162), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=36-step=3700.ckpt' as top 1
# Epoch 37, global step 3800: 'train_loss' was not in top 1
# Epoch 38, global step 3900: 'train_loss' reached -3.81239 (best -3.81239), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=38-step=3900.ckpt' as top 1
# Epoch 39, global step 4000: 'train_loss' reached -3.81960 (best -3.81960), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=39-step=4000.ckpt' as top 1
# Epoch 40, global step 4100: 'train_loss' was not in top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' was not in top 1
# Epoch 43, global step 4400: 'train_loss' was not in top 1
# Epoch 44, global step 4500: 'train_loss' reached -3.82330 (best -3.82330), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=44-step=4500.ckpt' as top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' reached -3.83104 (best -3.83104), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=47-step=4800.ckpt' as top 1
# Epoch 48, global step 4900: 'train_loss' was not in top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' reached -3.83271 (best -3.83271), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=50-step=5100.ckpt' as top 1
# Epoch 51, global step 5200: 'train_loss' reached -3.83631 (best -3.83631), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=51-step=5200.ckpt' as top 1
# Epoch 52, global step 5300: 'train_loss' reached -3.85059 (best -3.85059), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=52-step=5300.ckpt' as top 1
# Epoch 53, global step 5400: 'train_loss' was not in top 1
# Epoch 54, global step 5500: 'train_loss' reached -3.85329 (best -3.85329), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=54-step=5500.ckpt' as top 1
# Epoch 55, global step 5600: 'train_loss' was not in top 1
# Epoch 56, global step 5700: 'train_loss' was not in top 1
# Epoch 57, global step 5800: 'train_loss' was not in top 1
# Epoch 58, global step 5900: 'train_loss' reached -3.85350 (best -3.85350), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=58-step=5900.ckpt' as top 1
# Epoch 59, global step 6000: 'train_loss' was not in top 1
# Epoch 60, global step 6100: 'train_loss' was not in top 1
# Epoch 61, global step 6200: 'train_loss' was not in top 1
# Epoch 62, global step 6300: 'train_loss' reached -3.85832 (best -3.85832), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=62-step=6300.ckpt' as top 1
# Epoch 63, global step 6400: 'train_loss' reached -3.86720 (best -3.86720), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=63-step=6400.ckpt' as top 1
# Epoch 64, global step 6500: 'train_loss' was not in top 1
# Epoch 65, global step 6600: 'train_loss' was not in top 1
# Epoch 66, global step 6700: 'train_loss' was not in top 1
# Epoch 67, global step 6800: 'train_loss' was not in top 1
# Epoch 68, global step 6900: 'train_loss' was not in top 1
# Epoch 69, global step 7000: 'train_loss' was not in top 1
# Epoch 70, global step 7100: 'train_loss' was not in top 1
# Epoch 71, global step 7200: 'train_loss' was not in top 1
# Epoch 72, global step 7300: 'train_loss' was not in top 1
# Epoch 73, global step 7400: 'train_loss' reached -3.87265 (best -3.87265), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=73-step=7400.ckpt' as top 1
# Epoch 74, global step 7500: 'train_loss' was not in top 1
# Epoch 75, global step 7600: 'train_loss' was not in top 1
# Epoch 76, global step 7700: 'train_loss' was not in top 1
# Epoch 77, global step 7800: 'train_loss' was not in top 1
# Epoch 78, global step 7900: 'train_loss' reached -3.87988 (best -3.87988), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=78-step=7900.ckpt' as top 1
# Epoch 79, global step 8000: 'train_loss' was not in top 1
# Epoch 80, global step 8100: 'train_loss' was not in top 1
# Epoch 81, global step 8200: 'train_loss' reached -3.88146 (best -3.88146), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=81-step=8200.ckpt' as top 1
# Epoch 82, global step 8300: 'train_loss' was not in top 1
# Epoch 83, global step 8400: 'train_loss' was not in top 1
# Epoch 84, global step 8500: 'train_loss' reached -3.88176 (best -3.88176), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=84-step=8500.ckpt' as top 1
# Epoch 85, global step 8600: 'train_loss' reached -3.88191 (best -3.88191), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=85-step=8600.ckpt' as top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' reached -3.88199 (best -3.88199), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=87-step=8800.ckpt' as top 1
# Epoch 88, global step 8900: 'train_loss' was not in top 1
# Epoch 89, global step 9000: 'train_loss' reached -3.88263 (best -3.88263), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=89-step=9000.ckpt' as top 1
# Epoch 90, global step 9100: 'train_loss' was not in top 1
# Epoch 91, global step 9200: 'train_loss' reached -3.88446 (best -3.88446), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=91-step=9200.ckpt' as top 1
# Epoch 92, global step 9300: 'train_loss' was not in top 1
# Epoch 93, global step 9400: 'train_loss' reached -3.88485 (best -3.88485), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=93-step=9400.ckpt' as top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' reached -3.89316 (best -3.89316), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=95-step=9600.ckpt' as top 1
# Epoch 96, global step 9700: 'train_loss' was not in top 1
# Epoch 97, global step 9800: 'train_loss' was not in top 1
# Epoch 98, global step 9900: 'train_loss' reached -3.89691 (best -3.89691), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_10\\checkpoints\\epoch=98-step=9900.ckpt' as top 1
# Epoch 99, global step 10000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 5it [00:00, 54.19it/s]
# Running evaluation: 5it [00:00, 71.35it/s]
# Running evaluation: 5it [00:00, 56.62it/s]
# Running evaluation: 5it [00:00, 62.67it/s]
# Running evaluation: 5it [00:00, 60.63it/s]
# Running evaluation: 5it [00:00, 50.13it/s]
# Running evaluation: 5it [00:00, 60.40it/s]
# Running evaluation: 5it [00:00, 56.97it/s]
# Running evaluation: 5it [00:00, 43.98it/s]

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.009489051497405952
# CRPS: 0.011065841531660552
# QL50: 0.014138413601563172
# QL90: 0.005788281738034123
# MSIS: 19.37581054325475
# NRMSE: 0.026277380608687638
# sMAPE: 0.019998216754756867
# MASE: 2.5701222825816425

# %%
# print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
# print("ND-Sum: {}".format(agg_metric["m_sum_ND"]))
# print("NRMSE-Sum: {}".format(agg_metric["m_sum_NRMSE"]))
# print("MSE-Sum: {}".format(agg_metric["m_sum_MSE"]))

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
