# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.model.transformer import TransformerEstimator
from pts.dataset.repository.datasets import dataset_recipes
from pts.modules import StudentTOutput
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ## Prepeare data set

# %%
dataset = get_dataset("solar_nips", regenerate=False)

# %%
dataset.metadata
# Out:
# MetaData(freq='H', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='137')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=24)

# %%
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %% [markdown]
# ## Evaluator

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %% [markdown]
# ## `Transformer`

# %%
estimator = TransformerEstimator(
    distr_output=StudentTOutput(
        dim=int(dataset.metadata.feat_static_cat[0].cardinality)
    ),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    lags_seq=[1, 24 * 7],
    d_model=128,
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length,
    freq=dataset.metadata.freq,
    scaling="std",
    trainer_kwargs=dict(max_epochs=50, accelerator="gpu", devices="1"),
)

# %%
predictor = estimator.train(dataset_train, cache_data=True)
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params | In sizes | Out sizes
# --------------------------------------------------------------------------
# 0 | model | TransformerModel | 666 K  | ?        | [1, 100, 24, 137]
# --------------------------------------------------------------------------
# 660 K     Trainable params
# 6.1 K     Non-trainable params
# 666 K     Total params
# 2.668     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 620.20752 (best 620.20752), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 550.29047 (best 550.29047), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 533.20862 (best 533.20862), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 517.55536 (best 517.55536), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 505.48553 (best 505.48553), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 498.46634 (best 498.46634), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 492.24539 (best 492.24539), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 487.58087 (best 487.58087), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 481.28137 (best 481.28137), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 478.08212 (best 478.08212), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 474.65750 (best 474.65750), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached 471.26089 (best 471.26089), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 468.94797 (best 468.94797), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached 466.53253 (best 466.53253), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached 463.06714 (best 463.06714), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' reached 462.21970 (best 462.21970), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' reached 459.86871 (best 459.86871), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' reached 458.21262 (best 458.21262), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached 457.85992 (best 457.85992), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached 454.93457 (best 454.93457), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' reached 450.96567 (best 450.96567), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=20-step=1050.ckpt' as top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' reached 448.94974 (best 448.94974), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=23-step=1200.ckpt' as top 1
# Epoch 24, global step 1250: 'train_loss' reached 447.63474 (best 447.63474), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' reached 445.13300 (best 445.13300), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=25-step=1300.ckpt' as top 1
# Epoch 26, global step 1350: 'train_loss' reached 444.34866 (best 444.34866), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=26-step=1350.ckpt' as top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' was not in top 1
# Epoch 29, global step 1500: 'train_loss' reached 442.75586 (best 442.75586), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' reached 441.21234 (best 441.21234), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=30-step=1550.ckpt' as top 1
# Epoch 31, global step 1600: 'train_loss' reached 439.67581 (best 439.67581), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=31-step=1600.ckpt' as top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' reached 438.82281 (best 438.82281), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=33-step=1700.ckpt' as top 1
# Epoch 34, global step 1750: 'train_loss' reached 438.12149 (best 438.12149), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=34-step=1750.ckpt' as top 1
# Epoch 35, global step 1800: 'train_loss' reached 435.66565 (best 435.66565), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' reached 434.17499 (best 434.17499), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=36-step=1850.ckpt' as top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' reached 433.37970 (best 433.37970), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=38-step=1950.ckpt' as top 1
# Epoch 39, global step 2000: 'train_loss' reached 429.78113 (best 429.78113), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' reached 426.96243 (best 426.96243), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=43-step=2200.ckpt' as top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached 426.13882 (best 426.13882), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' reached 425.69141 (best 425.69141), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=48-step=2450.ckpt' as top 1
# Epoch 49, global step 2500: 'train_loss' reached 421.51886 (best 421.51886), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_138/checkpoints/epoch=49-step=2500.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 112.20it/s]
# Running evaluation: 7it [00:00, 113.56it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 112.03it/s]
# Running evaluation: 7it [00:00, 112.97it/s]
# Running evaluation: 7it [00:00, 112.47it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 111.67it/s]
# Running evaluation: 7it [00:00, 109.68it/s]
# Running evaluation: 7it [00:00, 109.64it/s]
# Running evaluation: 7it [00:00, 112.12it/s]
# Running evaluation: 7it [00:00, 113.00it/s]
# Running evaluation: 7it [00:00, 112.24it/s]
# Running evaluation: 7it [00:00, 111.70it/s]
# Running evaluation: 7it [00:00, 111.83it/s]
# Running evaluation: 7it [00:00, 113.33it/s]
# Running evaluation: 7it [00:00, 111.72it/s]
# Running evaluation: 7it [00:00, 112.23it/s]
# Running evaluation: 7it [00:00, 111.51it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.33it/s]
# Running evaluation: 7it [00:00, 111.93it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.05it/s]
# Running evaluation: 7it [00:00, 111.60it/s]
# Running evaluation: 7it [00:00, 111.72it/s]
# Running evaluation: 7it [00:00, 112.76it/s]
# Running evaluation: 7it [00:00, 112.30it/s]
# Running evaluation: 7it [00:00, 112.12it/s]
# Running evaluation: 7it [00:00, 113.34it/s]
# Running evaluation: 7it [00:00, 113.79it/s]
# Running evaluation: 7it [00:00, 114.17it/s]
# Running evaluation: 7it [00:00, 113.33it/s]
# Running evaluation: 7it [00:00, 113.36it/s]
# Running evaluation: 7it [00:00, 113.05it/s]
# Running evaluation: 7it [00:00, 113.33it/s]
# Running evaluation: 7it [00:00, 113.72it/s]
# Running evaluation: 7it [00:00, 111.91it/s]
# Running evaluation: 7it [00:00, 108.49it/s]
# Running evaluation: 7it [00:00, 112.75it/s]
# Running evaluation: 7it [00:00, 113.52it/s]
# Running evaluation: 7it [00:00, 113.25it/s]
# Running evaluation: 7it [00:00, 112.92it/s]
# Running evaluation: 7it [00:00, 113.58it/s]
# Running evaluation: 7it [00:00, 113.21it/s]
# Running evaluation: 7it [00:00, 109.82it/s]
# Running evaluation: 7it [00:00, 109.13it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 112.86it/s]
# Running evaluation: 7it [00:00, 113.82it/s]
# Running evaluation: 7it [00:00, 112.97it/s]
# Running evaluation: 7it [00:00, 113.73it/s]
# Running evaluation: 7it [00:00, 113.36it/s]
# Running evaluation: 7it [00:00, 113.70it/s]
# Running evaluation: 7it [00:00, 113.37it/s]
# Running evaluation: 7it [00:00, 113.43it/s]
# Running evaluation: 7it [00:00, 113.76it/s]
# Running evaluation: 7it [00:00, 114.03it/s]
# Running evaluation: 7it [00:00, 113.47it/s]
# Running evaluation: 7it [00:00, 114.08it/s]
# Running evaluation: 7it [00:00, 113.91it/s]
# Running evaluation: 7it [00:00, 113.76it/s]
# Running evaluation: 7it [00:00, 114.01it/s]
# Running evaluation: 7it [00:00, 113.31it/s]
# Running evaluation: 7it [00:00, 113.86it/s]
# Running evaluation: 7it [00:00, 113.61it/s]
# Running evaluation: 7it [00:00, 113.39it/s]
# Running evaluation: 7it [00:00, 113.66it/s]
# Running evaluation: 7it [00:00, 113.71it/s]
# Running evaluation: 7it [00:00, 113.96it/s]
# Running evaluation: 7it [00:00, 113.65it/s]
# Running evaluation: 7it [00:00, 113.66it/s]
# Running evaluation: 7it [00:00, 113.59it/s]
# Running evaluation: 7it [00:00, 21.09it/s]
# Running evaluation: 7it [00:00, 114.13it/s]
# Running evaluation: 7it [00:00, 114.40it/s]
# Running evaluation: 7it [00:00, 113.52it/s]
# Running evaluation: 7it [00:00, 113.93it/s]
# Running evaluation: 7it [00:00, 114.00it/s]
# Running evaluation: 7it [00:00, 111.54it/s]
# Running evaluation: 7it [00:00, 85.36it/s]
# Running evaluation: 7it [00:00, 114.30it/s]
# Running evaluation: 7it [00:00, 114.60it/s]
# Running evaluation: 7it [00:00, 113.59it/s]
# Running evaluation: 7it [00:00, 113.34it/s]
# Running evaluation: 7it [00:00, 114.27it/s]
# Running evaluation: 7it [00:00, 114.22it/s]
# Running evaluation: 7it [00:00, 113.83it/s]
# Running evaluation: 7it [00:00, 113.98it/s]
# Running evaluation: 7it [00:00, 113.55it/s]
# Running evaluation: 7it [00:00, 114.00it/s]
# Running evaluation: 7it [00:00, 113.69it/s]
# Running evaluation: 7it [00:00, 113.38it/s]
# Running evaluation: 7it [00:00, 113.17it/s]
# Running evaluation: 7it [00:00, 113.20it/s]
# Running evaluation: 7it [00:00, 113.02it/s]
# Running evaluation: 7it [00:00, 113.44it/s]
# Running evaluation: 7it [00:00, 113.04it/s]
# Running evaluation: 7it [00:00, 113.88it/s]
# Running evaluation: 7it [00:00, 113.36it/s]
# Running evaluation: 7it [00:00, 113.80it/s]
# Running evaluation: 7it [00:00, 114.10it/s]
# Running evaluation: 7it [00:00, 113.82it/s]
# Running evaluation: 7it [00:00, 113.73it/s]
# Running evaluation: 7it [00:00, 113.79it/s]
# Running evaluation: 7it [00:00, 113.82it/s]
# Running evaluation: 7it [00:00, 113.66it/s]
# Running evaluation: 7it [00:00, 114.20it/s]
# Running evaluation: 7it [00:00, 113.60it/s]
# Running evaluation: 7it [00:00, 114.23it/s]
# Running evaluation: 7it [00:00, 114.33it/s]
# Running evaluation: 7it [00:00, 113.88it/s]
# Running evaluation: 7it [00:00, 113.78it/s]
# Running evaluation: 7it [00:00, 113.69it/s]
# Running evaluation: 7it [00:00, 113.88it/s]
# Running evaluation: 7it [00:00, 114.01it/s]
# Running evaluation: 7it [00:00, 113.54it/s]
# Running evaluation: 7it [00:00, 113.34it/s]
# Running evaluation: 7it [00:00, 113.25it/s]
# Running evaluation: 7it [00:00, 113.50it/s]
# Running evaluation: 7it [00:00, 114.51it/s]
# Running evaluation: 7it [00:00, 113.87it/s]
# Running evaluation: 7it [00:00, 114.67it/s]
# Running evaluation: 7it [00:00, 114.21it/s]
# Running evaluation: 7it [00:00, 113.25it/s]
# Running evaluation: 7it [00:00, 113.54it/s]
# Running evaluation: 7it [00:00, 113.60it/s]
# Running evaluation: 7it [00:00, 113.77it/s]
# Running evaluation: 7it [00:00, 113.27it/s]
# Running evaluation: 7it [00:00, 113.58it/s]
# Running evaluation: 7it [00:00, 113.72it/s]
# Running evaluation: 7it [00:00, 113.77it/s]
# Running evaluation: 7it [00:00, 113.46it/s]
# Running evaluation: 7it [00:00, 113.68it/s]
# Running evaluation: 7it [00:00, 113.60it/s]
# Running evaluation: 7it [00:00, 113.64it/s]
# Running evaluation: 7it [00:00, 113.44it/s]
# Running evaluation: 7it [00:00, 89.02it/s]

# %% [markdown]
# ### Metrics

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.4233114413205175
# CRPS: 0.4441736249664146
# QL50: 0.5462133936858968
# QL90: 0.2878658137063482
# MSIS: 14.086790447412383
# NRMSE: 1.0706958629346386
# sMAPE: 1.4005839587666733
# MASE: 1.2894096117618956

# %%
# print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
# print("ND-Sum: {}".format(agg_metric["m_sum_ND"]))
# print("NRMSE-Sum: {}".format(agg_metric["m_sum_NRMSE"]))
# print("MSE-Sum: {}".format(agg_metric["m_sum_MSE"]))

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
