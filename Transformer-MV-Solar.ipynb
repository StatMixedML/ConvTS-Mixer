# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.model.transformer import TransformerEstimator
from pts.dataset.repository.datasets import dataset_recipes
from pts.modules import StudentTOutput
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ## Prepeare data set

# %%
dataset = get_dataset("solar_nips", regenerate=False)

# %%
dataset.metadata
# Out:
# MetaData(freq='H', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='137')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=24)

# %%
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %% [markdown]
# ## Evaluator

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %% [markdown]
# ## `Transformer`

# %%
estimator = TransformerEstimator(
    distr_output=StudentTOutput(
        dim=int(dataset.metadata.feat_static_cat[0].cardinality)
    ),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    lags_seq=[1],
    d_model=128,
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*3,
    freq=dataset.metadata.freq,
    scaling="std",
    trainer_kwargs=dict(max_epochs=100, accelerator="gpu", devices="1"),
)

# %%
predictor = estimator.train(dataset_train, cache_data=True)
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params | In sizes | Out sizes
# --------------------------------------------------------------------------
# 0 | model | TransformerModel | 637 K  | ?        | [1, 100, 24, 137]
# --------------------------------------------------------------------------
# 625 K     Trainable params
# 12.3 K    Non-trainable params
# 637 K     Total params
# 2.552     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 638.88574 (best 638.88574), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 560.43073 (best 560.43073), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 539.28534 (best 539.28534), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 526.16217 (best 526.16217), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 516.31036 (best 516.31036), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 509.24042 (best 509.24042), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 503.92282 (best 503.92282), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 496.77765 (best 496.77765), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' was not in top 1
# Epoch 9, global step 500: 'train_loss' reached 496.75101 (best 496.75101), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 488.85645 (best 488.85645), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached 488.40030 (best 488.40030), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 480.53168 (best 480.53168), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached 479.24203 (best 479.24203), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached 476.47275 (best 476.47275), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' reached 473.73438 (best 473.73438), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' reached 469.59039 (best 469.59039), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached 467.73813 (best 467.73813), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached 466.20062 (best 466.20062), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' reached 464.90955 (best 464.90955), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=20-step=1050.ckpt' as top 1
# Epoch 21, global step 1100: 'train_loss' reached 457.74344 (best 457.74344), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=21-step=1100.ckpt' as top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached 456.76404 (best 456.76404), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' reached 455.70108 (best 455.70108), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=25-step=1300.ckpt' as top 1
# Epoch 26, global step 1350: 'train_loss' reached 453.21481 (best 453.21481), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=26-step=1350.ckpt' as top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' reached 450.47827 (best 450.47827), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' reached 449.96280 (best 449.96280), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' reached 446.92813 (best 446.92813), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=31-step=1600.ckpt' as top 1
# Epoch 32, global step 1650: 'train_loss' reached 441.34552 (best 441.34552), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=32-step=1650.ckpt' as top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' was not in top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' reached 439.11584 (best 439.11584), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=37-step=1900.ckpt' as top 1
# Epoch 38, global step 1950: 'train_loss' reached 438.15594 (best 438.15594), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=38-step=1950.ckpt' as top 1
# Epoch 39, global step 2000: 'train_loss' reached 435.42133 (best 435.42133), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' reached 429.47333 (best 429.47333), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=41-step=2100.ckpt' as top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached 427.83273 (best 427.83273), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' reached 423.89059 (best 423.89059), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=47-step=2400.ckpt' as top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# Epoch 50, global step 2550: 'train_loss' reached 416.65955 (best 416.65955), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=50-step=2550.ckpt' as top 1
# Epoch 51, global step 2600: 'train_loss' was not in top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' was not in top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' reached 412.36145 (best 412.36145), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=56-step=2850.ckpt' as top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' reached 410.51755 (best 410.51755), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=61-step=3100.ckpt' as top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' reached 409.31296 (best 409.31296), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=64-step=3250.ckpt' as top 1
# Epoch 65, global step 3300: 'train_loss' was not in top 1
# Epoch 66, global step 3350: 'train_loss' reached 408.91556 (best 408.91556), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=66-step=3350.ckpt' as top 1
# Epoch 67, global step 3400: 'train_loss' reached 407.58282 (best 407.58282), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=67-step=3400.ckpt' as top 1
# Epoch 68, global step 3450: 'train_loss' reached 405.01187 (best 405.01187), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=68-step=3450.ckpt' as top 1
# Epoch 69, global step 3500: 'train_loss' reached 401.71857 (best 401.71857), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=69-step=3500.ckpt' as top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' reached 400.41913 (best 400.41913), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=72-step=3650.ckpt' as top 1
# Epoch 73, global step 3700: 'train_loss' reached 397.07132 (best 397.07132), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=73-step=3700.ckpt' as top 1
# Epoch 74, global step 3750: 'train_loss' reached 397.01147 (best 397.01147), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=74-step=3750.ckpt' as top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' reached 392.35733 (best 392.35733), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=84-step=4250.ckpt' as top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' reached 390.67065 (best 390.67065), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=87-step=4400.ckpt' as top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' was not in top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' reached 389.88184 (best 389.88184), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=92-step=4650.ckpt' as top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' was not in top 1
# Epoch 96, global step 4850: 'train_loss' reached 388.45129 (best 388.45129), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=96-step=4850.ckpt' as top 1
# Epoch 97, global step 4900: 'train_loss' reached 386.46341 (best 386.46341), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=97-step=4900.ckpt' as top 1
# Epoch 98, global step 4950: 'train_loss' reached 384.09937 (best 384.09937), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_148/checkpoints/epoch=98-step=4950.ckpt' as top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 109.57it/s]
# Running evaluation: 7it [00:00, 112.27it/s]
# Running evaluation: 7it [00:00, 111.13it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.49it/s]
# Running evaluation: 7it [00:00, 112.27it/s]
# Running evaluation: 7it [00:00, 112.55it/s]
# Running evaluation: 7it [00:00, 112.21it/s]
# Running evaluation: 7it [00:00, 113.09it/s]
# Running evaluation: 7it [00:00, 112.42it/s]
# Running evaluation: 7it [00:00, 112.26it/s]
# Running evaluation: 7it [00:00, 112.74it/s]
# Running evaluation: 7it [00:00, 112.99it/s]
# Running evaluation: 7it [00:00, 112.94it/s]
# Running evaluation: 7it [00:00, 112.93it/s]
# Running evaluation: 7it [00:00, 112.99it/s]
# Running evaluation: 7it [00:00, 112.83it/s]
# Running evaluation: 7it [00:00, 113.18it/s]
# Running evaluation: 7it [00:00, 112.34it/s]
# Running evaluation: 7it [00:00, 112.13it/s]
# Running evaluation: 7it [00:00, 112.32it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 112.92it/s]
# Running evaluation: 7it [00:00, 24.38it/s]
# Running evaluation: 7it [00:00, 112.49it/s]
# Running evaluation: 7it [00:00, 112.30it/s]
# Running evaluation: 7it [00:00, 112.25it/s]
# Running evaluation: 7it [00:00, 111.90it/s]
# Running evaluation: 7it [00:00, 110.72it/s]
# Running evaluation: 7it [00:00, 108.62it/s]
# Running evaluation: 7it [00:00, 111.45it/s]
# Running evaluation: 7it [00:00, 111.59it/s]
# Running evaluation: 7it [00:00, 111.86it/s]
# Running evaluation: 7it [00:00, 111.93it/s]
# Running evaluation: 7it [00:00, 112.32it/s]
# Running evaluation: 7it [00:00, 112.50it/s]
# Running evaluation: 7it [00:00, 112.60it/s]
# Running evaluation: 7it [00:00, 112.48it/s]
# Running evaluation: 7it [00:00, 112.45it/s]
# Running evaluation: 7it [00:00, 112.83it/s]
# Running evaluation: 7it [00:00, 111.94it/s]
# Running evaluation: 7it [00:00, 112.54it/s]
# Running evaluation: 7it [00:00, 112.44it/s]
# Running evaluation: 7it [00:00, 111.86it/s]
# Running evaluation: 7it [00:00, 112.54it/s]
# Running evaluation: 7it [00:00, 111.89it/s]
# Running evaluation: 7it [00:00, 112.64it/s]
# Running evaluation: 7it [00:00, 112.65it/s]
# Running evaluation: 7it [00:00, 112.47it/s]
# Running evaluation: 7it [00:00, 112.30it/s]
# Running evaluation: 7it [00:00, 112.56it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.29it/s]
# Running evaluation: 7it [00:00, 112.07it/s]
# Running evaluation: 7it [00:00, 112.29it/s]
# Running evaluation: 7it [00:00, 111.66it/s]
# Running evaluation: 7it [00:00, 112.47it/s]
# Running evaluation: 7it [00:00, 112.21it/s]
# Running evaluation: 7it [00:00, 112.09it/s]
# Running evaluation: 7it [00:00, 112.33it/s]
# Running evaluation: 7it [00:00, 112.06it/s]
# Running evaluation: 7it [00:00, 112.47it/s]
# Running evaluation: 7it [00:00, 112.32it/s]
# Running evaluation: 7it [00:00, 112.41it/s]
# Running evaluation: 7it [00:00, 110.84it/s]
# Running evaluation: 7it [00:00, 112.01it/s]
# Running evaluation: 7it [00:00, 112.32it/s]
# Running evaluation: 7it [00:00, 112.41it/s]
# Running evaluation: 7it [00:00, 112.33it/s]
# Running evaluation: 7it [00:00, 112.96it/s]
# Running evaluation: 7it [00:00, 112.41it/s]
# Running evaluation: 7it [00:00, 112.01it/s]
# Running evaluation: 7it [00:00, 112.77it/s]
# Running evaluation: 7it [00:00, 112.68it/s]
# Running evaluation: 7it [00:00, 112.45it/s]
# Running evaluation: 7it [00:00, 112.75it/s]
# Running evaluation: 7it [00:00, 112.76it/s]
# Running evaluation: 7it [00:00, 112.99it/s]
# Running evaluation: 7it [00:00, 112.75it/s]
# Running evaluation: 7it [00:00, 112.96it/s]
# Running evaluation: 7it [00:00, 112.83it/s]
# Running evaluation: 7it [00:00, 112.49it/s]
# Running evaluation: 7it [00:00, 113.18it/s]
# Running evaluation: 7it [00:00, 112.97it/s]
# Running evaluation: 7it [00:00, 112.69it/s]
# Running evaluation: 7it [00:00, 112.73it/s]
# Running evaluation: 7it [00:00, 112.96it/s]
# Running evaluation: 7it [00:00, 112.47it/s]
# Running evaluation: 7it [00:00, 112.57it/s]
# Running evaluation: 7it [00:00, 112.55it/s]
# Running evaluation: 7it [00:00, 112.81it/s]
# Running evaluation: 7it [00:00, 112.79it/s]
# Running evaluation: 7it [00:00, 113.06it/s]
# Running evaluation: 7it [00:00, 112.50it/s]
# Running evaluation: 7it [00:00, 112.59it/s]
# Running evaluation: 7it [00:00, 112.23it/s]
# Running evaluation: 7it [00:00, 110.51it/s]
# Running evaluation: 7it [00:00, 109.04it/s]
# Running evaluation: 7it [00:00, 112.64it/s]
# Running evaluation: 7it [00:00, 112.17it/s]
# Running evaluation: 7it [00:00, 112.93it/s]
# Running evaluation: 7it [00:00, 112.83it/s]
# Running evaluation: 7it [00:00, 112.82it/s]
# Running evaluation: 7it [00:00, 112.94it/s]
# Running evaluation: 7it [00:00, 112.59it/s]
# Running evaluation: 7it [00:00, 112.97it/s]
# Running evaluation: 7it [00:00, 112.56it/s]
# Running evaluation: 7it [00:00, 112.60it/s]
# Running evaluation: 7it [00:00, 112.93it/s]
# Running evaluation: 7it [00:00, 112.84it/s]
# Running evaluation: 7it [00:00, 112.25it/s]
# Running evaluation: 7it [00:00, 112.75it/s]
# Running evaluation: 7it [00:00, 112.71it/s]
# Running evaluation: 7it [00:00, 112.95it/s]
# Running evaluation: 7it [00:00, 112.90it/s]
# Running evaluation: 7it [00:00, 110.56it/s]
# Running evaluation: 7it [00:00, 111.56it/s]
# Running evaluation: 7it [00:00, 112.12it/s]
# Running evaluation: 7it [00:00, 112.43it/s]
# Running evaluation: 7it [00:00, 111.89it/s]
# Running evaluation: 7it [00:00, 113.01it/s]
# Running evaluation: 7it [00:00, 112.90it/s]
# Running evaluation: 7it [00:00, 112.57it/s]
# Running evaluation: 7it [00:00, 112.86it/s]
# Running evaluation: 7it [00:00, 112.63it/s]
# Running evaluation: 7it [00:00, 112.77it/s]
# Running evaluation: 7it [00:00, 112.96it/s]
# Running evaluation: 7it [00:00, 112.80it/s]
# Running evaluation: 7it [00:00, 113.06it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 113.14it/s]
# Running evaluation: 7it [00:00, 113.01it/s]
# Running evaluation: 7it [00:00, 112.88it/s]
# Running evaluation: 7it [00:00, 113.12it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 113.07it/s]
# Running evaluation: 7it [00:00, 88.37it/s]

# %% [markdown]
# ### Metrics

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.38883454755882874
# CRPS: 0.45023735568985385
# QL50: 0.6240058487375978
# QL90: 0.2660884765035922
# MSIS: 7.521541329291149
# NRMSE: 1.1470926000373396
# sMAPE: 1.4122683011619508
# MASE: 1.4638592570384743

# %%
# print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
# print("ND-Sum: {}".format(agg_metric["m_sum_ND"]))
# print("NRMSE-Sum: {}".format(agg_metric["m_sum_NRMSE"]))
# print("MSE-Sum: {}".format(agg_metric["m_sum_MSE"]))

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
