# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.modules import StudentTOutput

from TsT import TsTEstimator
# Out:
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
dataset = get_dataset("traffic_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = TsTEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=4,
    dim=64,
    patch_size=(3, 20),
    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda"),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/py ...
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/py ...
#   rank_zero_warn(
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
#
#   | Name  | Type     | Params
# -----------------------------------
# 0 | model | TsTModel | 212 K
# -----------------------------------
# 163 K     Trainable params
# 49.2 K    Non-trainable params
# 212 K     Total params
# 0.849     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -2.03859 (best -2.03859), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -2.54320 (best -2.54320), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -2.71031 (best -2.71031), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -2.80253 (best -2.80253), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -2.87003 (best -2.87003), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -2.90965 (best -2.90965), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -2.95490 (best -2.95490), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -2.99603 (best -2.99603), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -3.03828 (best -3.03828), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -3.07677 (best -3.07677), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -3.10822 (best -3.10822), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -3.13046 (best -3.13046), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -3.15215 (best -3.15215), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached -3.18546 (best -3.18546), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached -3.20895 (best -3.20895), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' reached -3.22021 (best -3.22021), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' reached -3.23525 (best -3.23525), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' reached -3.25771 (best -3.25771), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.26116 (best -3.26116), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached -3.28114 (best -3.28114), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' reached -3.28235 (best -3.28235), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' was not in top 1
# Epoch 22, global step 2300: 'train_loss' was not in top 1
# Epoch 23, global step 2400: 'train_loss' reached -3.30788 (best -3.30788), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.32008 (best -3.32008), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' was not in top 1
# Epoch 26, global step 2700: 'train_loss' reached -3.32947 (best -3.32947), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=26-step=2700.ckpt' as top 1
# Epoch 27, global step 2800: 'train_loss' was not in top 1
# Epoch 28, global step 2900: 'train_loss' reached -3.34340 (best -3.34340), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=28-step=2900.ckpt' as top 1
# Epoch 29, global step 3000: 'train_loss' reached -3.34390 (best -3.34390), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=29-step=3000.ckpt' as top 1
# Epoch 30, global step 3100: 'train_loss' reached -3.34761 (best -3.34761), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=30-step=3100.ckpt' as top 1
# Epoch 31, global step 3200: 'train_loss' reached -3.35387 (best -3.35387), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=31-step=3200.ckpt' as top 1
# Epoch 32, global step 3300: 'train_loss' was not in top 1
# Epoch 33, global step 3400: 'train_loss' reached -3.35959 (best -3.35959), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=33-step=3400.ckpt' as top 1
# Epoch 34, global step 3500: 'train_loss' reached -3.36361 (best -3.36361), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=34-step=3500.ckpt' as top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.36392 (best -3.36392), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' reached -3.36599 (best -3.36599), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=36-step=3700.ckpt' as top 1
# Epoch 37, global step 3800: 'train_loss' reached -3.37420 (best -3.37420), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=37-step=3800.ckpt' as top 1
# Epoch 38, global step 3900: 'train_loss' reached -3.37963 (best -3.37963), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=38-step=3900.ckpt' as top 1
# Epoch 39, global step 4000: 'train_loss' reached -3.38600 (best -3.38600), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=39-step=4000.ckpt' as top 1
# Epoch 40, global step 4100: 'train_loss' reached -3.38983 (best -3.38983), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=40-step=4100.ckpt' as top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' reached -3.39214 (best -3.39214), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=42-step=4300.ckpt' as top 1
# Epoch 43, global step 4400: 'train_loss' was not in top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' reached -3.39889 (best -3.39889), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=45-step=4600.ckpt' as top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' reached -3.40810 (best -3.40810), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=47-step=4800.ckpt' as top 1
# Epoch 48, global step 4900: 'train_loss' was not in top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' reached -3.41229 (best -3.41229), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=50-step=5100.ckpt' as top 1
# Epoch 51, global step 5200: 'train_loss' reached -3.41427 (best -3.41427), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=51-step=5200.ckpt' as top 1
# Epoch 52, global step 5300: 'train_loss' was not in top 1
# Epoch 53, global step 5400: 'train_loss' was not in top 1
# Epoch 54, global step 5500: 'train_loss' reached -3.42078 (best -3.42078), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=54-step=5500.ckpt' as top 1
# Epoch 55, global step 5600: 'train_loss' was not in top 1
# Epoch 56, global step 5700: 'train_loss' was not in top 1
# Epoch 57, global step 5800: 'train_loss' reached -3.43199 (best -3.43199), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=57-step=5800.ckpt' as top 1
# Epoch 58, global step 5900: 'train_loss' was not in top 1
# Epoch 59, global step 6000: 'train_loss' was not in top 1
# Epoch 60, global step 6100: 'train_loss' was not in top 1
# Epoch 61, global step 6200: 'train_loss' reached -3.43300 (best -3.43300), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=61-step=6200.ckpt' as top 1
# Epoch 62, global step 6300: 'train_loss' was not in top 1
# Epoch 63, global step 6400: 'train_loss' was not in top 1
# Epoch 64, global step 6500: 'train_loss' was not in top 1
# Epoch 65, global step 6600: 'train_loss' was not in top 1
# Epoch 66, global step 6700: 'train_loss' reached -3.44604 (best -3.44604), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=66-step=6700.ckpt' as top 1
# Epoch 67, global step 6800: 'train_loss' was not in top 1
# Epoch 68, global step 6900: 'train_loss' was not in top 1
# Epoch 69, global step 7000: 'train_loss' was not in top 1
# Epoch 70, global step 7100: 'train_loss' was not in top 1
# Epoch 71, global step 7200: 'train_loss' was not in top 1
# Epoch 72, global step 7300: 'train_loss' was not in top 1
# Epoch 73, global step 7400: 'train_loss' reached -3.44971 (best -3.44971), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=73-step=7400.ckpt' as top 1
# Epoch 74, global step 7500: 'train_loss' reached -3.45370 (best -3.45370), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=74-step=7500.ckpt' as top 1
# Epoch 75, global step 7600: 'train_loss' reached -3.45941 (best -3.45941), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=75-step=7600.ckpt' as top 1
# Epoch 76, global step 7700: 'train_loss' was not in top 1
# Epoch 77, global step 7800: 'train_loss' was not in top 1
# Epoch 78, global step 7900: 'train_loss' was not in top 1
# Epoch 79, global step 8000: 'train_loss' was not in top 1
# Epoch 80, global step 8100: 'train_loss' reached -3.46278 (best -3.46278), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=80-step=8100.ckpt' as top 1
# Epoch 81, global step 8200: 'train_loss' was not in top 1
# Epoch 82, global step 8300: 'train_loss' was not in top 1
# Epoch 83, global step 8400: 'train_loss' was not in top 1
# Epoch 84, global step 8500: 'train_loss' reached -3.46750 (best -3.46750), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=84-step=8500.ckpt' as top 1
# Epoch 85, global step 8600: 'train_loss' was not in top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' reached -3.47210 (best -3.47210), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=87-step=8800.ckpt' as top 1
# Epoch 88, global step 8900: 'train_loss' was not in top 1
# Epoch 89, global step 9000: 'train_loss' reached -3.47646 (best -3.47646), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=89-step=9000.ckpt' as top 1
# Epoch 90, global step 9100: 'train_loss' was not in top 1
# Epoch 91, global step 9200: 'train_loss' was not in top 1
# Epoch 92, global step 9300: 'train_loss' was not in top 1
# Epoch 93, global step 9400: 'train_loss' was not in top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' was not in top 1
# Epoch 96, global step 9700: 'train_loss' reached -3.48336 (best -3.48336), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_5/checkpoints/epoch=96-step=9700.ckpt' as top 1
# Epoch 97, global step 9800: 'train_loss' was not in top 1
# Epoch 98, global step 9900: 'train_loss' was not in top 1
# Epoch 99, global step 10000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 78.12it/s]
# Running evaluation: 7it [00:00, 84.93it/s]
# Running evaluation: 7it [00:00, 85.05it/s]
# Running evaluation: 7it [00:00, 84.58it/s]
# Running evaluation: 7it [00:00, 84.47it/s]
# Running evaluation: 7it [00:00, 82.87it/s]
# Running evaluation: 7it [00:00, 83.87it/s]
# Running evaluation: 7it [00:00, 86.26it/s]
# Running evaluation: 7it [00:00, 86.28it/s]
# Running evaluation: 7it [00:00, 84.55it/s]
# Running evaluation: 7it [00:00, 84.07it/s]
# Running evaluation: 7it [00:00, 84.66it/s]
# Running evaluation: 7it [00:00, 80.73it/s]
# Running evaluation: 7it [00:00, 83.34it/s]
# Running evaluation: 7it [00:00, 85.04it/s]
# Running evaluation: 7it [00:00, 86.58it/s]
# Running evaluation: 7it [00:00, 87.14it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 87.47it/s]
# Running evaluation: 7it [00:00, 85.71it/s]
# Running evaluation: 7it [00:00, 85.38it/s]
# Running evaluation: 7it [00:00, 86.54it/s]
# Running evaluation: 7it [00:00, 87.11it/s]
# Running evaluation: 7it [00:00, 85.88it/s]
# Running evaluation: 7it [00:00, 84.72it/s]
# Running evaluation: 7it [00:00, 86.32it/s]
# Running evaluation: 7it [00:00, 85.80it/s]
# Running evaluation: 7it [00:00, 82.09it/s]
# Running evaluation: 7it [00:00, 84.64it/s]
# Running evaluation: 7it [00:00, 84.89it/s]
# Running evaluation: 7it [00:00, 86.19it/s]
# Running evaluation: 7it [00:00, 82.11it/s]
# Running evaluation: 7it [00:00, 82.65it/s]
# Running evaluation: 7it [00:00, 85.69it/s]
# Running evaluation: 7it [00:00, 85.38it/s]
# Running evaluation: 7it [00:00, 83.77it/s]
# Running evaluation: 7it [00:00, 86.18it/s]
# Running evaluation: 7it [00:00, 86.10it/s]
# Running evaluation: 7it [00:00, 85.31it/s]
# Running evaluation: 7it [00:00, 84.81it/s]
# Running evaluation: 7it [00:00, 86.17it/s]
# Running evaluation: 7it [00:00, 85.17it/s]
# Running evaluation: 7it [00:00, 85.48it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 82.46it/s]
# Running evaluation: 7it [00:00, 82.22it/s]
# Running evaluation: 7it [00:00, 84.90it/s]
# Running evaluation: 7it [00:00, 82.93it/s]
# Running evaluation: 7it [00:00, 80.34it/s]
# Running evaluation: 7it [00:00, 85.16it/s]
# Running evaluation: 7it [00:00, 85.68it/s]
# Running evaluation: 7it [00:00, 80.88it/s]
# Running evaluation: 7it [00:00, 86.46it/s]
# Running evaluation: 7it [00:00, 86.93it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 85.95it/s]
# Running evaluation: 7it [00:00, 84.72it/s]
# Running evaluation: 7it [00:00, 84.88it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 85.76it/s]
# Running evaluation: 7it [00:00, 83.45it/s]
# Running evaluation: 7it [00:00, 85.29it/s]
# Running evaluation: 7it [00:00, 84.89it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 86.95it/s]
# Running evaluation: 7it [00:00, 79.88it/s]
# Running evaluation: 7it [00:00, 85.05it/s]
# Running evaluation: 7it [00:00, 87.48it/s]
# Running evaluation: 7it [00:00, 87.33it/s]
# Running evaluation: 7it [00:00, 86.36it/s]
# Running evaluation: 7it [00:00, 85.64it/s]
# Running evaluation: 7it [00:00, 85.67it/s]
# Running evaluation: 7it [00:00, 83.71it/s]
# Running evaluation: 7it [00:00, 82.64it/s]
# Running evaluation: 7it [00:00, 83.81it/s]
# Running evaluation: 7it [00:00, 85.81it/s]
# Running evaluation: 7it [00:00, 85.35it/s]
# Running evaluation: 7it [00:00, 84.83it/s]
# Running evaluation: 7it [00:00, 82.06it/s]
# Running evaluation: 7it [00:00, 85.41it/s]
# Running evaluation: 7it [00:00, 86.73it/s]
# Running evaluation: 7it [00:00, 84.80it/s]
# Running evaluation: 7it [00:00, 85.12it/s]
# Running evaluation: 7it [00:00, 84.70it/s]
# Running evaluation: 7it [00:00, 86.54it/s]
# Running evaluation: 7it [00:00, 80.77it/s]
# Running evaluation: 7it [00:00, 83.88it/s]
# Running evaluation: 7it [00:00, 85.42it/s]
# Running evaluation: 7it [00:00, 87.12it/s]
# Running evaluation: 7it [00:00, 84.21it/s]
# Running evaluation: 7it [00:00, 85.09it/s]
# Running evaluation: 7it [00:00, 86.26it/s]
# Running evaluation: 7it [00:00, 84.38it/s]
# Running evaluation: 7it [00:00, 85.63it/s]
# Running evaluation: 7it [00:00, 83.90it/s]
# Running evaluation: 7it [00:00, 84.49it/s]
# Running evaluation: 7it [00:00, 83.36it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 85.57it/s]
# Running evaluation: 7it [00:00, 82.59it/s]
# Running evaluation: 7it [00:00, 84.16it/s]
# Running evaluation: 7it [00:00, 83.21it/s]
# Running evaluation: 7it [00:00, 82.60it/s]
# Running evaluation: 7it [00:00, 84.95it/s]
# Running evaluation: 7it [00:00, 84.67it/s]
# Running evaluation: 7it [00:00, 85.25it/s]
# Running evaluation: 7it [00:00, 84.93it/s]
# Running evaluation: 7it [00:00, 84.24it/s]
# Running evaluation: 7it [00:00, 83.31it/s]
# Running evaluation: 7it [00:00, 83.72it/s]
# Running evaluation: 7it [00:00, 83.08it/s]
# Running evaluation: 7it [00:00, 84.11it/s]
# Running evaluation: 7it [00:00, 81.33it/s]
# Running evaluation: 7it [00:00, 83.87it/s]
# Running evaluation: 7it [00:00, 84.19it/s]
# Running evaluation: 7it [00:00, 82.59it/s]
# Running evaluation: 7it [00:00, 79.94it/s]
# Running evaluation: 7it [00:00, 84.28it/s]
# Running evaluation: 7it [00:00, 85.20it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 83.71it/s]
# Running evaluation: 7it [00:00, 86.55it/s]
# Running evaluation: 7it [00:00, 84.95it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 84.15it/s]
# Running evaluation: 7it [00:00, 84.79it/s]
# Running evaluation: 7it [00:00, 83.24it/s]
# Running evaluation: 7it [00:00, 84.87it/s]
# Running evaluation: 7it [00:00, 84.34it/s]
# Running evaluation: 7it [00:00, 85.44it/s]
# Running evaluation: 7it [00:00, 86.57it/s]
# Running evaluation: 7it [00:00, 87.34it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 83.75it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 85.83it/s]
# Running evaluation: 7it [00:00, 84.54it/s]
# Running evaluation: 7it [00:00, 77.50it/s]
# Running evaluation: 7it [00:00, 83.38it/s]
# Running evaluation: 7it [00:00, 84.86it/s]
# Running evaluation: 7it [00:00, 85.87it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 85.49it/s]
# Running evaluation: 7it [00:00, 87.31it/s]
# Running evaluation: 7it [00:00, 86.63it/s]
# Running evaluation: 7it [00:00, 87.25it/s]
# Running evaluation: 7it [00:00, 87.01it/s]
# Running evaluation: 7it [00:00, 85.01it/s]
# Running evaluation: 7it [00:00, 84.82it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 86.34it/s]
# Running evaluation: 7it [00:00, 83.67it/s]
# Running evaluation: 7it [00:00, 86.48it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 88.06it/s]
# Running evaluation: 7it [00:00, 80.18it/s]
# Running evaluation: 7it [00:00, 85.40it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 85.48it/s]
# Running evaluation: 7it [00:00, 85.48it/s]
# Running evaluation: 7it [00:00, 87.27it/s]
# Running evaluation: 7it [00:00, 86.59it/s]
# Running evaluation: 7it [00:00, 86.15it/s]
# Running evaluation: 7it [00:00, 85.13it/s]
# Running evaluation: 7it [00:00, 83.67it/s]
# Running evaluation: 7it [00:00, 84.81it/s]
# Running evaluation: 7it [00:00, 86.86it/s]
# Running evaluation: 7it [00:00, 84.83it/s]
# Running evaluation: 7it [00:00, 86.01it/s]
# Running evaluation: 7it [00:00, 85.34it/s]
# Running evaluation: 7it [00:00, 80.05it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 86.76it/s]
# Running evaluation: 7it [00:00, 83.48it/s]
# Running evaluation: 7it [00:00, 83.27it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 85.99it/s]
# Running evaluation: 7it [00:00, 83.81it/s]
# Running evaluation: 7it [00:00, 84.12it/s]
# Running evaluation: 7it [00:00, 87.30it/s]
# Running evaluation: 7it [00:00, 84.15it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 87.28it/s]
# Running evaluation: 7it [00:00, 82.40it/s]
# Running evaluation: 7it [00:00, 81.98it/s]
# Running evaluation: 7it [00:00, 86.08it/s]
# Running evaluation: 7it [00:00, 85.60it/s]
# Running evaluation: 7it [00:00, 81.03it/s]
# Running evaluation: 7it [00:00, 86.34it/s]
# Running evaluation: 7it [00:00, 86.43it/s]
# Running evaluation: 7it [00:00, 86.61it/s]
# Running evaluation: 7it [00:00, 86.11it/s]
# Running evaluation: 7it [00:00, 86.42it/s]
# Running evaluation: 7it [00:00, 85.73it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 84.95it/s]
# Running evaluation: 7it [00:00, 86.82it/s]
# Running evaluation: 7it [00:00, 85.53it/s]
# Running evaluation: 7it [00:00, 86.83it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 20.70it/s]
# Running evaluation: 7it [00:00, 87.44it/s]
# Running evaluation: 7it [00:00, 85.36it/s]
# Running evaluation: 7it [00:00, 84.24it/s]
# Running evaluation: 7it [00:00, 82.59it/s]
# Running evaluation: 7it [00:00, 87.08it/s]
# Running evaluation: 7it [00:00, 87.21it/s]
# Running evaluation: 7it [00:00, 86.89it/s]
# Running evaluation: 7it [00:00, 86.58it/s]
# Running evaluation: 7it [00:00, 87.45it/s]
# Running evaluation: 7it [00:00, 86.21it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 87.64it/s]
# Running evaluation: 7it [00:00, 86.91it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 87.10it/s]
# Running evaluation: 7it [00:00, 86.18it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 87.25it/s]
# Running evaluation: 7it [00:00, 82.74it/s]
# Running evaluation: 7it [00:00, 86.14it/s]
# Running evaluation: 7it [00:00, 81.11it/s]
# Running evaluation: 7it [00:00, 83.77it/s]
# Running evaluation: 7it [00:00, 86.55it/s]
# Running evaluation: 7it [00:00, 79.25it/s]
# Running evaluation: 7it [00:00, 78.54it/s]
# Running evaluation: 7it [00:00, 85.61it/s]
# Running evaluation: 7it [00:00, 86.71it/s]
# Running evaluation: 7it [00:00, 84.28it/s]
# Running evaluation: 7it [00:00, 84.92it/s]
# Running evaluation: 7it [00:00, 84.05it/s]
# Running evaluation: 7it [00:00, 84.00it/s]
# Running evaluation: 7it [00:00, 83.58it/s]
# Running evaluation: 7it [00:00, 85.39it/s]
# Running evaluation: 7it [00:00, 85.78it/s]
# Running evaluation: 7it [00:00, 86.79it/s]
# Running evaluation: 7it [00:00, 75.24it/s]
# Running evaluation: 7it [00:00, 80.38it/s]
# Running evaluation: 7it [00:00, 86.82it/s]
# Running evaluation: 7it [00:00, 86.68it/s]
# Running evaluation: 7it [00:00, 86.67it/s]
# Running evaluation: 7it [00:00, 85.77it/s]
# Running evaluation: 7it [00:00, 83.33it/s]
# Running evaluation: 7it [00:00, 82.97it/s]
# Running evaluation: 7it [00:00, 85.62it/s]
# Running evaluation: 7it [00:00, 84.48it/s]
# Running evaluation: 7it [00:00, 84.47it/s]
# Running evaluation: 7it [00:00, 79.61it/s]
# Running evaluation: 7it [00:00, 82.86it/s]
# Running evaluation: 7it [00:00, 84.14it/s]
# Running evaluation: 7it [00:00, 81.50it/s]
# Running evaluation: 7it [00:00, 85.25it/s]
# Running evaluation: 7it [00:00, 82.10it/s]
# Running evaluation: 7it [00:00, 81.79it/s]
# Running evaluation: 7it [00:00, 83.71it/s]
# Running evaluation: 7it [00:00, 80.06it/s]
# Running evaluation: 7it [00:00, 82.85it/s]
# Running evaluation: 7it [00:00, 84.39it/s]
# Running evaluation: 7it [00:00, 83.49it/s]
# Running evaluation: 7it [00:00, 83.16it/s]
# Running evaluation: 7it [00:00, 84.97it/s]
# Running evaluation: 7it [00:00, 84.97it/s]
# Running evaluation: 7it [00:00, 82.99it/s]
# Running evaluation: 7it [00:00, 85.15it/s]
# Running evaluation: 7it [00:00, 85.73it/s]
# Running evaluation: 7it [00:00, 84.09it/s]
# Running evaluation: 7it [00:00, 80.69it/s]
# Running evaluation: 7it [00:00, 84.47it/s]
# Running evaluation: 7it [00:00, 84.67it/s]
# Running evaluation: 7it [00:00, 84.26it/s]
# Running evaluation: 7it [00:00, 85.80it/s]
# Running evaluation: 7it [00:00, 86.02it/s]
# Running evaluation: 7it [00:00, 84.20it/s]
# Running evaluation: 7it [00:00, 84.54it/s]
# Running evaluation: 7it [00:00, 86.19it/s]
# Running evaluation: 7it [00:00, 85.78it/s]
# Running evaluation: 7it [00:00, 84.50it/s]
# Running evaluation: 7it [00:00, 83.55it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 83.22it/s]
# Running evaluation: 7it [00:00, 84.81it/s]
# Running evaluation: 7it [00:00, 83.37it/s]
# Running evaluation: 7it [00:00, 84.17it/s]
# Running evaluation: 7it [00:00, 79.64it/s]
# Running evaluation: 7it [00:00, 85.12it/s]
# Running evaluation: 7it [00:00, 84.15it/s]
# Running evaluation: 7it [00:00, 84.73it/s]
# Running evaluation: 7it [00:00, 86.21it/s]
# Running evaluation: 7it [00:00, 81.42it/s]
# Running evaluation: 7it [00:00, 84.97it/s]
# Running evaluation: 7it [00:00, 84.84it/s]
# Running evaluation: 7it [00:00, 85.01it/s]
# Running evaluation: 7it [00:00, 79.74it/s]
# Running evaluation: 7it [00:00, 84.39it/s]
# Running evaluation: 7it [00:00, 84.76it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 83.56it/s]
# Running evaluation: 7it [00:00, 84.83it/s]
# Running evaluation: 7it [00:00, 85.89it/s]
# Running evaluation: 7it [00:00, 84.74it/s]
# Running evaluation: 7it [00:00, 85.53it/s]
# Running evaluation: 7it [00:00, 86.86it/s]
# Running evaluation: 7it [00:00, 70.43it/s]
# Running evaluation: 7it [00:00, 85.44it/s]
# Running evaluation: 7it [00:00, 83.95it/s]
# Running evaluation: 7it [00:00, 84.38it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 84.86it/s]
# Running evaluation: 7it [00:00, 85.85it/s]
# Running evaluation: 7it [00:00, 85.54it/s]
# Running evaluation: 7it [00:00, 85.70it/s]
# Running evaluation: 7it [00:00, 84.29it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 81.24it/s]
# Running evaluation: 7it [00:00, 84.65it/s]
# Running evaluation: 7it [00:00, 83.12it/s]
# Running evaluation: 7it [00:00, 85.45it/s]
# Running evaluation: 7it [00:00, 85.13it/s]
# Running evaluation: 7it [00:00, 85.09it/s]
# Running evaluation: 7it [00:00, 86.47it/s]
# Running evaluation: 7it [00:00, 86.71it/s]
# Running evaluation: 7it [00:00, 84.29it/s]
# Running evaluation: 7it [00:00, 85.74it/s]
# Running evaluation: 7it [00:00, 85.10it/s]
# Running evaluation: 7it [00:00, 83.27it/s]
# Running evaluation: 7it [00:00, 85.78it/s]
# Running evaluation: 7it [00:00, 85.61it/s]
# Running evaluation: 7it [00:00, 82.32it/s]
# Running evaluation: 7it [00:00, 84.67it/s]
# Running evaluation: 7it [00:00, 80.65it/s]
# Running evaluation: 7it [00:00, 84.39it/s]
# Running evaluation: 7it [00:00, 85.97it/s]
# Running evaluation: 7it [00:00, 85.35it/s]
# Running evaluation: 7it [00:00, 86.12it/s]
# Running evaluation: 7it [00:00, 85.69it/s]
# Running evaluation: 7it [00:00, 85.74it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 85.75it/s]
# Running evaluation: 7it [00:00, 85.46it/s]
# Running evaluation: 7it [00:00, 83.89it/s]
# Running evaluation: 7it [00:00, 84.29it/s]
# Running evaluation: 7it [00:00, 86.68it/s]
# Running evaluation: 7it [00:00, 85.64it/s]
# Running evaluation: 7it [00:00, 84.82it/s]
# Running evaluation: 7it [00:00, 84.65it/s]
# Running evaluation: 7it [00:00, 85.18it/s]
# Running evaluation: 7it [00:00, 79.56it/s]
# Running evaluation: 7it [00:00, 85.42it/s]
# Running evaluation: 7it [00:00, 85.93it/s]
# Running evaluation: 7it [00:00, 85.22it/s]
# Running evaluation: 7it [00:00, 81.06it/s]
# Running evaluation: 7it [00:00, 84.40it/s]
# Running evaluation: 7it [00:00, 86.23it/s]
# Running evaluation: 7it [00:00, 85.59it/s]
# Running evaluation: 7it [00:00, 71.88it/s]
# Running evaluation: 7it [00:00, 81.17it/s]
# Running evaluation: 7it [00:00, 83.87it/s]
# Running evaluation: 7it [00:00, 84.93it/s]
# Running evaluation: 7it [00:00, 83.70it/s]
# Running evaluation: 7it [00:00, 82.23it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 84.61it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 85.08it/s]
# Running evaluation: 7it [00:00, 86.25it/s]
# Running evaluation: 7it [00:00, 85.79it/s]
# Running evaluation: 7it [00:00, 85.25it/s]
# Running evaluation: 7it [00:00, 84.97it/s]
# Running evaluation: 7it [00:00, 84.85it/s]
# Running evaluation: 7it [00:00, 85.56it/s]
# Running evaluation: 7it [00:00, 83.64it/s]
# Running evaluation: 7it [00:00, 84.06it/s]
# Running evaluation: 7it [00:00, 84.99it/s]
# Running evaluation: 7it [00:00, 77.57it/s]
# Running evaluation: 7it [00:00, 85.82it/s]
# Running evaluation: 7it [00:00, 84.38it/s]
# Running evaluation: 7it [00:00, 84.21it/s]
# Running evaluation: 7it [00:00, 86.60it/s]
# Running evaluation: 7it [00:00, 84.71it/s]
# Running evaluation: 7it [00:00, 84.48it/s]
# Running evaluation: 7it [00:00, 86.62it/s]
# Running evaluation: 7it [00:00, 73.39it/s]
# Running evaluation: 7it [00:00, 83.31it/s]
# Running evaluation: 7it [00:00, 85.56it/s]
# Running evaluation: 7it [00:00, 87.43it/s]
# Running evaluation: 7it [00:00, 86.53it/s]
# Running evaluation: 7it [00:00, 83.98it/s]
# Running evaluation: 7it [00:00, 84.63it/s]
# Running evaluation: 7it [00:00, 84.79it/s]
# Running evaluation: 7it [00:00, 85.92it/s]
# Running evaluation: 7it [00:00, 84.63it/s]
# Running evaluation: 7it [00:00, 85.87it/s]
# Running evaluation: 7it [00:00, 84.01it/s]
# Running evaluation: 7it [00:00, 85.48it/s]
# Running evaluation: 7it [00:00, 85.63it/s]
# Running evaluation: 7it [00:00, 84.60it/s]
# Running evaluation: 7it [00:00, 86.31it/s]
# Running evaluation: 7it [00:00, 76.69it/s]
# Running evaluation: 7it [00:00, 78.08it/s]
# Running evaluation: 7it [00:00, 84.47it/s]
# Running evaluation: 7it [00:00, 77.58it/s]
# Running evaluation: 7it [00:00, 85.11it/s]
# Running evaluation: 7it [00:00, 85.58it/s]
# Running evaluation: 7it [00:00, 83.32it/s]
# Running evaluation: 7it [00:00, 82.18it/s]
# Running evaluation: 7it [00:00, 84.48it/s]
# Running evaluation: 7it [00:00, 84.46it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 85.69it/s]
# Running evaluation: 7it [00:00, 72.32it/s]
# Running evaluation: 7it [00:00, 73.90it/s]
# Running evaluation: 7it [00:00, 72.95it/s]
# Running evaluation: 7it [00:00, 84.71it/s]
# Running evaluation: 7it [00:00, 85.54it/s]
# Running evaluation: 7it [00:00, 83.64it/s]
# Running evaluation: 7it [00:00, 84.86it/s]
# Running evaluation: 7it [00:00, 84.60it/s]
# Running evaluation: 7it [00:00, 85.41it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 85.93it/s]
# Running evaluation: 7it [00:00, 84.14it/s]
# Running evaluation: 7it [00:00, 82.39it/s]
# Running evaluation: 7it [00:00, 86.15it/s]
# Running evaluation: 7it [00:00, 86.20it/s]
# Running evaluation: 7it [00:00, 84.07it/s]
# Running evaluation: 7it [00:00, 85.49it/s]
# Running evaluation: 7it [00:00, 85.12it/s]
# Running evaluation: 7it [00:00, 84.20it/s]
# Running evaluation: 7it [00:00, 84.81it/s]
# Running evaluation: 7it [00:00, 85.68it/s]
# Running evaluation: 7it [00:00, 85.48it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 75.85it/s]
# Running evaluation: 7it [00:00, 85.25it/s]
# Running evaluation: 7it [00:00, 86.19it/s]
# Running evaluation: 7it [00:00, 85.30it/s]
# Running evaluation: 7it [00:00, 80.61it/s]
# Running evaluation: 7it [00:00, 80.38it/s]
# Running evaluation: 7it [00:00, 84.69it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 84.58it/s]
# Running evaluation: 7it [00:00, 84.44it/s]
# Running evaluation: 7it [00:00, 84.98it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 85.18it/s]
# Running evaluation: 7it [00:00, 85.62it/s]
# Running evaluation: 7it [00:00, 85.53it/s]
# Running evaluation: 7it [00:00, 85.60it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 85.66it/s]
# Running evaluation: 7it [00:00, 85.67it/s]
# Running evaluation: 7it [00:00, 84.77it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 84.66it/s]
# Running evaluation: 7it [00:00, 85.07it/s]
# Running evaluation: 7it [00:00, 15.74it/s]
# Running evaluation: 7it [00:00, 86.48it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 83.44it/s]
# Running evaluation: 7it [00:00, 84.61it/s]
# Running evaluation: 7it [00:00, 85.20it/s]
# Running evaluation: 7it [00:00, 85.44it/s]
# Running evaluation: 7it [00:00, 86.17it/s]
# Running evaluation: 7it [00:00, 85.79it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 86.75it/s]
# Running evaluation: 7it [00:00, 83.48it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 84.29it/s]
# Running evaluation: 7it [00:00, 81.59it/s]
# Running evaluation: 7it [00:00, 81.95it/s]
# Running evaluation: 7it [00:00, 87.33it/s]
# Running evaluation: 7it [00:00, 87.34it/s]
# Running evaluation: 7it [00:00, 85.16it/s]
# Running evaluation: 7it [00:00, 84.47it/s]
# Running evaluation: 7it [00:00, 86.07it/s]
# Running evaluation: 7it [00:00, 84.12it/s]
# Running evaluation: 7it [00:00, 80.23it/s]
# Running evaluation: 7it [00:00, 85.81it/s]
# Running evaluation: 7it [00:00, 82.39it/s]
# Running evaluation: 7it [00:00, 84.00it/s]
# Running evaluation: 7it [00:00, 86.71it/s]
# Running evaluation: 7it [00:00, 85.73it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 86.53it/s]
# Running evaluation: 7it [00:00, 86.05it/s]
# Running evaluation: 7it [00:00, 85.62it/s]
# Running evaluation: 7it [00:00, 87.26it/s]
# Running evaluation: 7it [00:00, 86.39it/s]
# Running evaluation: 7it [00:00, 85.32it/s]
# Running evaluation: 7it [00:00, 84.75it/s]
# Running evaluation: 7it [00:00, 85.75it/s]
# Running evaluation: 7it [00:00, 84.93it/s]
# Running evaluation: 7it [00:00, 85.51it/s]
# Running evaluation: 7it [00:00, 84.89it/s]
# Running evaluation: 7it [00:00, 85.39it/s]
# Running evaluation: 7it [00:00, 86.35it/s]
# Running evaluation: 7it [00:00, 85.91it/s]
# Running evaluation: 7it [00:00, 76.23it/s]
# Running evaluation: 7it [00:00, 86.52it/s]
# Running evaluation: 7it [00:00, 82.27it/s]
# Running evaluation: 7it [00:00, 87.16it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 85.56it/s]
# Running evaluation: 7it [00:00, 87.02it/s]
# Running evaluation: 7it [00:00, 86.61it/s]
# Running evaluation: 7it [00:00, 86.36it/s]
# Running evaluation: 7it [00:00, 85.67it/s]
# Running evaluation: 7it [00:00, 86.35it/s]
# Running evaluation: 7it [00:00, 78.43it/s]
# Running evaluation: 7it [00:00, 83.11it/s]
# Running evaluation: 7it [00:00, 85.19it/s]
# Running evaluation: 7it [00:00, 85.94it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 73.58it/s]
# Running evaluation: 7it [00:00, 73.95it/s]
# Running evaluation: 7it [00:00, 83.24it/s]
# Running evaluation: 7it [00:00, 84.88it/s]
# Running evaluation: 7it [00:00, 87.04it/s]
# Running evaluation: 7it [00:00, 86.62it/s]
# Running evaluation: 7it [00:00, 81.67it/s]
# Running evaluation: 7it [00:00, 84.41it/s]
# Running evaluation: 7it [00:00, 85.58it/s]
# Running evaluation: 7it [00:00, 87.12it/s]
# Running evaluation: 7it [00:00, 87.17it/s]
# Running evaluation: 7it [00:00, 85.49it/s]
# Running evaluation: 7it [00:00, 87.35it/s]
# Running evaluation: 7it [00:00, 85.76it/s]
# Running evaluation: 7it [00:00, 86.21it/s]
# Running evaluation: 7it [00:00, 86.74it/s]
# Running evaluation: 7it [00:00, 85.14it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 71.72it/s]
# Running evaluation: 7it [00:00, 86.49it/s]
# Running evaluation: 7it [00:00, 86.53it/s]
# Running evaluation: 7it [00:00, 87.16it/s]
# Running evaluation: 7it [00:00, 85.88it/s]
# Running evaluation: 7it [00:00, 86.99it/s]
# Running evaluation: 7it [00:00, 83.28it/s]
# Running evaluation: 7it [00:00, 85.86it/s]
# Running evaluation: 7it [00:00, 85.58it/s]
# Running evaluation: 7it [00:00, 84.37it/s]
# Running evaluation: 7it [00:00, 84.83it/s]
# Running evaluation: 7it [00:00, 86.11it/s]
# Running evaluation: 7it [00:00, 86.05it/s]
# Running evaluation: 7it [00:00, 86.34it/s]
# Running evaluation: 7it [00:00, 85.95it/s]
# Running evaluation: 7it [00:00, 86.18it/s]
# Running evaluation: 7it [00:00, 87.17it/s]
# Running evaluation: 7it [00:00, 84.91it/s]
# Running evaluation: 7it [00:00, 84.13it/s]
# Running evaluation: 7it [00:00, 85.71it/s]
# Running evaluation: 7it [00:00, 85.53it/s]
# Running evaluation: 7it [00:00, 87.53it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 86.58it/s]
# Running evaluation: 7it [00:00, 84.70it/s]
# Running evaluation: 7it [00:00, 84.68it/s]
# Running evaluation: 7it [00:00, 85.03it/s]
# Running evaluation: 7it [00:00, 85.27it/s]
# Running evaluation: 7it [00:00, 86.38it/s]
# Running evaluation: 7it [00:00, 86.21it/s]
# Running evaluation: 7it [00:00, 86.16it/s]
# Running evaluation: 7it [00:00, 87.71it/s]
# Running evaluation: 7it [00:00, 69.60it/s]
# Running evaluation: 7it [00:00, 81.76it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 86.67it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 86.24it/s]
# Running evaluation: 7it [00:00, 86.54it/s]
# Running evaluation: 7it [00:00, 86.38it/s]
# Running evaluation: 7it [00:00, 86.19it/s]
# Running evaluation: 7it [00:00, 86.56it/s]
# Running evaluation: 7it [00:00, 81.38it/s]
# Running evaluation: 7it [00:00, 86.54it/s]
# Running evaluation: 7it [00:00, 86.97it/s]
# Running evaluation: 7it [00:00, 84.10it/s]
# Running evaluation: 7it [00:00, 83.17it/s]
# Running evaluation: 7it [00:00, 85.99it/s]
# Running evaluation: 7it [00:00, 85.86it/s]
# Running evaluation: 7it [00:00, 85.51it/s]
# Running evaluation: 7it [00:00, 85.80it/s]
# Running evaluation: 7it [00:00, 84.90it/s]
# Running evaluation: 7it [00:00, 85.21it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 87.35it/s]
# Running evaluation: 7it [00:00, 87.25it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 84.81it/s]
# Running evaluation: 7it [00:00, 84.13it/s]
# Running evaluation: 7it [00:00, 85.77it/s]
# Running evaluation: 7it [00:00, 86.50it/s]
# Running evaluation: 7it [00:00, 83.74it/s]
# Running evaluation: 7it [00:00, 84.89it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 76.88it/s]
# Running evaluation: 7it [00:00, 85.73it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 83.94it/s]
# Running evaluation: 7it [00:00, 85.07it/s]
# Running evaluation: 7it [00:00, 84.43it/s]
# Running evaluation: 7it [00:00, 73.68it/s]
# Running evaluation: 7it [00:00, 72.69it/s]
# Running evaluation: 7it [00:00, 87.01it/s]
# Running evaluation: 7it [00:00, 86.25it/s]
# Running evaluation: 7it [00:00, 86.11it/s]
# Running evaluation: 7it [00:00, 84.29it/s]
# Running evaluation: 7it [00:00, 86.79it/s]
# Running evaluation: 7it [00:00, 81.73it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 82.80it/s]
# Running evaluation: 7it [00:00, 85.75it/s]
# Running evaluation: 7it [00:00, 86.74it/s]
# Running evaluation: 7it [00:00, 87.73it/s]
# Running evaluation: 7it [00:00, 87.01it/s]
# Running evaluation: 7it [00:00, 87.52it/s]
# Running evaluation: 7it [00:00, 85.80it/s]
# Running evaluation: 7it [00:00, 85.35it/s]
# Running evaluation: 7it [00:00, 86.87it/s]
# Running evaluation: 7it [00:00, 86.83it/s]
# Running evaluation: 7it [00:00, 84.15it/s]
# Running evaluation: 7it [00:00, 83.38it/s]
# Running evaluation: 7it [00:00, 13.39it/s]
# Running evaluation: 7it [00:00, 74.04it/s]
# Running evaluation: 7it [00:00, 84.28it/s]
# Running evaluation: 7it [00:00, 86.03it/s]
# Running evaluation: 7it [00:00, 86.27it/s]
# Running evaluation: 7it [00:00, 86.92it/s]
# Running evaluation: 7it [00:00, 87.00it/s]
# Running evaluation: 7it [00:00, 72.68it/s]
# Running evaluation: 7it [00:00, 85.95it/s]
# Running evaluation: 7it [00:00, 85.88it/s]
# Running evaluation: 7it [00:00, 82.53it/s]
# Running evaluation: 7it [00:00, 84.55it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 85.67it/s]
# Running evaluation: 7it [00:00, 84.12it/s]
# Running evaluation: 7it [00:00, 84.91it/s]
# Running evaluation: 7it [00:00, 86.46it/s]
# Running evaluation: 7it [00:00, 87.91it/s]
# Running evaluation: 7it [00:00, 87.03it/s]
# Running evaluation: 7it [00:00, 86.85it/s]
# Running evaluation: 7it [00:00, 86.71it/s]
# Running evaluation: 7it [00:00, 86.82it/s]
# Running evaluation: 7it [00:00, 85.27it/s]
# Running evaluation: 7it [00:00, 80.34it/s]
# Running evaluation: 7it [00:00, 83.88it/s]
# Running evaluation: 7it [00:00, 84.90it/s]
# Running evaluation: 7it [00:00, 85.16it/s]
# Running evaluation: 7it [00:00, 85.45it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 85.04it/s]
# Running evaluation: 7it [00:00, 86.16it/s]
# Running evaluation: 7it [00:00, 79.20it/s]
# Running evaluation: 7it [00:00, 76.76it/s]
# Running evaluation: 7it [00:00, 84.22it/s]
# Running evaluation: 7it [00:00, 83.72it/s]
# Running evaluation: 7it [00:00, 84.19it/s]
# Running evaluation: 7it [00:00, 82.91it/s]
# Running evaluation: 7it [00:00, 85.39it/s]
# Running evaluation: 7it [00:00, 85.08it/s]
# Running evaluation: 7it [00:00, 85.75it/s]
# Running evaluation: 7it [00:00, 86.15it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 77.57it/s]
# Running evaluation: 7it [00:00, 82.16it/s]
# Running evaluation: 7it [00:00, 86.38it/s]
# Running evaluation: 7it [00:00, 79.36it/s]
# Running evaluation: 7it [00:00, 85.31it/s]
# Running evaluation: 7it [00:00, 83.16it/s]
# Running evaluation: 7it [00:00, 84.89it/s]
# Running evaluation: 7it [00:00, 85.08it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 83.70it/s]
# Running evaluation: 7it [00:00, 85.30it/s]
# Running evaluation: 7it [00:00, 86.32it/s]
# Running evaluation: 7it [00:00, 85.71it/s]
# Running evaluation: 7it [00:00, 84.18it/s]
# Running evaluation: 7it [00:00, 86.57it/s]
# Running evaluation: 7it [00:00, 86.59it/s]
# Running evaluation: 7it [00:00, 84.19it/s]
# Running evaluation: 7it [00:00, 71.88it/s]
# Running evaluation: 7it [00:00, 74.25it/s]
# Running evaluation: 7it [00:00, 84.70it/s]
# Running evaluation: 7it [00:00, 85.25it/s]
# Running evaluation: 7it [00:00, 85.73it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 85.38it/s]
# Running evaluation: 7it [00:00, 85.05it/s]
# Running evaluation: 7it [00:00, 85.18it/s]
# Running evaluation: 7it [00:00, 85.70it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 79.63it/s]
# Running evaluation: 7it [00:00, 84.84it/s]
# Running evaluation: 7it [00:00, 86.22it/s]
# Running evaluation: 7it [00:00, 84.42it/s]
# Running evaluation: 7it [00:00, 85.61it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 85.36it/s]
# Running evaluation: 7it [00:00, 85.17it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 87.44it/s]
# Running evaluation: 7it [00:00, 86.37it/s]
# Running evaluation: 7it [00:00, 84.24it/s]
# Running evaluation: 7it [00:00, 84.40it/s]
# Running evaluation: 7it [00:00, 86.60it/s]
# Running evaluation: 7it [00:00, 85.50it/s]
# Running evaluation: 7it [00:00, 86.40it/s]
# Running evaluation: 7it [00:00, 85.20it/s]
# Running evaluation: 7it [00:00, 84.59it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 86.31it/s]
# Running evaluation: 7it [00:00, 86.33it/s]
# Running evaluation: 7it [00:00, 74.03it/s]
# Running evaluation: 7it [00:00, 74.03it/s]
# Running evaluation: 7it [00:00, 73.80it/s]
# Running evaluation: 7it [00:00, 85.37it/s]
# Running evaluation: 7it [00:00, 84.21it/s]
# Running evaluation: 7it [00:00, 85.28it/s]
# Running evaluation: 7it [00:00, 86.52it/s]
# Running evaluation: 7it [00:00, 84.28it/s]
# Running evaluation: 7it [00:00, 86.77it/s]
# Running evaluation: 7it [00:00, 85.59it/s]
# Running evaluation: 7it [00:00, 86.22it/s]
# Running evaluation: 7it [00:00, 86.94it/s]
# Running evaluation: 7it [00:00, 83.60it/s]
# Running evaluation: 7it [00:00, 84.20it/s]
# Running evaluation: 7it [00:00, 85.51it/s]
# Running evaluation: 7it [00:00, 78.31it/s]
# Running evaluation: 7it [00:00, 85.51it/s]
# Running evaluation: 7it [00:00, 84.60it/s]
# Running evaluation: 7it [00:00, 85.23it/s]
# Running evaluation: 7it [00:00, 86.15it/s]
# Running evaluation: 7it [00:00, 85.44it/s]
# Running evaluation: 7it [00:00, 82.99it/s]
# Running evaluation: 7it [00:00, 86.84it/s]
# Running evaluation: 7it [00:00, 86.75it/s]
# Running evaluation: 7it [00:00, 85.84it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 85.74it/s]
# Running evaluation: 7it [00:00, 85.74it/s]
# Running evaluation: 7it [00:00, 84.06it/s]
# Running evaluation: 7it [00:00, 85.19it/s]
# Running evaluation: 7it [00:00, 82.11it/s]
# Running evaluation: 7it [00:00, 84.65it/s]
# Running evaluation: 7it [00:00, 86.13it/s]
# Running evaluation: 7it [00:00, 86.12it/s]
# Running evaluation: 7it [00:00, 82.73it/s]
# Running evaluation: 7it [00:00, 85.15it/s]
# Running evaluation: 7it [00:00, 87.07it/s]
# Running evaluation: 7it [00:00, 86.05it/s]
# Running evaluation: 7it [00:00, 87.34it/s]
# Running evaluation: 7it [00:00, 83.24it/s]
# Running evaluation: 7it [00:00, 84.83it/s]
# Running evaluation: 7it [00:00, 86.92it/s]
# Running evaluation: 7it [00:00, 87.58it/s]
# Running evaluation: 7it [00:00, 85.94it/s]
# Running evaluation: 7it [00:00, 86.03it/s]
# Running evaluation: 7it [00:00, 86.25it/s]
# Running evaluation: 7it [00:00, 87.49it/s]
# Running evaluation: 7it [00:00, 86.35it/s]
# Running evaluation: 7it [00:00, 82.49it/s]
# Running evaluation: 7it [00:00, 86.06it/s]
# Running evaluation: 7it [00:00, 86.83it/s]
# Running evaluation: 7it [00:00, 85.85it/s]
# Running evaluation: 7it [00:00, 86.44it/s]
# Running evaluation: 7it [00:00, 85.42it/s]
# Running evaluation: 7it [00:00, 84.43it/s]
# Running evaluation: 7it [00:00, 84.91it/s]
# Running evaluation: 7it [00:00, 87.11it/s]
# Running evaluation: 7it [00:00, 84.22it/s]
# Running evaluation: 7it [00:00, 87.33it/s]
# Running evaluation: 7it [00:00, 85.90it/s]
# Running evaluation: 7it [00:00, 86.54it/s]
# Running evaluation: 7it [00:00, 85.98it/s]
# Running evaluation: 7it [00:00, 86.97it/s]
# Running evaluation: 7it [00:00, 86.33it/s]
# Running evaluation: 7it [00:00, 85.89it/s]
# Running evaluation: 7it [00:00, 85.11it/s]
# Running evaluation: 7it [00:00, 86.39it/s]
# Running evaluation: 7it [00:00, 86.48it/s]
# Running evaluation: 7it [00:00, 86.36it/s]
# Running evaluation: 7it [00:00, 86.42it/s]
# Running evaluation: 7it [00:00, 81.93it/s]
# Running evaluation: 7it [00:00, 85.62it/s]
# Running evaluation: 7it [00:00, 85.07it/s]
# Running evaluation: 7it [00:00, 84.03it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 87.99it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 86.83it/s]
# Running evaluation: 7it [00:00, 87.13it/s]
# Running evaluation: 7it [00:00, 87.28it/s]
# Running evaluation: 7it [00:00, 86.76it/s]
# Running evaluation: 7it [00:00, 86.63it/s]
# Running evaluation: 7it [00:00, 87.31it/s]
# Running evaluation: 7it [00:00, 87.05it/s]
# Running evaluation: 7it [00:00, 85.40it/s]
# Running evaluation: 7it [00:00, 83.61it/s]
# Running evaluation: 7it [00:00, 87.50it/s]
# Running evaluation: 7it [00:00, 86.58it/s]
# Running evaluation: 7it [00:00, 85.37it/s]
# Running evaluation: 7it [00:00, 83.65it/s]
# Running evaluation: 7it [00:00, 86.64it/s]
# Running evaluation: 7it [00:00, 83.07it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 87.20it/s]
# Running evaluation: 7it [00:00, 86.27it/s]
# Running evaluation: 7it [00:00, 86.67it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 87.31it/s]
# Running evaluation: 7it [00:00, 86.90it/s]
# Running evaluation: 7it [00:00, 84.96it/s]
# Running evaluation: 7it [00:00, 83.16it/s]
# Running evaluation: 7it [00:00, 82.44it/s]
# Running evaluation: 7it [00:00, 85.50it/s]
# Running evaluation: 7it [00:00, 86.79it/s]
# Running evaluation: 7it [00:00, 85.38it/s]
# Running evaluation: 7it [00:00, 82.50it/s]
# Running evaluation: 7it [00:00, 85.87it/s]
# Running evaluation: 7it [00:00, 85.69it/s]
# Running evaluation: 7it [00:00, 82.60it/s]
# Running evaluation: 7it [00:00, 11.87it/s]
# Running evaluation: 7it [00:00, 86.09it/s]
# Running evaluation: 7it [00:00, 83.75it/s]
# Running evaluation: 7it [00:00, 86.39it/s]
# Running evaluation: 7it [00:00, 86.99it/s]
# Running evaluation: 7it [00:00, 88.28it/s]
# Running evaluation: 7it [00:00, 87.61it/s]
# Running evaluation: 7it [00:00, 85.91it/s]
# Running evaluation: 7it [00:00, 86.86it/s]
# Running evaluation: 7it [00:00, 83.50it/s]
# Running evaluation: 7it [00:00, 83.43it/s]
# Running evaluation: 7it [00:00, 84.43it/s]
# Running evaluation: 7it [00:00, 86.88it/s]
# Running evaluation: 7it [00:00, 86.74it/s]
# Running evaluation: 7it [00:00, 83.18it/s]
# Running evaluation: 7it [00:00, 85.21it/s]
# Running evaluation: 7it [00:00, 86.16it/s]
# Running evaluation: 7it [00:00, 86.79it/s]
# Running evaluation: 7it [00:00, 87.24it/s]
# Running evaluation: 7it [00:00, 84.16it/s]
# Running evaluation: 7it [00:00, 86.47it/s]
# Running evaluation: 7it [00:00, 86.67it/s]
# Running evaluation: 7it [00:00, 83.41it/s]
# Running evaluation: 7it [00:00, 85.55it/s]
# Running evaluation: 7it [00:00, 85.88it/s]
# Running evaluation: 7it [00:00, 86.71it/s]
# Running evaluation: 7it [00:00, 86.25it/s]
# Running evaluation: 7it [00:00, 85.39it/s]
# Running evaluation: 7it [00:00, 84.67it/s]
# Running evaluation: 7it [00:00, 82.65it/s]
# Running evaluation: 7it [00:00, 86.41it/s]
# Running evaluation: 7it [00:00, 84.97it/s]
# Running evaluation: 7it [00:00, 83.75it/s]
# Running evaluation: 7it [00:00, 85.93it/s]
# Running evaluation: 7it [00:00, 87.00it/s]
# Running evaluation: 7it [00:00, 87.78it/s]
# Running evaluation: 7it [00:00, 87.13it/s]
# Running evaluation: 7it [00:00, 86.74it/s]
# Running evaluation: 7it [00:00, 87.84it/s]
# Running evaluation: 7it [00:00, 84.90it/s]
# Running evaluation: 7it [00:00, 86.72it/s]
# Running evaluation: 7it [00:00, 85.91it/s]
# Running evaluation: 7it [00:00, 82.87it/s]
# Running evaluation: 7it [00:00, 85.50it/s]
# Running evaluation: 7it [00:00, 80.16it/s]
# Running evaluation: 7it [00:00, 83.99it/s]
# Running evaluation: 7it [00:00, 85.72it/s]
# Running evaluation: 7it [00:00, 86.40it/s]
# Running evaluation: 7it [00:00, 86.03it/s]
# Running evaluation: 7it [00:00, 86.85it/s]
# Running evaluation: 7it [00:00, 87.15it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 86.94it/s]
# Running evaluation: 7it [00:00, 83.04it/s]
# Running evaluation: 7it [00:00, 85.64it/s]
# Running evaluation: 7it [00:00, 86.36it/s]
# Running evaluation: 7it [00:00, 86.75it/s]
# Running evaluation: 7it [00:00, 86.99it/s]
# Running evaluation: 7it [00:00, 84.33it/s]
# Running evaluation: 7it [00:00, 84.86it/s]
# Running evaluation: 7it [00:00, 87.09it/s]
# Running evaluation: 7it [00:00, 84.73it/s]
# Running evaluation: 7it [00:00, 86.46it/s]
# Running evaluation: 7it [00:00, 85.08it/s]
# Running evaluation: 7it [00:00, 86.26it/s]
# Running evaluation: 7it [00:00, 83.93it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 86.78it/s]
# Running evaluation: 7it [00:00, 84.12it/s]
# Running evaluation: 7it [00:00, 85.58it/s]
# Running evaluation: 7it [00:00, 86.44it/s]
# Running evaluation: 7it [00:00, 83.31it/s]
# Running evaluation: 7it [00:00, 86.58it/s]
# Running evaluation: 7it [00:00, 84.30it/s]
# Running evaluation: 7it [00:00, 86.09it/s]
# Running evaluation: 7it [00:00, 86.93it/s]
# Running evaluation: 7it [00:00, 86.07it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 86.98it/s]
# Running evaluation: 7it [00:00, 85.57it/s]
# Running evaluation: 7it [00:00, 85.61it/s]
# Running evaluation: 7it [00:00, 85.65it/s]
# Running evaluation: 7it [00:00, 83.76it/s]
# Running evaluation: 7it [00:00, 84.06it/s]
# Running evaluation: 7it [00:00, 83.86it/s]
# Running evaluation: 7it [00:00, 85.71it/s]
# Running evaluation: 7it [00:00, 85.16it/s]
# Running evaluation: 7it [00:00, 86.81it/s]
# Running evaluation: 7it [00:00, 86.06it/s]
# Running evaluation: 7it [00:00, 85.97it/s]
# Running evaluation: 7it [00:00, 81.49it/s]
# Running evaluation: 7it [00:00, 87.38it/s]
# Running evaluation: 7it [00:00, 86.44it/s]
# Running evaluation: 7it [00:00, 83.09it/s]
# Running evaluation: 7it [00:00, 82.96it/s]
# Running evaluation: 7it [00:00, 86.00it/s]
# Running evaluation: 7it [00:00, 86.28it/s]
# Running evaluation: 7it [00:00, 85.63it/s]
# Running evaluation: 7it [00:00, 82.81it/s]
# Running evaluation: 7it [00:00, 86.05it/s]
# Running evaluation: 7it [00:00, 87.17it/s]
# Running evaluation: 7it [00:00, 86.04it/s]
# Running evaluation: 7it [00:00, 87.43it/s]
# Running evaluation: 7it [00:00, 82.75it/s]
# Running evaluation: 7it [00:00, 83.73it/s]
# Running evaluation: 7it [00:00, 85.13it/s]
# Running evaluation: 7it [00:00, 86.30it/s]
# Running evaluation: 7it [00:00, 85.88it/s]
# Running evaluation: 7it [00:00, 85.40it/s]
# Running evaluation: 7it [00:00, 85.96it/s]
# Running evaluation: 7it [00:00, 86.57it/s]
# Running evaluation: 7it [00:00, 86.65it/s]
# Running evaluation: 7it [00:00, 86.95it/s]
# Running evaluation: 7it [00:00, 82.96it/s]
# Running evaluation: 7it [00:00, 85.07it/s]
# Running evaluation: 7it [00:00, 85.45it/s]
# Running evaluation: 7it [00:00, 85.98it/s]
# Running evaluation: 7it [00:00, 85.63it/s]
# Running evaluation: 7it [00:00, 86.23it/s]
# Running evaluation: 7it [00:00, 84.50it/s]
# Running evaluation: 7it [00:00, 77.04it/s]
# Running evaluation: 7it [00:00, 85.10it/s]
# Running evaluation: 7it [00:00, 85.98it/s]
# Running evaluation: 7it [00:00, 86.59it/s]
# Running evaluation: 7it [00:00, 85.43it/s]
# Running evaluation: 7it [00:00, 83.20it/s]
# Running evaluation: 7it [00:00, 85.50it/s]
# Running evaluation: 7it [00:00, 84.92it/s]
# Running evaluation: 7it [00:00, 85.65it/s]
# Running evaluation: 7it [00:00, 85.26it/s]
# Running evaluation: 7it [00:00, 86.45it/s]
# Running evaluation: 7it [00:00, 86.02it/s]
# Running evaluation: 7it [00:00, 87.18it/s]
# Running evaluation: 7it [00:00, 85.56it/s]
# Running evaluation: 7it [00:00, 46.36it/s]

# %%
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("ND: {}".format(agg_metric["ND"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS: 0.16339298714403305
# ND: 0.21169252294997476
# NRMSE: 0.4934295422058236
# MSE: 0.0006677706891912659

# %%
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("ND: {}".format(agg_metric["ND"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS: 0.16339298714403305
# ND: 0.21169252294997476
# NRMSE: 0.4934295422058236
# MSE: 0.0006677706891912659

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
