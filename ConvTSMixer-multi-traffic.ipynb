# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

#from pts.modules import StudentTOutput

from ConvTSMixer import ConvTSMixerEstimator
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kashif/.env/pytorch/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
dataset = get_dataset("traffic_nips", regenerate=False)
train_grouper = MultivariateGrouper(max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)), 
                                   max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality))
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = ConvTSMixerEstimator(
    #distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*2,
    freq=dataset.metadata.freq,
    scaling="std",
    
    depth=4,
    patch_size=(3, 20),
    kernel_size=9,
    dim=32,
    
    batch_size=128,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda")
)

# %%
predictor = estimator.train(
    training_data=dataset_train, 
    cache_data=True, 
    shuffle_buffer_length=1024, 
)
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | ConvTSMixerModel | 30.8 K
# -------------------------------------------
# 30.8 K    Trainable params
# 0         Non-trainable params
# 30.8 K    Total params
# 0.123     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -2.41258 (best -2.41258), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -2.75173 (best -2.75173), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -2.81017 (best -2.81017), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -2.83491 (best -2.83491), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -2.84844 (best -2.84844), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -2.85973 (best -2.85973), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -2.86482 (best -2.86482), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -2.86748 (best -2.86748), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -2.87066 (best -2.87066), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -2.87817 (best -2.87817), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -2.87981 (best -2.87981), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -2.88509 (best -2.88509), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -2.88819 (best -2.88819), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' was not in top 1
# Epoch 14, global step 1500: 'train_loss' reached -2.89291 (best -2.89291), saving model to '/mnt/scratch/kashif/ConvTS-Mixer/lightning_logs/version_105/checkpoints/epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' was not in top 1
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:54: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                             predictor=predictor,
                                             num_samples=100)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:],
                                  target_agg_funcs={'sum': np.sum})

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 71.86it/s]
#
# Running evaluation: 7it [00:00, 104.75it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 111.08it/s]
#
# Running evaluation: 7it [00:00, 111.03it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 110.26it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 111.51it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 109.75it/s]
#
# Running evaluation: 7it [00:00, 107.22it/s]
#
# Running evaluation: 7it [00:00, 109.53it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 111.08it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.23it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 111.55it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 111.53it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 111.56it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 111.43it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 110.23it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 110.86it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.08it/s]
#
# Running evaluation: 7it [00:00, 110.12it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.26it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 110.02it/s]
#
# Running evaluation: 7it [00:00, 109.80it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.31it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.74it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.02it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.26it/s]
#
# Running evaluation: 7it [00:00, 110.29it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.39it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 88.89it/s]
#
# Running evaluation: 7it [00:00, 107.77it/s]
#
# Running evaluation: 7it [00:00, 109.79it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 109.44it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.18it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 109.97it/s]
#
# Running evaluation: 7it [00:00, 110.22it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 110.71it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 109.95it/s]
#
# Running evaluation: 7it [00:00, 110.21it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.01it/s]
#
# Running evaluation: 7it [00:00, 110.14it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.14it/s]
#
# Running evaluation: 7it [00:00, 110.21it/s]
#
# Running evaluation: 7it [00:00, 108.66it/s]
#
# Running evaluation: 7it [00:00, 109.20it/s]
#
# Running evaluation: 7it [00:00, 110.74it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 110.46it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 109.83it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 110.07it/s]
#
# Running evaluation: 7it [00:00, 110.46it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.39it/s]
#
# Running evaluation: 7it [00:00, 105.19it/s]
#
# Running evaluation: 7it [00:00, 110.15it/s]
#
# Running evaluation: 7it [00:00, 109.52it/s]
#
# Running evaluation: 7it [00:00, 109.40it/s]
#
# Running evaluation: 7it [00:00, 109.41it/s]
#
# Running evaluation: 7it [00:00, 22.14it/s]
#
# Running evaluation: 7it [00:00, 111.45it/s]
#
# Running evaluation: 7it [00:00, 111.84it/s]
#
# Running evaluation: 7it [00:00, 109.84it/s]
#
# Running evaluation: 7it [00:00, 109.92it/s]
#
# Running evaluation: 7it [00:00, 109.46it/s]
#
# Running evaluation: 7it [00:00, 108.75it/s]
#
# Running evaluation: 7it [00:00, 108.11it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 108.90it/s]
#
# Running evaluation: 7it [00:00, 108.59it/s]
#
# Running evaluation: 7it [00:00, 109.60it/s]
#
# Running evaluation: 7it [00:00, 109.62it/s]
#
# Running evaluation: 7it [00:00, 108.72it/s]
#
# Running evaluation: 7it [00:00, 108.77it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 108.50it/s]
#
# Running evaluation: 7it [00:00, 108.92it/s]
#
# Running evaluation: 7it [00:00, 108.98it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 109.12it/s]
#
# Running evaluation: 7it [00:00, 109.51it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 109.99it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 110.31it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 110.12it/s]
#
# Running evaluation: 7it [00:00, 109.46it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 111.08it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 110.31it/s]
#
# Running evaluation: 7it [00:00, 109.95it/s]
#
# Running evaluation: 7it [00:00, 91.05it/s]
#
# Running evaluation: 7it [00:00, 109.73it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 110.18it/s]
#
# Running evaluation: 7it [00:00, 110.19it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.24it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.14it/s]
#
# Running evaluation: 7it [00:00, 109.69it/s]
#
# Running evaluation: 7it [00:00, 109.84it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 111.23it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 109.77it/s]
#
# Running evaluation: 7it [00:00, 109.79it/s]
#
# Running evaluation: 7it [00:00, 111.91it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.30it/s]
#
# Running evaluation: 7it [00:00, 110.53it/s]
#
# Running evaluation: 7it [00:00, 111.03it/s]
#
# Running evaluation: 7it [00:00, 110.30it/s]
#
# Running evaluation: 7it [00:00, 110.31it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 110.53it/s]
#
# Running evaluation: 7it [00:00, 109.67it/s]
#
# Running evaluation: 7it [00:00, 109.49it/s]
#
# Running evaluation: 7it [00:00, 109.74it/s]
#
# Running evaluation: 7it [00:00, 109.99it/s]
#
# Running evaluation: 7it [00:00, 110.01it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 111.24it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 111.73it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 109.63it/s]
#
# Running evaluation: 7it [00:00, 109.74it/s]
#
# Running evaluation: 7it [00:00, 109.18it/s]
#
# Running evaluation: 7it [00:00, 109.79it/s]
#
# Running evaluation: 7it [00:00, 109.03it/s]
#
# Running evaluation: 7it [00:00, 109.71it/s]
#
# Running evaluation: 7it [00:00, 109.82it/s]
#
# Running evaluation: 7it [00:00, 109.30it/s]
#
# Running evaluation: 7it [00:00, 109.36it/s]
#
# Running evaluation: 7it [00:00, 109.09it/s]
#
# Running evaluation: 7it [00:00, 109.24it/s]
#
# Running evaluation: 7it [00:00, 105.50it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 111.42it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 105.68it/s]
#
# Running evaluation: 7it [00:00, 106.10it/s]
#
# Running evaluation: 7it [00:00, 109.54it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 109.29it/s]
#
# Running evaluation: 7it [00:00, 108.83it/s]
#
# Running evaluation: 7it [00:00, 80.93it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 108.45it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 108.81it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 110.06it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 110.07it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.53it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 110.04it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.12it/s]
#
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 109.84it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 109.66it/s]
#
# Running evaluation: 7it [00:00, 109.88it/s]
#
# Running evaluation: 7it [00:00, 110.86it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 109.20it/s]
#
# Running evaluation: 7it [00:00, 108.07it/s]
#
# Running evaluation: 7it [00:00, 109.65it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 108.94it/s]
#
# Running evaluation: 7it [00:00, 108.89it/s]
#
# Running evaluation: 7it [00:00, 108.82it/s]
#
# Running evaluation: 7it [00:00, 108.80it/s]
#
# Running evaluation: 7it [00:00, 109.64it/s]
#
# Running evaluation: 7it [00:00, 109.21it/s]
#
# Running evaluation: 7it [00:00, 108.77it/s]
#
# Running evaluation: 7it [00:00, 109.32it/s]
#
# Running evaluation: 7it [00:00, 108.91it/s]
#
# Running evaluation: 7it [00:00, 109.93it/s]
#
# Running evaluation: 7it [00:00, 108.62it/s]
#
# Running evaluation: 7it [00:00, 109.01it/s]
#
# Running evaluation: 7it [00:00, 110.28it/s]
#
# Running evaluation: 7it [00:00, 109.14it/s]
#
# Running evaluation: 7it [00:00, 108.70it/s]
#
# Running evaluation: 7it [00:00, 108.81it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 109.01it/s]
#
# Running evaluation: 7it [00:00, 109.12it/s]
#
# Running evaluation: 7it [00:00, 108.48it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 109.09it/s]
# Running evaluation: 7it [00:00, 109.28it/s]
#
# Running evaluation: 7it [00:00, 109.52it/s]
#
# Running evaluation: 7it [00:00, 109.19it/s]
#
# Running evaluation: 7it [00:00, 109.07it/s]
#
# Running evaluation: 7it [00:00, 108.61it/s]
#
# Running evaluation: 7it [00:00, 108.96it/s]
#
# Running evaluation: 7it [00:00, 110.09it/s]
#
# Running evaluation: 7it [00:00, 108.57it/s]
#
# Running evaluation: 7it [00:00, 109.36it/s]
#
# Running evaluation: 7it [00:00, 108.82it/s]
#
# Running evaluation: 7it [00:00, 108.67it/s]
#
# Running evaluation: 7it [00:00, 103.18it/s]
#
# Running evaluation: 7it [00:00, 105.52it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 111.12it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.44it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.01it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 108.69it/s]
#
# Running evaluation: 7it [00:00, 109.21it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 111.40it/s]
#
# Running evaluation: 7it [00:00, 110.53it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.74it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
#
# Running evaluation: 7it [00:00, 109.19it/s]
#
# Running evaluation: 7it [00:00, 107.72it/s]
#
# Running evaluation: 7it [00:00, 109.48it/s]
#
# Running evaluation: 7it [00:00, 109.35it/s]
#
# Running evaluation: 7it [00:00, 109.85it/s]
#
# Running evaluation: 7it [00:00, 108.61it/s]
#
# Running evaluation: 7it [00:00, 109.94it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 111.25it/s]
#
# Running evaluation: 7it [00:00, 111.99it/s]
#
# Running evaluation: 7it [00:00, 111.41it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 111.81it/s]
#
# Running evaluation: 7it [00:00, 108.74it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 111.06it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 111.65it/s]
#
# Running evaluation: 7it [00:00, 111.42it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 105.69it/s]
#
# Running evaluation: 7it [00:00, 105.38it/s]
#
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 109.78it/s]
#
# Running evaluation: 7it [00:00, 110.46it/s]
#
# Running evaluation: 7it [00:00, 106.19it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 111.54it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 110.71it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 110.97it/s]
#
# Running evaluation: 7it [00:00, 111.42it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 111.25it/s]
#
# Running evaluation: 7it [00:00, 111.68it/s]
#
# Running evaluation: 7it [00:00, 111.37it/s]
#
# Running evaluation: 7it [00:00, 111.21it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 111.35it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 111.61it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 109.36it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 111.01it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.86it/s]
#
# Running evaluation: 7it [00:00, 104.67it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 111.29it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 111.00it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 111.16it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 111.20it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 111.05it/s]
#
# Running evaluation: 7it [00:00, 110.84it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 111.58it/s]
#
# Running evaluation: 7it [00:00, 111.18it/s]
#
# Running evaluation: 7it [00:00, 109.64it/s]
#
# Running evaluation: 7it [00:00, 107.00it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 106.05it/s]
#
# Running evaluation: 7it [00:00, 108.11it/s]
#
# Running evaluation: 7it [00:00, 109.01it/s]
#
# Running evaluation: 7it [00:00, 111.07it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 111.38it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 109.91it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.91it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 110.04it/s]
#
# Running evaluation: 7it [00:00, 110.26it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 109.88it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 110.46it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 110.83it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.11it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 110.81it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 108.50it/s]
#
# Running evaluation: 7it [00:00, 107.45it/s]
#
# Running evaluation: 7it [00:00, 111.12it/s]
#
# Running evaluation: 7it [00:00, 111.31it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 110.47it/s]
#
# Running evaluation: 7it [00:00, 110.71it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 110.70it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.75it/s]
#
# Running evaluation: 7it [00:00, 110.63it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.85it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 111.19it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 110.06it/s]
#
# Running evaluation: 7it [00:00, 109.53it/s]
#
# Running evaluation: 7it [00:00, 102.17it/s]
#
# Running evaluation: 7it [00:00, 110.08it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 109.50it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 105.65it/s]
#
# Running evaluation: 7it [00:00, 110.07it/s]
#
# Running evaluation: 7it [00:00, 111.04it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 111.26it/s]
#
# Running evaluation: 7it [00:00, 110.15it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 109.96it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 111.17it/s]
#
# Running evaluation: 7it [00:00, 110.72it/s]
#
# Running evaluation: 7it [00:00, 105.53it/s]
#
# Running evaluation: 7it [00:00, 109.33it/s]
#
# Running evaluation: 7it [00:00, 110.57it/s]
#
# Running evaluation: 7it [00:00, 111.01it/s]
#
# Running evaluation: 7it [00:00, 109.41it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 111.10it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 108.77it/s]
#
# Running evaluation: 7it [00:00, 110.59it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 108.65it/s]
#
# Running evaluation: 7it [00:00, 100.54it/s]
#
# Running evaluation: 7it [00:00, 108.82it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 109.99it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 110.52it/s]
#
# Running evaluation: 7it [00:00, 110.03it/s]
#
# Running evaluation: 7it [00:00, 109.36it/s]
#
# Running evaluation: 7it [00:00, 110.74it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 109.75it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.58it/s]
#
# Running evaluation: 7it [00:00, 104.89it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 109.43it/s]
#
# Running evaluation: 7it [00:00, 110.99it/s]
#
# Running evaluation: 7it [00:00, 111.14it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 109.63it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.82it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 107.72it/s]
#
# Running evaluation: 7it [00:00, 110.69it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 110.90it/s]
#
# Running evaluation: 7it [00:00, 102.77it/s]
#
# Running evaluation: 7it [00:00, 109.86it/s]
#
# Running evaluation: 7it [00:00, 110.02it/s]
#
# Running evaluation: 7it [00:00, 110.29it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 111.57it/s]
#
# Running evaluation: 7it [00:00, 111.36it/s]
#
# Running evaluation: 7it [00:00, 110.53it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 110.86it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 111.09it/s]
#
# Running evaluation: 7it [00:00, 110.93it/s]
#
# Running evaluation: 7it [00:00, 109.96it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.38it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
#
# Running evaluation: 7it [00:00, 110.87it/s]
#
# Running evaluation: 7it [00:00, 110.94it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 110.60it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.54it/s]
#
# Running evaluation: 7it [00:00, 103.89it/s]
#
# Running evaluation: 7it [00:00, 77.89it/s]
#
# Running evaluation: 7it [00:00, 110.46it/s]
#
# Running evaluation: 7it [00:00, 110.00it/s]
#
# Running evaluation: 7it [00:00, 110.11it/s]
#
# Running evaluation: 7it [00:00, 110.80it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 14.31it/s]
#
# Running evaluation: 7it [00:00, 111.22it/s]
#
# Running evaluation: 7it [00:00, 111.64it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.79it/s]
#
# Running evaluation: 7it [00:00, 110.51it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.03it/s]
#
# Running evaluation: 7it [00:00, 110.14it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.29it/s]
#
# Running evaluation: 7it [00:00, 109.90it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.01it/s]
#
# Running evaluation: 7it [00:00, 110.45it/s]
#
# Running evaluation: 7it [00:00, 110.37it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.92it/s]
# Running evaluation: 7it [00:00, 109.53it/s]
#
# Running evaluation: 7it [00:00, 108.44it/s]
#
# Running evaluation: 7it [00:00, 98.86it/s]
#
# Running evaluation: 7it [00:00, 109.69it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 110.66it/s]
#
# Running evaluation: 7it [00:00, 110.73it/s]
#
# Running evaluation: 7it [00:00, 110.97it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 111.85it/s]
#
# Running evaluation: 7it [00:00, 109.83it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.95it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 110.21it/s]
#
# Running evaluation: 7it [00:00, 111.26it/s]
#
# Running evaluation: 7it [00:00, 110.64it/s]
#
# Running evaluation: 7it [00:00, 110.22it/s]
#
# Running evaluation: 7it [00:00, 110.76it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 110.98it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.40it/s]
#
# Running evaluation: 7it [00:00, 110.15it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.78it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 110.05it/s]
#
# Running evaluation: 7it [00:00, 110.96it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 108.79it/s]
#
# Running evaluation: 7it [00:00, 108.84it/s]
#
# Running evaluation: 7it [00:00, 109.29it/s]
#
# Running evaluation: 7it [00:00, 101.13it/s]
#
# Running evaluation: 7it [00:00, 110.62it/s]
#
# Running evaluation: 7it [00:00, 109.99it/s]
#
# Running evaluation: 7it [00:00, 111.11it/s]
#
# Running evaluation: 7it [00:00, 110.42it/s]
#
# Running evaluation: 7it [00:00, 110.36it/s]
#
# Running evaluation: 7it [00:00, 110.65it/s]
#
# Running evaluation: 7it [00:00, 110.97it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 110.68it/s]
#
# Running evaluation: 7it [00:00, 111.30it/s]
#
# Running evaluation: 7it [00:00, 110.32it/s]
#
# Running evaluation: 7it [00:00, 110.43it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.10it/s]
#
# Running evaluation: 7it [00:00, 105.82it/s]
#
# Running evaluation: 7it [00:00, 107.78it/s]
#
# Running evaluation: 7it [00:00, 105.88it/s]
#
# Running evaluation: 7it [00:00, 109.40it/s]
#
# Running evaluation: 7it [00:00, 110.55it/s]
#
# Running evaluation: 7it [00:00, 110.33it/s]
#
# Running evaluation: 7it [00:00, 110.20it/s]
#
# Running evaluation: 7it [00:00, 109.47it/s]
#
# Running evaluation: 7it [00:00, 109.44it/s]
#
# Running evaluation: 7it [00:00, 109.96it/s]
#
# Running evaluation: 7it [00:00, 110.67it/s]
#
# Running evaluation: 7it [00:00, 110.27it/s]
#
# Running evaluation: 7it [00:00, 110.18it/s]
#
# Running evaluation: 7it [00:00, 110.50it/s]
#
# Running evaluation: 7it [00:00, 110.34it/s]
#
# Running evaluation: 7it [00:00, 110.88it/s]
#
# Running evaluation: 7it [00:00, 110.35it/s]
#
# Running evaluation: 7it [00:00, 110.47it/s]
#
# Running evaluation: 7it [00:00, 109.74it/s]
#
# Running evaluation: 7it [00:00, 109.03it/s]
#
# Running evaluation: 7it [00:00, 109.21it/s]
#
# Running evaluation: 7it [00:00, 101.39it/s]
#
# Running evaluation: 7it [00:00, 102.34it/s]
#
# Running evaluation: 7it [00:00, 108.23it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.41it/s]
#
# Running evaluation: 7it [00:00, 110.16it/s]
#
# Running evaluation: 7it [00:00, 110.03it/s]
#
# Running evaluation: 7it [00:00, 110.29it/s]
#
# Running evaluation: 7it [00:00, 110.89it/s]
#
# Running evaluation: 7it [00:00, 110.49it/s]
#
# Running evaluation: 7it [00:00, 110.26it/s]
#
# Running evaluation: 7it [00:00, 110.13it/s]
#
# Running evaluation: 7it [00:00, 110.07it/s]
#
# Running evaluation: 7it [00:00, 109.84it/s]
#
# Running evaluation: 7it [00:00, 109.26it/s]
#
# Running evaluation: 7it [00:00, 109.81it/s]
#
# Running evaluation: 7it [00:00, 110.02it/s]
#
# Running evaluation: 7it [00:00, 109.93it/s]
#
# Running evaluation: 7it [00:00, 109.89it/s]
#
# Running evaluation: 7it [00:00, 109.31it/s]
#
# Running evaluation: 7it [00:00, 110.07it/s]
#
# Running evaluation: 7it [00:00, 109.59it/s]
#
# Running evaluation: 7it [00:00, 110.08it/s]
#
# Running evaluation: 7it [00:00, 109.68it/s]
#
# Running evaluation: 7it [00:00, 110.24it/s]
#
# Running evaluation: 7it [00:00, 109.94it/s]
#
# Running evaluation: 7it [00:00, 110.56it/s]
#
# Running evaluation: 7it [00:00, 108.86it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 110.01it/s]
#
# Running evaluation: 7it [00:00, 109.62it/s]
#
# Running evaluation: 7it [00:00, 110.18it/s]
#
# Running evaluation: 7it [00:00, 109.96it/s]
#
# Running evaluation: 7it [00:00, 110.19it/s]
#
# Running evaluation: 7it [00:00, 111.27it/s]
#
# Running evaluation: 7it [00:00, 110.15it/s]
#
# Running evaluation: 7it [00:00, 106.40it/s]
#
# Running evaluation: 7it [00:00, 104.23it/s]
#
# Running evaluation: 7it [00:00, 110.48it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 110.77it/s]
#
# Running evaluation: 7it [00:00, 109.93it/s]
#
# Running evaluation: 7it [00:00, 109.95it/s]
#
# Running evaluation: 7it [00:00, 110.25it/s]
#
# Running evaluation: 7it [00:00, 109.69it/s]
#
# Running evaluation: 7it [00:00, 110.30it/s]
#
# Running evaluation: 7it [00:00, 108.76it/s]
#
# Running evaluation: 7it [00:00, 101.32it/s]
#
# Running evaluation: 7it [00:00, 102.21it/s]
#
# Running evaluation: 7it [00:00, 103.59it/s]
#
# Running evaluation: 7it [00:00, 108.51it/s]
#
# Running evaluation: 7it [00:00, 103.82it/s]
#
# Running evaluation: 7it [00:00, 95.84it/s]
#
# Running evaluation: 7it [00:00, 99.33it/s]
#
# Running evaluation: 7it [00:00, 91.62it/s]
#
# Running evaluation: 7it [00:00, 102.89it/s]
#
# Running evaluation: 7it [00:00, 103.86it/s]
#
# Running evaluation: 7it [00:00, 103.19it/s]
#
# Running evaluation: 7it [00:00, 102.97it/s]
#
# Running evaluation: 7it [00:00, 102.67it/s]
#
# Running evaluation: 7it [00:00, 103.54it/s]
#
# Running evaluation: 7it [00:00, 101.83it/s]
#
# Running evaluation: 7it [00:00, 100.62it/s]
#
# Running evaluation: 7it [00:00, 101.40it/s]
#
# Running evaluation: 7it [00:00, 105.52it/s]
#
# Running evaluation: 7it [00:00, 104.23it/s]
#
# Running evaluation: 7it [00:00, 104.77it/s]
#
# Running evaluation: 7it [00:00, 103.85it/s]
#
# Running evaluation: 7it [00:00, 104.06it/s]
#
# Running evaluation: 7it [00:00, 102.90it/s]
#
# Running evaluation: 7it [00:00, 103.40it/s]
#
# Running evaluation: 7it [00:00, 101.84it/s]
#
# Running evaluation: 7it [00:00, 101.96it/s]
#
# Running evaluation: 7it [00:00, 103.02it/s]
#
# Running evaluation: 7it [00:00, 103.07it/s]
#
# Running evaluation: 7it [00:00, 104.12it/s]
#
# Running evaluation: 7it [00:00, 81.65it/s]
#
# Running evaluation: 7it [00:00, 102.95it/s]
#
# Running evaluation: 7it [00:00, 103.12it/s]
#
# Running evaluation: 7it [00:00, 91.28it/s]
#
# Running evaluation: 7it [00:00, 105.86it/s]
#
# Running evaluation: 7it [00:00, 105.00it/s]
#
# Running evaluation: 7it [00:00, 104.88it/s]
#
# Running evaluation: 7it [00:00, 104.04it/s]
#
# Running evaluation: 7it [00:00, 104.90it/s]
#
# Running evaluation: 7it [00:00, 99.68it/s]
#
# Running evaluation: 7it [00:00, 103.78it/s]
#
# Running evaluation: 7it [00:00, 102.64it/s]
#
# Running evaluation: 7it [00:00, 102.47it/s]
#
# Running evaluation: 7it [00:00, 103.82it/s]
#
# Running evaluation: 7it [00:00, 98.87it/s]
#
# Running evaluation: 7it [00:00, 102.00it/s]
#
# Running evaluation: 7it [00:00, 101.51it/s]
#
# Running evaluation: 7it [00:00, 100.95it/s]
#
# Running evaluation: 7it [00:00, 103.97it/s]
#
# Running evaluation: 7it [00:00, 104.48it/s]
#
# Running evaluation: 7it [00:00, 102.45it/s]
#
# Running evaluation: 7it [00:00, 103.59it/s]
#
# Running evaluation: 7it [00:00, 102.11it/s]
#
# Running evaluation: 7it [00:00, 102.51it/s]
#
# Running evaluation: 7it [00:00, 102.78it/s]
#
# Running evaluation: 7it [00:00, 104.28it/s]
#
# Running evaluation: 7it [00:00, 103.86it/s]
#
# Running evaluation: 7it [00:00, 101.00it/s]
#
# Running evaluation: 7it [00:00, 103.49it/s]
#
# Running evaluation: 7it [00:00, 102.04it/s]
#
# Running evaluation: 7it [00:00, 101.22it/s]
#
# Running evaluation: 7it [00:00, 103.45it/s]
# Running evaluation: 7it [00:00, 104.25it/s]
#
# Running evaluation: 7it [00:00, 103.44it/s]
#
# Running evaluation: 7it [00:00, 101.19it/s]
#
# Running evaluation: 7it [00:00, 101.00it/s]
#
# Running evaluation: 7it [00:00, 95.06it/s]
#
# Running evaluation: 7it [00:00, 89.17it/s]
#
# Running evaluation: 7it [00:00, 98.23it/s]
#
# Running evaluation: 7it [00:00, 99.29it/s]
#
# Running evaluation: 7it [00:00, 101.47it/s]
#
# Running evaluation: 7it [00:00, 101.40it/s]
#
# Running evaluation: 7it [00:00, 88.27it/s]
#
# Running evaluation: 7it [00:00, 99.57it/s]
#
# Running evaluation: 7it [00:00, 100.95it/s]
#
# Running evaluation: 7it [00:00, 102.36it/s]
#
# Running evaluation: 7it [00:00, 102.49it/s]
#
# Running evaluation: 7it [00:00, 101.66it/s]
#
# Running evaluation: 7it [00:00, 101.97it/s]
#
# Running evaluation: 7it [00:00, 102.06it/s]
#
# Running evaluation: 7it [00:00, 99.77it/s]
#
# Running evaluation: 7it [00:00, 100.40it/s]
#
# Running evaluation: 7it [00:00, 103.54it/s]
#
# Running evaluation: 7it [00:00, 102.34it/s]
#
# Running evaluation: 7it [00:00, 101.86it/s]
#
# Running evaluation: 7it [00:00, 102.92it/s]
#
# Running evaluation: 7it [00:00, 103.96it/s]
#
# Running evaluation: 7it [00:00, 104.36it/s]
#
# Running evaluation: 7it [00:00, 104.69it/s]
#
# Running evaluation: 7it [00:00, 109.49it/s]
#
# Running evaluation: 7it [00:00, 108.66it/s]
#
# Running evaluation: 7it [00:00, 109.56it/s]
#
# Running evaluation: 7it [00:00, 109.14it/s]
#
# Running evaluation: 7it [00:00, 109.02it/s]
#
# Running evaluation: 7it [00:00, 107.07it/s]
#
# Running evaluation: 7it [00:00, 108.83it/s]
#
# Running evaluation: 7it [00:00, 109.22it/s]
#
# Running evaluation: 7it [00:00, 107.90it/s]
#
# Running evaluation: 7it [00:00, 110.22it/s]
#
# Running evaluation: 7it [00:00, 109.98it/s]
#
# Running evaluation: 7it [00:00, 108.96it/s]
#
# Running evaluation: 7it [00:00, 108.75it/s]
#
# Running evaluation: 7it [00:00, 109.52it/s]
#
# Running evaluation: 7it [00:00, 107.61it/s]
#
# Running evaluation: 7it [00:00, 110.61it/s]
#
# Running evaluation: 7it [00:00, 109.64it/s]
#
# Running evaluation: 7it [00:00, 109.61it/s]
#
# Running evaluation: 7it [00:00, 109.84it/s]
#
# Running evaluation: 7it [00:00, 109.59it/s]
#
# Running evaluation: 7it [00:00, 109.11it/s]
#
# Running evaluation: 7it [00:00, 108.30it/s]
#
# Running evaluation: 7it [00:00, 109.74it/s]
#
# Running evaluation: 7it [00:00, 109.76it/s]
#
# Running evaluation: 7it [00:00, 110.02it/s]
#
# Running evaluation: 7it [00:00, 107.94it/s]
#
# Running evaluation: 7it [00:00, 57.73it/s]

# %%
print("CRPS: {}".format(agg_metric['mean_wQuantileLoss']))
print("ND: {}".format(agg_metric['ND']))
print("NRMSE: {}".format(agg_metric['NRMSE']))
print("MSE: {}".format(agg_metric['MSE']))
# Out:
# CRPS: 0.20487897906731406
# ND: 0.2679647221335116
# NRMSE: 0.5416969274362488
# MSE: 0.0008048033983747326

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
# Out:
# [rank: 0] Received SIGTERM: 15
