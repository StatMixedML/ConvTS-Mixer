# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

from pts.model.deepar import DeepAREstimator
from pts.dataset.repository.datasets import dataset_recipes
from pts.modules import StudentTOutput

# %% [markdown]
# ## Prepeare data set

# %%
dataset = get_dataset("exchange_rate_nips", regenerate=False)

# %%
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %% [markdown]
# ## Evaluator

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %% [markdown]
# ## DeepVAR

# %%
estimator = DeepAREstimator(
    distr_output=StudentTOutput(
        dim=int(dataset.metadata.feat_static_cat[0].cardinality)
    ),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    hidden_size=32,
    num_layers=3,
    dropout_rate=0.1,
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length*2,
    freq=dataset.metadata.freq,
    scaling="std",
    batch_size=64,
    trainer_kwargs=dict(max_epochs=100, accelerator="gpu"),
)

# %%
predictor = estimator.train(dataset_train, cache_data=True)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:72: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params | In sizes | Out sizes
# -------------------------------------------------------------------
# 0 | model | DeepARModel | 54.6 K | ?        | [1, 100, 30, 8]
# -------------------------------------------------------------------
# 54.6 K    Trainable params
# 0         Non-trainable params
# 54.6 K    Total params
# 0.218     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached -26.10443 (best -26.10443), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached -28.44020 (best -28.44020), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached -29.52512 (best -29.52512), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached -30.43063 (best -30.43063), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached -30.73438 (best -30.73438), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached -31.27964 (best -31.27964), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached -31.45910 (best -31.45910), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached -31.73034 (best -31.73034), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached -32.02755 (best -32.02755), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached -32.30036 (best -32.30036), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached -32.52832 (best -32.52832), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached -32.68244 (best -32.68244), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached -32.88364 (best -32.88364), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached -33.00430 (best -33.00430), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached -33.17555 (best -33.17555), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' reached -33.26943 (best -33.26943), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' reached -33.46758 (best -33.46758), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' reached -33.56785 (best -33.56785), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached -33.71267 (best -33.71267), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached -33.80451 (best -33.80451), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' reached -33.86943 (best -33.86943), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=20-step=1050.ckpt' as top 1
# Epoch 21, global step 1100: 'train_loss' reached -33.98023 (best -33.98023), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=21-step=1100.ckpt' as top 1
# Epoch 22, global step 1150: 'train_loss' reached -34.20236 (best -34.20236), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=22-step=1150.ckpt' as top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached -34.25636 (best -34.25636), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' reached -34.30274 (best -34.30274), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=25-step=1300.ckpt' as top 1
# Epoch 26, global step 1350: 'train_loss' reached -34.43959 (best -34.43959), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=26-step=1350.ckpt' as top 1
# Epoch 27, global step 1400: 'train_loss' reached -34.52160 (best -34.52160), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=27-step=1400.ckpt' as top 1
# Epoch 28, global step 1450: 'train_loss' reached -34.67607 (best -34.67607), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' was not in top 1
# Epoch 30, global step 1550: 'train_loss' reached -34.69946 (best -34.69946), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=30-step=1550.ckpt' as top 1
# Epoch 31, global step 1600: 'train_loss' reached -34.78947 (best -34.78947), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=31-step=1600.ckpt' as top 1
# Epoch 32, global step 1650: 'train_loss' reached -34.90696 (best -34.90696), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=32-step=1650.ckpt' as top 1
# Epoch 33, global step 1700: 'train_loss' reached -34.99887 (best -34.99887), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=33-step=1700.ckpt' as top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' reached -35.09481 (best -35.09481), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' reached -35.11252 (best -35.11252), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=36-step=1850.ckpt' as top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' reached -35.24989 (best -35.24989), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=38-step=1950.ckpt' as top 1
# Epoch 39, global step 2000: 'train_loss' reached -35.34038 (best -35.34038), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' reached -35.46723 (best -35.46723), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=40-step=2050.ckpt' as top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' reached -35.49531 (best -35.49531), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=42-step=2150.ckpt' as top 1
# Epoch 43, global step 2200: 'train_loss' reached -35.53367 (best -35.53367), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=43-step=2200.ckpt' as top 1
# Epoch 44, global step 2250: 'train_loss' reached -35.62321 (best -35.62321), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=44-step=2250.ckpt' as top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached -35.68811 (best -35.68811), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' reached -35.75012 (best -35.75012), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=47-step=2400.ckpt' as top 1
# Epoch 48, global step 2450: 'train_loss' reached -35.82287 (best -35.82287), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=48-step=2450.ckpt' as top 1
# Epoch 49, global step 2500: 'train_loss' reached -35.83427 (best -35.83427), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=49-step=2500.ckpt' as top 1
# Epoch 50, global step 2550: 'train_loss' reached -35.91861 (best -35.91861), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=50-step=2550.ckpt' as top 1
# Epoch 51, global step 2600: 'train_loss' reached -35.94044 (best -35.94044), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=51-step=2600.ckpt' as top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' reached -35.97837 (best -35.97837), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=53-step=2700.ckpt' as top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' reached -36.14098 (best -36.14098), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=57-step=2900.ckpt' as top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' reached -36.17826 (best -36.17826), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=60-step=3050.ckpt' as top 1
# Epoch 61, global step 3100: 'train_loss' reached -36.20168 (best -36.20168), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=61-step=3100.ckpt' as top 1
# Epoch 62, global step 3150: 'train_loss' reached -36.22519 (best -36.22519), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=62-step=3150.ckpt' as top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' reached -36.29023 (best -36.29023), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=64-step=3250.ckpt' as top 1
# Epoch 65, global step 3300: 'train_loss' was not in top 1
# Epoch 66, global step 3350: 'train_loss' reached -36.31058 (best -36.31058), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=66-step=3350.ckpt' as top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' reached -36.46291 (best -36.46291), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=69-step=3500.ckpt' as top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' reached -36.50994 (best -36.50994), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=73-step=3700.ckpt' as top 1
# Epoch 74, global step 3750: 'train_loss' reached -36.51196 (best -36.51196), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=74-step=3750.ckpt' as top 1
# Epoch 75, global step 3800: 'train_loss' reached -36.53550 (best -36.53550), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=75-step=3800.ckpt' as top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' reached -36.54951 (best -36.54951), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=77-step=3900.ckpt' as top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' reached -36.70914 (best -36.70914), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=79-step=4000.ckpt' as top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' reached -36.75122 (best -36.75122), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=81-step=4100.ckpt' as top 1
# Epoch 82, global step 4150: 'train_loss' reached -36.76532 (best -36.76532), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=82-step=4150.ckpt' as top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' reached -36.77621 (best -36.77621), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=84-step=4250.ckpt' as top 1
# Epoch 85, global step 4300: 'train_loss' reached -36.78862 (best -36.78862), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=85-step=4300.ckpt' as top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' reached -36.83853 (best -36.83853), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=87-step=4400.ckpt' as top 1
# Epoch 88, global step 4450: 'train_loss' reached -36.97020 (best -36.97020), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=88-step=4450.ckpt' as top 1
# Epoch 89, global step 4500: 'train_loss' was not in top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' was not in top 1
# Epoch 96, global step 4850: 'train_loss' reached -37.03249 (best -37.03249), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=96-step=4850.ckpt' as top 1
# Epoch 97, global step 4900: 'train_loss' reached -37.06291 (best -37.06291), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=97-step=4900.ckpt' as top 1
# Epoch 98, global step 4950: 'train_loss' reached -37.07238 (best -37.07238), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=98-step=4950.ckpt' as top 1
# Epoch 99, global step 5000: 'train_loss' reached -37.07456 (best -37.07456), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_18\\checkpoints\\epoch=99-step=5000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 5it [00:00, 71.65it/s]
# Running evaluation: 5it [00:00, 65.97it/s]
# Running evaluation: 5it [00:00, 80.86it/s]
# Running evaluation: 5it [00:00, 79.62it/s]
# Running evaluation: 5it [00:00, 79.53it/s]
# Running evaluation: 5it [00:00, 74.82it/s]
# Running evaluation: 5it [00:00, 90.98it/s]
# Running evaluation: 5it [00:00, 89.52it/s]
# Running evaluation: 5it [00:00, 82.19it/s]

# %% [markdown]
# ### Metrics

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.011280274698782004
# CRPS: 0.012964644162607432
# QL50: 0.015537237224518692
# QL90: 0.005351267624525436
# MSIS: 42.00605953438172
# NRMSE: 0.02397617658604023
# sMAPE: 0.017148530518946548
# MASE: 2.422929830707651

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
