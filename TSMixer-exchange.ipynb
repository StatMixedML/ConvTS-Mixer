# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator, aggregate_valid

from TSMixer import TSMixerEstimator

# %%
dataset = get_dataset("exchange_rate_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = TSMixerEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=3,
    dim=32,
    expansion_factor=4,
    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda", max_epochs=100),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# C:\Users\maerzale\.virtualenvs\ConvTS_Mixer-3Rl3B8jo\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type         | Params
# ---------------------------------------
# 0 | model | TSMixerModel | 105 K
# ---------------------------------------
# 105 K     Trainable params
# 0         Non-trainable params
# 105 K     Total params
# 0.421     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -2.94104 (best -2.94104), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -3.49372 (best -3.49372), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -3.61407 (best -3.61407), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -3.66570 (best -3.66570), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -3.70062 (best -3.70062), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -3.71396 (best -3.71396), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -3.73262 (best -3.73262), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -3.74260 (best -3.74260), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -3.76442 (best -3.76442), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -3.77082 (best -3.77082), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -3.77786 (best -3.77786), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -3.79292 (best -3.79292), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -3.79938 (best -3.79938), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' was not in top 1
# Epoch 14, global step 1500: 'train_loss' reached -3.82484 (best -3.82484), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' was not in top 1
# Epoch 16, global step 1700: 'train_loss' was not in top 1
# Epoch 17, global step 1800: 'train_loss' reached -3.83097 (best -3.83097), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.83978 (best -3.83978), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached -3.84003 (best -3.84003), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' reached -3.84453 (best -3.84453), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' reached -3.85908 (best -3.85908), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' was not in top 1
# Epoch 23, global step 2400: 'train_loss' reached -3.86198 (best -3.86198), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.88153 (best -3.88153), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' was not in top 1
# Epoch 26, global step 2700: 'train_loss' was not in top 1
# Epoch 27, global step 2800: 'train_loss' reached -3.88250 (best -3.88250), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=27-step=2800.ckpt' as top 1
# Epoch 28, global step 2900: 'train_loss' reached -3.88289 (best -3.88289), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=28-step=2900.ckpt' as top 1
# Epoch 29, global step 3000: 'train_loss' reached -3.90258 (best -3.90258), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=29-step=3000.ckpt' as top 1
# Epoch 30, global step 3100: 'train_loss' reached -3.90480 (best -3.90480), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=30-step=3100.ckpt' as top 1
# Epoch 31, global step 3200: 'train_loss' reached -3.91291 (best -3.91291), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=31-step=3200.ckpt' as top 1
# Epoch 32, global step 3300: 'train_loss' reached -3.91872 (best -3.91872), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=32-step=3300.ckpt' as top 1
# Epoch 33, global step 3400: 'train_loss' was not in top 1
# Epoch 34, global step 3500: 'train_loss' reached -3.92456 (best -3.92456), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=34-step=3500.ckpt' as top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.94414 (best -3.94414), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' was not in top 1
# Epoch 37, global step 3800: 'train_loss' reached -3.96476 (best -3.96476), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=37-step=3800.ckpt' as top 1
# Epoch 38, global step 3900: 'train_loss' reached -3.96587 (best -3.96587), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=38-step=3900.ckpt' as top 1
# Epoch 39, global step 4000: 'train_loss' reached -3.96640 (best -3.96640), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=39-step=4000.ckpt' as top 1
# Epoch 40, global step 4100: 'train_loss' reached -3.97553 (best -3.97553), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=40-step=4100.ckpt' as top 1
# Epoch 41, global step 4200: 'train_loss' reached -3.98414 (best -3.98414), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=41-step=4200.ckpt' as top 1
# Epoch 42, global step 4300: 'train_loss' reached -3.98815 (best -3.98815), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=42-step=4300.ckpt' as top 1
# Epoch 43, global step 4400: 'train_loss' was not in top 1
# Epoch 44, global step 4500: 'train_loss' reached -4.01288 (best -4.01288), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=44-step=4500.ckpt' as top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' reached -4.05043 (best -4.05043), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=47-step=4800.ckpt' as top 1
# Epoch 48, global step 4900: 'train_loss' reached -4.05203 (best -4.05203), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=48-step=4900.ckpt' as top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' reached -4.05696 (best -4.05696), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=50-step=5100.ckpt' as top 1
# Epoch 51, global step 5200: 'train_loss' reached -4.07430 (best -4.07430), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=51-step=5200.ckpt' as top 1
# Epoch 52, global step 5300: 'train_loss' was not in top 1
# Epoch 53, global step 5400: 'train_loss' reached -4.08026 (best -4.08026), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=53-step=5400.ckpt' as top 1
# Epoch 54, global step 5500: 'train_loss' reached -4.08588 (best -4.08588), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=54-step=5500.ckpt' as top 1
# Epoch 55, global step 5600: 'train_loss' reached -4.09642 (best -4.09642), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=55-step=5600.ckpt' as top 1
# Epoch 56, global step 5700: 'train_loss' reached -4.10781 (best -4.10781), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=56-step=5700.ckpt' as top 1
# Epoch 57, global step 5800: 'train_loss' reached -4.11520 (best -4.11520), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=57-step=5800.ckpt' as top 1
# Epoch 58, global step 5900: 'train_loss' reached -4.11637 (best -4.11637), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=58-step=5900.ckpt' as top 1
# Epoch 59, global step 6000: 'train_loss' reached -4.13308 (best -4.13308), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=59-step=6000.ckpt' as top 1
# Epoch 60, global step 6100: 'train_loss' reached -4.13457 (best -4.13457), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=60-step=6100.ckpt' as top 1
# Epoch 61, global step 6200: 'train_loss' reached -4.13629 (best -4.13629), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=61-step=6200.ckpt' as top 1
# Epoch 62, global step 6300: 'train_loss' reached -4.15534 (best -4.15534), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=62-step=6300.ckpt' as top 1
# Epoch 63, global step 6400: 'train_loss' reached -4.16291 (best -4.16291), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=63-step=6400.ckpt' as top 1
# Epoch 64, global step 6500: 'train_loss' reached -4.16990 (best -4.16990), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=64-step=6500.ckpt' as top 1
# Epoch 65, global step 6600: 'train_loss' reached -4.17164 (best -4.17164), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=65-step=6600.ckpt' as top 1
# Epoch 66, global step 6700: 'train_loss' reached -4.17835 (best -4.17835), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=66-step=6700.ckpt' as top 1
# Epoch 67, global step 6800: 'train_loss' reached -4.18826 (best -4.18826), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=67-step=6800.ckpt' as top 1
# Epoch 68, global step 6900: 'train_loss' reached -4.19672 (best -4.19672), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=68-step=6900.ckpt' as top 1
# Epoch 69, global step 7000: 'train_loss' reached -4.20149 (best -4.20149), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=69-step=7000.ckpt' as top 1
# Epoch 70, global step 7100: 'train_loss' reached -4.20966 (best -4.20966), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=70-step=7100.ckpt' as top 1
# Epoch 71, global step 7200: 'train_loss' reached -4.22976 (best -4.22976), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=71-step=7200.ckpt' as top 1
# Epoch 72, global step 7300: 'train_loss' was not in top 1
# Epoch 73, global step 7400: 'train_loss' was not in top 1
# Epoch 74, global step 7500: 'train_loss' reached -4.23501 (best -4.23501), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=74-step=7500.ckpt' as top 1
# Epoch 75, global step 7600: 'train_loss' reached -4.24314 (best -4.24314), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=75-step=7600.ckpt' as top 1
# Epoch 76, global step 7700: 'train_loss' reached -4.24818 (best -4.24818), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=76-step=7700.ckpt' as top 1
# Epoch 77, global step 7800: 'train_loss' reached -4.25401 (best -4.25401), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=77-step=7800.ckpt' as top 1
# Epoch 78, global step 7900: 'train_loss' reached -4.26135 (best -4.26135), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=78-step=7900.ckpt' as top 1
# Epoch 79, global step 8000: 'train_loss' reached -4.28044 (best -4.28044), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=79-step=8000.ckpt' as top 1
# Epoch 80, global step 8100: 'train_loss' was not in top 1
# Epoch 81, global step 8200: 'train_loss' was not in top 1
# Epoch 82, global step 8300: 'train_loss' reached -4.28606 (best -4.28606), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=82-step=8300.ckpt' as top 1
# Epoch 83, global step 8400: 'train_loss' reached -4.29288 (best -4.29288), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=83-step=8400.ckpt' as top 1
# Epoch 84, global step 8500: 'train_loss' reached -4.30271 (best -4.30271), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=84-step=8500.ckpt' as top 1
# Epoch 85, global step 8600: 'train_loss' was not in top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' reached -4.31710 (best -4.31710), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=87-step=8800.ckpt' as top 1
# Epoch 88, global step 8900: 'train_loss' reached -4.31771 (best -4.31771), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=88-step=8900.ckpt' as top 1
# Epoch 89, global step 9000: 'train_loss' reached -4.32899 (best -4.32899), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=89-step=9000.ckpt' as top 1
# Epoch 90, global step 9100: 'train_loss' reached -4.33300 (best -4.33300), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=90-step=9100.ckpt' as top 1
# Epoch 91, global step 9200: 'train_loss' was not in top 1
# Epoch 92, global step 9300: 'train_loss' reached -4.35086 (best -4.35086), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=92-step=9300.ckpt' as top 1
# Epoch 93, global step 9400: 'train_loss' was not in top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' was not in top 1
# Epoch 96, global step 9700: 'train_loss' reached -4.35447 (best -4.35447), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=96-step=9700.ckpt' as top 1
# Epoch 97, global step 9800: 'train_loss' was not in top 1
# Epoch 98, global step 9900: 'train_loss' reached -4.36083 (best -4.36083), saving model to 'C:\\Users\\maerzale\\OneDrive - adidas\\ConvTS Mixer\\lightning_logs\\version_8\\checkpoints\\epoch=98-step=9900.ckpt' as top 1
# Epoch 99, global step 10000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)
evaluator.aggregation_strategy = aggregate_valid

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 5it [00:00, 31.53it/s]
# Running evaluation: 5it [00:00, 31.93it/s]
# Running evaluation: 5it [00:00, 28.32it/s]
# Running evaluation: 5it [00:00, 30.95it/s]
# Running evaluation: 5it [00:00, 32.98it/s]
# Running evaluation: 5it [00:00, 41.43it/s]
# Running evaluation: 5it [00:00, 28.98it/s]
# Running evaluation: 5it [00:00, 22.79it/s]
# Running evaluation: 5it [00:00, 17.59it/s]

# %%
print("CRPS-Sum: {}".format(agg_metric["m_sum_mean_wQuantileLoss"]))
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("QL50: {}".format(agg_metric["wQuantileLoss[0.5]"]))
print("QL90: {}".format(agg_metric["wQuantileLoss[0.9]"]))
print("MSIS: {}".format(agg_metric["MSIS"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("sMAPE: {}".format(agg_metric["sMAPE"]))
print("MASE: {}".format(agg_metric["MASE"]))

# print("ND: {}".format(agg_metric["ND"]))
# print("NRMSE: {}".format(agg_metric["NRMSE"]))
# print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS-Sum: 0.007008023364458918
# CRPS: 0.009905885826906635
# QL50: 0.01312067185145214
# QL90: 0.004780968098742462
# MSIS: 15.877188328189112
# NRMSE: 0.022044354434065837
# sMAPE: 0.017508856157461804
# MASE: 2.3279619516349412

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
