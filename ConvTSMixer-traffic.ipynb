# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

# from pts.modules import StudentTOutput

from ConvTSMixer import ConvTSMixerEstimator
# Out:
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
dataset = get_dataset("traffic_nips", regenerate=False)
train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)

test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
estimator = ConvTSMixerEstimator(
    # distr_output=StudentTOutput(dim=int(dataset.metadata.feat_static_cat[0].cardinality)),
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 2,
    freq=dataset.metadata.freq,
    scaling="std",
    depth=4,
    patch_size=(3, 20),
    kernel_size=9,
    dim=32,
    batch_size=128,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="cuda"),
)

# %%
predictor = estimator.train(
    training_data=dataset_train,
    cache_data=True,
    shuffle_buffer_length=1024,
)
# Out:
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/py ...
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/py ...
#   rank_zero_warn(
# /nfs/homedirs/bilos/miniconda3/envs/tsmix/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | ConvTSMixerModel | 78.4 K
# -------------------------------------------
# 78.4 K    Trainable params
# 0         Non-trainable params
# 78.4 K    Total params
# 0.314     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -2.30768 (best -2.30768), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -2.74594 (best -2.74594), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -2.86162 (best -2.86162), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -2.92514 (best -2.92514), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -2.99096 (best -2.99096), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -3.05398 (best -3.05398), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -3.09778 (best -3.09778), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -3.13258 (best -3.13258), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -3.16984 (best -3.16984), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -3.19131 (best -3.19131), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -3.20959 (best -3.20959), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -3.22313 (best -3.22313), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -3.25147 (best -3.25147), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached -3.26832 (best -3.26832), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached -3.27608 (best -3.27608), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' reached -3.29409 (best -3.29409), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' reached -3.30727 (best -3.30727), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' reached -3.30801 (best -3.30801), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.32538 (best -3.32538), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached -3.33025 (best -3.33025), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' reached -3.34273 (best -3.34273), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=20-step=2100.ckpt' as top 1
# Epoch 21, global step 2200: 'train_loss' reached -3.35239 (best -3.35239), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' reached -3.35371 (best -3.35371), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=22-step=2300.ckpt' as top 1
# Epoch 23, global step 2400: 'train_loss' reached -3.36427 (best -3.36427), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.37190 (best -3.37190), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' reached -3.38275 (best -3.38275), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=25-step=2600.ckpt' as top 1
# Epoch 26, global step 2700: 'train_loss' was not in top 1
# Epoch 27, global step 2800: 'train_loss' reached -3.39164 (best -3.39164), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=27-step=2800.ckpt' as top 1
# Epoch 28, global step 2900: 'train_loss' reached -3.39194 (best -3.39194), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=28-step=2900.ckpt' as top 1
# Epoch 29, global step 3000: 'train_loss' reached -3.40872 (best -3.40872), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=29-step=3000.ckpt' as top 1
# Epoch 30, global step 3100: 'train_loss' reached -3.41186 (best -3.41186), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=30-step=3100.ckpt' as top 1
# Epoch 31, global step 3200: 'train_loss' was not in top 1
# Epoch 32, global step 3300: 'train_loss' reached -3.41590 (best -3.41590), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=32-step=3300.ckpt' as top 1
# Epoch 33, global step 3400: 'train_loss' was not in top 1
# Epoch 34, global step 3500: 'train_loss' reached -3.42192 (best -3.42192), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=34-step=3500.ckpt' as top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.42673 (best -3.42673), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' reached -3.43734 (best -3.43734), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=36-step=3700.ckpt' as top 1
# Epoch 37, global step 3800: 'train_loss' was not in top 1
# Epoch 38, global step 3900: 'train_loss' was not in top 1
# Epoch 39, global step 4000: 'train_loss' reached -3.44215 (best -3.44215), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=39-step=4000.ckpt' as top 1
# Epoch 40, global step 4100: 'train_loss' reached -3.44560 (best -3.44560), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=40-step=4100.ckpt' as top 1
# Epoch 41, global step 4200: 'train_loss' reached -3.44890 (best -3.44890), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=41-step=4200.ckpt' as top 1
# Epoch 42, global step 4300: 'train_loss' reached -3.45143 (best -3.45143), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=42-step=4300.ckpt' as top 1
# Epoch 43, global step 4400: 'train_loss' reached -3.45409 (best -3.45409), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=43-step=4400.ckpt' as top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' reached -3.45799 (best -3.45799), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=46-step=4700.ckpt' as top 1
# Epoch 47, global step 4800: 'train_loss' was not in top 1
# Epoch 48, global step 4900: 'train_loss' reached -3.46581 (best -3.46581), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=48-step=4900.ckpt' as top 1
# Epoch 49, global step 5000: 'train_loss' was not in top 1
# Epoch 50, global step 5100: 'train_loss' reached -3.46789 (best -3.46789), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=50-step=5100.ckpt' as top 1
# Epoch 51, global step 5200: 'train_loss' reached -3.46819 (best -3.46819), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=51-step=5200.ckpt' as top 1
# Epoch 52, global step 5300: 'train_loss' was not in top 1
# Epoch 53, global step 5400: 'train_loss' reached -3.47600 (best -3.47600), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=53-step=5400.ckpt' as top 1
# Epoch 54, global step 5500: 'train_loss' was not in top 1
# Epoch 55, global step 5600: 'train_loss' was not in top 1
# Epoch 56, global step 5700: 'train_loss' reached -3.48130 (best -3.48130), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=56-step=5700.ckpt' as top 1
# Epoch 57, global step 5800: 'train_loss' reached -3.48265 (best -3.48265), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=57-step=5800.ckpt' as top 1
# Epoch 58, global step 5900: 'train_loss' was not in top 1
# Epoch 59, global step 6000: 'train_loss' was not in top 1
# Epoch 60, global step 6100: 'train_loss' was not in top 1
# Epoch 61, global step 6200: 'train_loss' reached -3.48774 (best -3.48774), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=61-step=6200.ckpt' as top 1
# Epoch 62, global step 6300: 'train_loss' was not in top 1
# Epoch 63, global step 6400: 'train_loss' was not in top 1
# Epoch 64, global step 6500: 'train_loss' reached -3.48901 (best -3.48901), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=64-step=6500.ckpt' as top 1
# Epoch 65, global step 6600: 'train_loss' was not in top 1
# Epoch 66, global step 6700: 'train_loss' reached -3.49408 (best -3.49408), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=66-step=6700.ckpt' as top 1
# Epoch 67, global step 6800: 'train_loss' reached -3.49472 (best -3.49472), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=67-step=6800.ckpt' as top 1
# Epoch 68, global step 6900: 'train_loss' was not in top 1
# Epoch 69, global step 7000: 'train_loss' reached -3.49734 (best -3.49734), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=69-step=7000.ckpt' as top 1
# Epoch 70, global step 7100: 'train_loss' was not in top 1
# Epoch 71, global step 7200: 'train_loss' reached -3.50070 (best -3.50070), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=71-step=7200.ckpt' as top 1
# Epoch 72, global step 7300: 'train_loss' was not in top 1
# Epoch 73, global step 7400: 'train_loss' was not in top 1
# Epoch 74, global step 7500: 'train_loss' was not in top 1
# Epoch 75, global step 7600: 'train_loss' was not in top 1
# Epoch 76, global step 7700: 'train_loss' was not in top 1
# Epoch 77, global step 7800: 'train_loss' was not in top 1
# Epoch 78, global step 7900: 'train_loss' reached -3.50168 (best -3.50168), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=78-step=7900.ckpt' as top 1
# Epoch 79, global step 8000: 'train_loss' was not in top 1
# Epoch 80, global step 8100: 'train_loss' was not in top 1
# Epoch 81, global step 8200: 'train_loss' was not in top 1
# Epoch 82, global step 8300: 'train_loss' reached -3.50512 (best -3.50512), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=82-step=8300.ckpt' as top 1
# Epoch 83, global step 8400: 'train_loss' reached -3.50518 (best -3.50518), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=83-step=8400.ckpt' as top 1
# Epoch 84, global step 8500: 'train_loss' reached -3.50863 (best -3.50863), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=84-step=8500.ckpt' as top 1
# Epoch 85, global step 8600: 'train_loss' reached -3.50941 (best -3.50941), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=85-step=8600.ckpt' as top 1
# Epoch 86, global step 8700: 'train_loss' was not in top 1
# Epoch 87, global step 8800: 'train_loss' was not in top 1
# Epoch 88, global step 8900: 'train_loss' reached -3.51401 (best -3.51401), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=88-step=8900.ckpt' as top 1
# Epoch 89, global step 9000: 'train_loss' was not in top 1
# Epoch 90, global step 9100: 'train_loss' was not in top 1
# Epoch 91, global step 9200: 'train_loss' was not in top 1
# Epoch 92, global step 9300: 'train_loss' reached -3.51610 (best -3.51610), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=92-step=9300.ckpt' as top 1
# Epoch 93, global step 9400: 'train_loss' was not in top 1
# Epoch 94, global step 9500: 'train_loss' was not in top 1
# Epoch 95, global step 9600: 'train_loss' was not in top 1
# Epoch 96, global step 9700: 'train_loss' was not in top 1
# Epoch 97, global step 9800: 'train_loss' reached -3.51824 (best -3.51824), saving model to '/nfs/homedirs/bilos/ConvTS-Mixer/lightning_logs/version_1/checkpoints/epoch=97-step=9800.ckpt' as top 1
# Epoch 98, global step 9900: 'train_loss' was not in top 1
# Epoch 99, global step 10000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset_test, predictor=predictor, num_samples=100
)
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
evaluator = MultivariateEvaluator(
    quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
)

# %%
agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 67.05it/s]
# Running evaluation: 7it [00:00, 77.15it/s]
# Running evaluation: 7it [00:00, 79.36it/s]
# Running evaluation: 7it [00:00, 75.07it/s]
# Running evaluation: 7it [00:00, 79.64it/s]
# Running evaluation: 7it [00:00, 76.18it/s]
# Running evaluation: 7it [00:00, 79.80it/s]
# Running evaluation: 7it [00:00, 75.08it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 72.99it/s]
# Running evaluation: 7it [00:00, 78.12it/s]
# Running evaluation: 7it [00:00, 77.14it/s]
# Running evaluation: 7it [00:00, 74.96it/s]
# Running evaluation: 7it [00:00, 76.57it/s]
# Running evaluation: 7it [00:00, 77.66it/s]
# Running evaluation: 7it [00:00, 80.49it/s]
# Running evaluation: 7it [00:00, 72.71it/s]
# Running evaluation: 7it [00:00, 79.98it/s]
# Running evaluation: 7it [00:00, 80.43it/s]
# Running evaluation: 7it [00:00, 79.73it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 75.52it/s]
# Running evaluation: 7it [00:00, 80.99it/s]
# Running evaluation: 7it [00:00, 77.40it/s]
# Running evaluation: 7it [00:00, 81.07it/s]
# Running evaluation: 7it [00:00, 78.91it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 81.17it/s]
# Running evaluation: 7it [00:00, 81.11it/s]
# Running evaluation: 7it [00:00, 81.83it/s]
# Running evaluation: 7it [00:00, 80.78it/s]
# Running evaluation: 7it [00:00, 81.97it/s]
# Running evaluation: 7it [00:00, 80.77it/s]
# Running evaluation: 7it [00:00, 83.47it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 77.27it/s]
# Running evaluation: 7it [00:00, 81.14it/s]
# Running evaluation: 7it [00:00, 81.50it/s]
# Running evaluation: 7it [00:00, 79.90it/s]
# Running evaluation: 7it [00:00, 77.88it/s]
# Running evaluation: 7it [00:00, 16.28it/s]
# Running evaluation: 7it [00:00, 81.48it/s]
# Running evaluation: 7it [00:00, 79.12it/s]
# Running evaluation: 7it [00:00, 81.65it/s]
# Running evaluation: 7it [00:00, 78.63it/s]
# Running evaluation: 7it [00:00, 79.61it/s]
# Running evaluation: 7it [00:00, 77.86it/s]
# Running evaluation: 7it [00:00, 77.31it/s]
# Running evaluation: 7it [00:00, 80.47it/s]
# Running evaluation: 7it [00:00, 74.50it/s]
# Running evaluation: 7it [00:00, 81.30it/s]
# Running evaluation: 7it [00:00, 79.62it/s]
# Running evaluation: 7it [00:00, 79.01it/s]
# Running evaluation: 7it [00:00, 79.23it/s]
# Running evaluation: 7it [00:00, 80.67it/s]
# Running evaluation: 7it [00:00, 80.85it/s]
# Running evaluation: 7it [00:00, 79.38it/s]
# Running evaluation: 7it [00:00, 81.38it/s]
# Running evaluation: 7it [00:00, 78.62it/s]
# Running evaluation: 7it [00:00, 80.53it/s]
# Running evaluation: 7it [00:00, 78.48it/s]
# Running evaluation: 7it [00:00, 81.49it/s]
# Running evaluation: 7it [00:00, 78.16it/s]
# Running evaluation: 7it [00:00, 78.92it/s]
# Running evaluation: 7it [00:00, 80.43it/s]
# Running evaluation: 7it [00:00, 81.22it/s]
# Running evaluation: 7it [00:00, 79.00it/s]
# Running evaluation: 7it [00:00, 77.58it/s]
# Running evaluation: 7it [00:00, 77.93it/s]
# Running evaluation: 7it [00:00, 79.06it/s]
# Running evaluation: 7it [00:00, 82.43it/s]
# Running evaluation: 7it [00:00, 81.32it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 79.14it/s]
# Running evaluation: 7it [00:00, 80.71it/s]
# Running evaluation: 7it [00:00, 80.20it/s]
# Running evaluation: 7it [00:00, 80.33it/s]
# Running evaluation: 7it [00:00, 80.73it/s]
# Running evaluation: 7it [00:00, 79.52it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 78.97it/s]
# Running evaluation: 7it [00:00, 79.62it/s]
# Running evaluation: 7it [00:00, 78.60it/s]
# Running evaluation: 7it [00:00, 76.57it/s]
# Running evaluation: 7it [00:00, 78.58it/s]
# Running evaluation: 7it [00:00, 80.88it/s]
# Running evaluation: 7it [00:00, 81.27it/s]
# Running evaluation: 7it [00:00, 78.89it/s]
# Running evaluation: 7it [00:00, 80.80it/s]
# Running evaluation: 7it [00:00, 78.30it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 78.10it/s]
# Running evaluation: 7it [00:00, 78.31it/s]
# Running evaluation: 7it [00:00, 80.83it/s]
# Running evaluation: 7it [00:00, 79.74it/s]
# Running evaluation: 7it [00:00, 79.57it/s]
# Running evaluation: 7it [00:00, 77.42it/s]
# Running evaluation: 7it [00:00, 81.19it/s]
# Running evaluation: 7it [00:00, 77.77it/s]
# Running evaluation: 7it [00:00, 81.64it/s]
# Running evaluation: 7it [00:00, 80.59it/s]
# Running evaluation: 7it [00:00, 80.37it/s]
# Running evaluation: 7it [00:00, 79.11it/s]
# Running evaluation: 7it [00:00, 81.76it/s]
# Running evaluation: 7it [00:00, 80.31it/s]
# Running evaluation: 7it [00:00, 73.01it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 72.68it/s]
# Running evaluation: 7it [00:00, 25.38it/s]
# Running evaluation: 7it [00:00, 81.14it/s]
# Running evaluation: 7it [00:00, 79.96it/s]
# Running evaluation: 7it [00:00, 78.46it/s]
# Running evaluation: 7it [00:00, 80.34it/s]
# Running evaluation: 7it [00:00, 81.22it/s]
# Running evaluation: 7it [00:00, 76.07it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 75.00it/s]
# Running evaluation: 7it [00:00, 81.17it/s]
# Running evaluation: 7it [00:00, 78.49it/s]
# Running evaluation: 7it [00:00, 82.37it/s]
# Running evaluation: 7it [00:00, 80.25it/s]
# Running evaluation: 7it [00:00, 81.82it/s]
# Running evaluation: 7it [00:00, 79.44it/s]
# Running evaluation: 7it [00:00, 79.91it/s]
# Running evaluation: 7it [00:00, 78.54it/s]
# Running evaluation: 7it [00:00, 77.06it/s]
# Running evaluation: 7it [00:00, 79.52it/s]
# Running evaluation: 7it [00:00, 79.98it/s]
# Running evaluation: 7it [00:00, 80.88it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 79.26it/s]
# Running evaluation: 7it [00:00, 76.40it/s]
# Running evaluation: 7it [00:00, 82.30it/s]
# Running evaluation: 7it [00:00, 79.78it/s]
# Running evaluation: 7it [00:00, 77.17it/s]
# Running evaluation: 7it [00:00, 79.58it/s]
# Running evaluation: 7it [00:00, 81.53it/s]
# Running evaluation: 7it [00:00, 80.85it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 79.54it/s]
# Running evaluation: 7it [00:00, 80.98it/s]
# Running evaluation: 7it [00:00, 80.95it/s]
# Running evaluation: 7it [00:00, 78.85it/s]
# Running evaluation: 7it [00:00, 80.33it/s]
# Running evaluation: 7it [00:00, 77.88it/s]
# Running evaluation: 7it [00:00, 80.70it/s]
# Running evaluation: 7it [00:00, 79.16it/s]
# Running evaluation: 7it [00:00, 80.63it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 79.10it/s]
# Running evaluation: 7it [00:00, 79.75it/s]
# Running evaluation: 7it [00:00, 79.48it/s]
# Running evaluation: 7it [00:00, 79.57it/s]
# Running evaluation: 7it [00:00, 82.36it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 78.40it/s]
# Running evaluation: 7it [00:00, 79.85it/s]
# Running evaluation: 7it [00:00, 75.90it/s]
# Running evaluation: 7it [00:00, 78.59it/s]
# Running evaluation: 7it [00:00, 78.31it/s]
# Running evaluation: 7it [00:00, 76.05it/s]
# Running evaluation: 7it [00:00, 79.52it/s]
# Running evaluation: 7it [00:00, 79.94it/s]
# Running evaluation: 7it [00:00, 78.69it/s]
# Running evaluation: 7it [00:00, 80.11it/s]
# Running evaluation: 7it [00:00, 81.50it/s]
# Running evaluation: 7it [00:00, 77.24it/s]
# Running evaluation: 7it [00:00, 80.51it/s]
# Running evaluation: 7it [00:00, 78.49it/s]
# Running evaluation: 7it [00:00, 80.14it/s]
# Running evaluation: 7it [00:00, 80.94it/s]
# Running evaluation: 7it [00:00, 79.11it/s]
# Running evaluation: 7it [00:00, 81.59it/s]
# Running evaluation: 7it [00:00, 78.07it/s]
# Running evaluation: 7it [00:00, 81.66it/s]
# Running evaluation: 7it [00:00, 80.72it/s]
# Running evaluation: 7it [00:00, 82.45it/s]
# Running evaluation: 7it [00:00, 75.91it/s]
# Running evaluation: 7it [00:00, 77.70it/s]
# Running evaluation: 7it [00:00, 82.07it/s]
# Running evaluation: 7it [00:00, 78.53it/s]
# Running evaluation: 7it [00:00, 81.24it/s]
# Running evaluation: 7it [00:00, 74.59it/s]
# Running evaluation: 7it [00:00, 79.29it/s]
# Running evaluation: 7it [00:00, 79.40it/s]
# Running evaluation: 7it [00:00, 80.18it/s]
# Running evaluation: 7it [00:00, 78.05it/s]
# Running evaluation: 7it [00:00, 77.86it/s]
# Running evaluation: 7it [00:00, 79.60it/s]
# Running evaluation: 7it [00:00, 79.47it/s]
# Running evaluation: 7it [00:00, 79.05it/s]
# Running evaluation: 7it [00:00, 76.76it/s]
# Running evaluation: 7it [00:00, 77.31it/s]
# Running evaluation: 7it [00:00, 80.28it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 79.86it/s]
# Running evaluation: 7it [00:00, 79.66it/s]
# Running evaluation: 7it [00:00, 81.86it/s]
# Running evaluation: 7it [00:00, 78.68it/s]
# Running evaluation: 7it [00:00, 79.95it/s]
# Running evaluation: 7it [00:00, 79.35it/s]
# Running evaluation: 7it [00:00, 79.66it/s]
# Running evaluation: 7it [00:00, 78.39it/s]
# Running evaluation: 7it [00:00, 80.57it/s]
# Running evaluation: 7it [00:00, 76.09it/s]
# Running evaluation: 7it [00:00, 77.47it/s]
# Running evaluation: 7it [00:00, 80.63it/s]
# Running evaluation: 7it [00:00, 79.65it/s]
# Running evaluation: 7it [00:00, 79.36it/s]
# Running evaluation: 7it [00:00, 79.85it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 78.80it/s]
# Running evaluation: 7it [00:00, 80.21it/s]
# Running evaluation: 7it [00:00, 82.44it/s]
# Running evaluation: 7it [00:00, 79.90it/s]
# Running evaluation: 7it [00:00, 80.88it/s]
# Running evaluation: 7it [00:00, 76.86it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 80.90it/s]
# Running evaluation: 7it [00:00, 79.26it/s]
# Running evaluation: 7it [00:00, 79.25it/s]
# Running evaluation: 7it [00:00, 79.63it/s]
# Running evaluation: 7it [00:00, 80.13it/s]
# Running evaluation: 7it [00:00, 79.87it/s]
# Running evaluation: 7it [00:00, 78.05it/s]
# Running evaluation: 7it [00:00, 81.38it/s]
# Running evaluation: 7it [00:00, 76.56it/s]
# Running evaluation: 7it [00:00, 81.79it/s]
# Running evaluation: 7it [00:00, 77.59it/s]
# Running evaluation: 7it [00:00, 80.11it/s]
# Running evaluation: 7it [00:00, 79.38it/s]
# Running evaluation: 7it [00:00, 75.43it/s]
# Running evaluation: 7it [00:00, 79.65it/s]
# Running evaluation: 7it [00:00, 81.01it/s]
# Running evaluation: 7it [00:00, 80.26it/s]
# Running evaluation: 7it [00:00, 76.94it/s]
# Running evaluation: 7it [00:00, 80.49it/s]
# Running evaluation: 7it [00:00, 80.81it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 79.09it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 79.15it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 81.43it/s]
# Running evaluation: 7it [00:00, 80.28it/s]
# Running evaluation: 7it [00:00, 82.75it/s]
# Running evaluation: 7it [00:00, 82.14it/s]
# Running evaluation: 7it [00:00, 81.91it/s]
# Running evaluation: 7it [00:00, 78.57it/s]
# Running evaluation: 7it [00:00, 81.57it/s]
# Running evaluation: 7it [00:00, 79.05it/s]
# Running evaluation: 7it [00:00, 80.54it/s]
# Running evaluation: 7it [00:00, 80.09it/s]
# Running evaluation: 7it [00:00, 81.60it/s]
# Running evaluation: 7it [00:00, 78.67it/s]
# Running evaluation: 7it [00:00, 80.24it/s]
# Running evaluation: 7it [00:00, 81.68it/s]
# Running evaluation: 7it [00:00, 77.71it/s]
# Running evaluation: 7it [00:00, 77.78it/s]
# Running evaluation: 7it [00:00, 79.14it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 78.43it/s]
# Running evaluation: 7it [00:00, 78.51it/s]
# Running evaluation: 7it [00:00, 80.28it/s]
# Running evaluation: 7it [00:00, 80.32it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 78.60it/s]
# Running evaluation: 7it [00:00, 77.81it/s]
# Running evaluation: 7it [00:00, 79.36it/s]
# Running evaluation: 7it [00:00, 80.84it/s]
# Running evaluation: 7it [00:00, 80.37it/s]
# Running evaluation: 7it [00:00, 80.95it/s]
# Running evaluation: 7it [00:00, 79.68it/s]
# Running evaluation: 7it [00:00, 78.57it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 77.19it/s]
# Running evaluation: 7it [00:00, 74.58it/s]
# Running evaluation: 7it [00:00, 80.77it/s]
# Running evaluation: 7it [00:00, 80.61it/s]
# Running evaluation: 7it [00:00, 77.57it/s]
# Running evaluation: 7it [00:00, 77.94it/s]
# Running evaluation: 7it [00:00, 80.62it/s]
# Running evaluation: 7it [00:00, 80.09it/s]
# Running evaluation: 7it [00:00, 81.17it/s]
# Running evaluation: 7it [00:00, 79.51it/s]
# Running evaluation: 7it [00:00, 80.14it/s]
# Running evaluation: 7it [00:00, 80.15it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 80.59it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 81.58it/s]
# Running evaluation: 7it [00:00, 79.03it/s]
# Running evaluation: 7it [00:00, 82.17it/s]
# Running evaluation: 7it [00:00, 78.30it/s]
# Running evaluation: 7it [00:00, 80.73it/s]
# Running evaluation: 7it [00:00, 79.32it/s]
# Running evaluation: 7it [00:00, 78.87it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 75.53it/s]
# Running evaluation: 7it [00:00, 79.25it/s]
# Running evaluation: 7it [00:00, 77.17it/s]
# Running evaluation: 7it [00:00, 79.96it/s]
# Running evaluation: 7it [00:00, 78.32it/s]
# Running evaluation: 7it [00:00, 79.36it/s]
# Running evaluation: 7it [00:00, 79.67it/s]
# Running evaluation: 7it [00:00, 80.62it/s]
# Running evaluation: 7it [00:00, 79.74it/s]
# Running evaluation: 7it [00:00, 81.26it/s]
# Running evaluation: 7it [00:00, 79.65it/s]
# Running evaluation: 7it [00:00, 81.31it/s]
# Running evaluation: 7it [00:00, 82.17it/s]
# Running evaluation: 7it [00:00, 81.25it/s]
# Running evaluation: 7it [00:00, 80.00it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 79.35it/s]
# Running evaluation: 7it [00:00, 81.20it/s]
# Running evaluation: 7it [00:00, 80.48it/s]
# Running evaluation: 7it [00:00, 80.28it/s]
# Running evaluation: 7it [00:00, 82.49it/s]
# Running evaluation: 7it [00:00, 78.23it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 78.70it/s]
# Running evaluation: 7it [00:00, 78.26it/s]
# Running evaluation: 7it [00:00, 82.33it/s]
# Running evaluation: 7it [00:00, 79.42it/s]
# Running evaluation: 7it [00:00, 80.81it/s]
# Running evaluation: 7it [00:00, 75.53it/s]
# Running evaluation: 7it [00:00, 81.25it/s]
# Running evaluation: 7it [00:00, 79.19it/s]
# Running evaluation: 7it [00:00, 82.10it/s]
# Running evaluation: 7it [00:00, 79.89it/s]
# Running evaluation: 7it [00:00, 81.57it/s]
# Running evaluation: 7it [00:00, 77.09it/s]
# Running evaluation: 7it [00:00, 78.07it/s]
# Running evaluation: 7it [00:00, 81.53it/s]
# Running evaluation: 7it [00:00, 79.48it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 77.19it/s]
# Running evaluation: 7it [00:00, 79.41it/s]
# Running evaluation: 7it [00:00, 77.57it/s]
# Running evaluation: 7it [00:00, 82.27it/s]
# Running evaluation: 7it [00:00, 80.26it/s]
# Running evaluation: 7it [00:00, 79.79it/s]
# Running evaluation: 7it [00:00, 78.16it/s]
# Running evaluation: 7it [00:00, 77.70it/s]
# Running evaluation: 7it [00:00, 77.78it/s]
# Running evaluation: 7it [00:00, 78.89it/s]
# Running evaluation: 7it [00:00, 81.02it/s]
# Running evaluation: 7it [00:00, 77.58it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 81.20it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 81.61it/s]
# Running evaluation: 7it [00:00, 77.85it/s]
# Running evaluation: 7it [00:00, 79.68it/s]
# Running evaluation: 7it [00:00, 79.11it/s]
# Running evaluation: 7it [00:00, 81.69it/s]
# Running evaluation: 7it [00:00, 77.86it/s]
# Running evaluation: 7it [00:00, 79.00it/s]
# Running evaluation: 7it [00:00, 80.65it/s]
# Running evaluation: 7it [00:00, 80.78it/s]
# Running evaluation: 7it [00:00, 81.88it/s]
# Running evaluation: 7it [00:00, 75.76it/s]
# Running evaluation: 7it [00:00, 80.35it/s]
# Running evaluation: 7it [00:00, 78.25it/s]
# Running evaluation: 7it [00:00, 80.42it/s]
# Running evaluation: 7it [00:00, 79.60it/s]
# Running evaluation: 7it [00:00, 80.37it/s]
# Running evaluation: 7it [00:00, 79.46it/s]
# Running evaluation: 7it [00:00, 80.10it/s]
# Running evaluation: 7it [00:00, 81.34it/s]
# Running evaluation: 7it [00:00, 78.95it/s]
# Running evaluation: 7it [00:00, 79.23it/s]
# Running evaluation: 7it [00:00, 78.51it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 77.58it/s]
# Running evaluation: 7it [00:00, 82.54it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 79.49it/s]
# Running evaluation: 7it [00:00, 79.31it/s]
# Running evaluation: 7it [00:00, 78.16it/s]
# Running evaluation: 7it [00:00, 80.04it/s]
# Running evaluation: 7it [00:00, 79.35it/s]
# Running evaluation: 7it [00:00, 81.49it/s]
# Running evaluation: 7it [00:00, 78.99it/s]
# Running evaluation: 7it [00:00, 79.73it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 79.02it/s]
# Running evaluation: 7it [00:00, 82.88it/s]
# Running evaluation: 7it [00:00, 82.22it/s]
# Running evaluation: 7it [00:00, 79.91it/s]
# Running evaluation: 7it [00:00, 80.67it/s]
# Running evaluation: 7it [00:00, 75.86it/s]
# Running evaluation: 7it [00:00, 81.16it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 82.64it/s]
# Running evaluation: 7it [00:00, 82.47it/s]
# Running evaluation: 7it [00:00, 81.92it/s]
# Running evaluation: 7it [00:00, 82.74it/s]
# Running evaluation: 7it [00:00, 81.69it/s]
# Running evaluation: 7it [00:00, 76.68it/s]
# Running evaluation: 7it [00:00, 75.05it/s]
# Running evaluation: 7it [00:00, 80.36it/s]
# Running evaluation: 7it [00:00, 78.31it/s]
# Running evaluation: 7it [00:00, 80.53it/s]
# Running evaluation: 7it [00:00, 77.43it/s]
# Running evaluation: 7it [00:00, 79.35it/s]
# Running evaluation: 7it [00:00, 79.60it/s]
# Running evaluation: 7it [00:00, 81.31it/s]
# Running evaluation: 7it [00:00, 79.22it/s]
# Running evaluation: 7it [00:00, 79.98it/s]
# Running evaluation: 7it [00:00, 81.29it/s]
# Running evaluation: 7it [00:00, 79.41it/s]
# Running evaluation: 7it [00:00, 78.48it/s]
# Running evaluation: 7it [00:00, 77.29it/s]
# Running evaluation: 7it [00:00, 80.13it/s]
# Running evaluation: 7it [00:00, 82.53it/s]
# Running evaluation: 7it [00:00, 77.23it/s]
# Running evaluation: 7it [00:00, 78.70it/s]
# Running evaluation: 7it [00:00, 79.22it/s]
# Running evaluation: 7it [00:00, 80.23it/s]
# Running evaluation: 7it [00:00, 79.72it/s]
# Running evaluation: 7it [00:00, 75.31it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 75.71it/s]
# Running evaluation: 7it [00:00, 81.11it/s]
# Running evaluation: 7it [00:00, 81.16it/s]
# Running evaluation: 7it [00:00, 82.85it/s]
# Running evaluation: 7it [00:00, 79.23it/s]
# Running evaluation: 7it [00:00, 80.03it/s]
# Running evaluation: 7it [00:00, 81.57it/s]
# Running evaluation: 7it [00:00, 80.30it/s]
# Running evaluation: 7it [00:00, 75.47it/s]
# Running evaluation: 7it [00:00, 78.72it/s]
# Running evaluation: 7it [00:00, 78.57it/s]
# Running evaluation: 7it [00:00, 78.49it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 81.13it/s]
# Running evaluation: 7it [00:00, 76.41it/s]
# Running evaluation: 7it [00:00, 82.22it/s]
# Running evaluation: 7it [00:00, 80.03it/s]
# Running evaluation: 7it [00:00, 81.75it/s]
# Running evaluation: 7it [00:00, 78.29it/s]
# Running evaluation: 7it [00:00, 78.87it/s]
# Running evaluation: 7it [00:00, 80.46it/s]
# Running evaluation: 7it [00:00, 80.96it/s]
# Running evaluation: 7it [00:00, 81.69it/s]
# Running evaluation: 7it [00:00, 78.39it/s]
# Running evaluation: 7it [00:00, 81.29it/s]
# Running evaluation: 7it [00:00, 81.56it/s]
# Running evaluation: 7it [00:00, 81.11it/s]
# Running evaluation: 7it [00:00, 82.93it/s]
# Running evaluation: 7it [00:00, 79.18it/s]
# Running evaluation: 7it [00:00, 80.94it/s]
# Running evaluation: 7it [00:00, 77.41it/s]
# Running evaluation: 7it [00:00, 81.81it/s]
# Running evaluation: 7it [00:00, 79.22it/s]
# Running evaluation: 7it [00:00, 83.40it/s]
# Running evaluation: 7it [00:00, 81.26it/s]
# Running evaluation: 7it [00:00, 82.54it/s]
# Running evaluation: 7it [00:00, 81.62it/s]
# Running evaluation: 7it [00:00, 80.60it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 79.81it/s]
# Running evaluation: 7it [00:00, 80.59it/s]
# Running evaluation: 7it [00:00, 80.78it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 76.19it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 80.16it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 78.29it/s]
# Running evaluation: 7it [00:00, 80.41it/s]
# Running evaluation: 7it [00:00, 81.23it/s]
# Running evaluation: 7it [00:00, 74.49it/s]
# Running evaluation: 7it [00:00, 80.30it/s]
# Running evaluation: 7it [00:00, 80.20it/s]
# Running evaluation: 7it [00:00, 78.42it/s]
# Running evaluation: 7it [00:00, 81.90it/s]
# Running evaluation: 7it [00:00, 78.68it/s]
# Running evaluation: 7it [00:00, 79.65it/s]
# Running evaluation: 7it [00:00, 77.66it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 78.69it/s]
# Running evaluation: 7it [00:00, 78.92it/s]
# Running evaluation: 7it [00:00, 81.32it/s]
# Running evaluation: 7it [00:00, 80.41it/s]
# Running evaluation: 7it [00:00, 81.71it/s]
# Running evaluation: 7it [00:00, 77.95it/s]
# Running evaluation: 7it [00:00, 81.42it/s]
# Running evaluation: 7it [00:00, 76.40it/s]
# Running evaluation: 7it [00:00, 71.66it/s]
# Running evaluation: 7it [00:00, 78.97it/s]
# Running evaluation: 7it [00:00, 81.49it/s]
# Running evaluation: 7it [00:00, 81.12it/s]
# Running evaluation: 7it [00:00, 79.34it/s]
# Running evaluation: 7it [00:00, 81.80it/s]
# Running evaluation: 7it [00:00, 78.86it/s]
# Running evaluation: 7it [00:00, 78.94it/s]
# Running evaluation: 7it [00:00, 81.64it/s]
# Running evaluation: 7it [00:00, 80.07it/s]
# Running evaluation: 7it [00:00, 81.00it/s]
# Running evaluation: 7it [00:00, 80.38it/s]
# Running evaluation: 7it [00:00, 80.46it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 82.44it/s]
# Running evaluation: 7it [00:00, 78.84it/s]
# Running evaluation: 7it [00:00, 81.56it/s]
# Running evaluation: 7it [00:00, 78.16it/s]
# Running evaluation: 7it [00:00, 80.78it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 79.61it/s]
# Running evaluation: 7it [00:00, 80.25it/s]
# Running evaluation: 7it [00:00, 80.63it/s]
# Running evaluation: 7it [00:00, 81.22it/s]
# Running evaluation: 7it [00:00, 75.45it/s]
# Running evaluation: 7it [00:00, 80.89it/s]
# Running evaluation: 7it [00:00, 79.24it/s]
# Running evaluation: 7it [00:00, 81.47it/s]
# Running evaluation: 7it [00:00, 78.69it/s]
# Running evaluation: 7it [00:00, 80.51it/s]
# Running evaluation: 7it [00:00, 77.60it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 81.52it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 79.43it/s]
# Running evaluation: 7it [00:00, 79.86it/s]
# Running evaluation: 7it [00:00, 80.12it/s]
# Running evaluation: 7it [00:00, 79.82it/s]
# Running evaluation: 7it [00:00, 78.75it/s]
# Running evaluation: 7it [00:00, 80.44it/s]
# Running evaluation: 7it [00:00, 81.41it/s]
# Running evaluation: 7it [00:00, 80.89it/s]
# Running evaluation: 7it [00:00, 80.49it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 80.02it/s]
# Running evaluation: 7it [00:00, 80.29it/s]
# Running evaluation: 7it [00:00, 81.81it/s]
# Running evaluation: 7it [00:00, 82.14it/s]
# Running evaluation: 7it [00:00, 81.86it/s]
# Running evaluation: 7it [00:00, 81.46it/s]
# Running evaluation: 7it [00:00, 78.07it/s]
# Running evaluation: 7it [00:00, 79.79it/s]
# Running evaluation: 7it [00:00, 80.41it/s]
# Running evaluation: 7it [00:00, 80.11it/s]
# Running evaluation: 7it [00:00, 80.82it/s]
# Running evaluation: 7it [00:00, 75.02it/s]
# Running evaluation: 7it [00:00, 83.04it/s]
# Running evaluation: 7it [00:00, 78.94it/s]
# Running evaluation: 7it [00:00, 82.21it/s]
# Running evaluation: 7it [00:00, 80.51it/s]
# Running evaluation: 7it [00:00, 81.29it/s]
# Running evaluation: 7it [00:00, 80.44it/s]
# Running evaluation: 7it [00:00, 74.12it/s]
# Running evaluation: 7it [00:00, 81.17it/s]
# Running evaluation: 7it [00:00, 76.91it/s]
# Running evaluation: 7it [00:00, 81.59it/s]
# Running evaluation: 7it [00:00, 79.75it/s]
# Running evaluation: 7it [00:00, 79.84it/s]
# Running evaluation: 7it [00:00, 77.50it/s]
# Running evaluation: 7it [00:00, 81.35it/s]
# Running evaluation: 7it [00:00, 80.61it/s]
# Running evaluation: 7it [00:00, 79.92it/s]
# Running evaluation: 7it [00:00, 72.03it/s]
# Running evaluation: 7it [00:00, 76.82it/s]
# Running evaluation: 7it [00:00, 80.24it/s]
# Running evaluation: 7it [00:00, 83.48it/s]
# Running evaluation: 7it [00:00, 80.20it/s]
# Running evaluation: 7it [00:00, 79.96it/s]
# Running evaluation: 7it [00:00, 81.73it/s]
# Running evaluation: 7it [00:00, 81.25it/s]
# Running evaluation: 7it [00:00, 81.42it/s]
# Running evaluation: 7it [00:00, 79.74it/s]
# Running evaluation: 7it [00:00, 80.60it/s]
# Running evaluation: 7it [00:00, 80.56it/s]
# Running evaluation: 7it [00:00, 80.10it/s]
# Running evaluation: 7it [00:00, 74.74it/s]
# Running evaluation: 7it [00:00, 79.46it/s]
# Running evaluation: 7it [00:00, 79.64it/s]
# Running evaluation: 7it [00:00, 80.18it/s]
# Running evaluation: 7it [00:00, 80.35it/s]
# Running evaluation: 7it [00:00, 82.01it/s]
# Running evaluation: 7it [00:00, 79.37it/s]
# Running evaluation: 7it [00:00, 80.59it/s]
# Running evaluation: 7it [00:00, 78.46it/s]
# Running evaluation: 7it [00:00, 82.06it/s]
# Running evaluation: 7it [00:00, 79.57it/s]
# Running evaluation: 7it [00:00, 81.99it/s]
# Running evaluation: 7it [00:00, 79.46it/s]
# Running evaluation: 7it [00:00, 81.74it/s]
# Running evaluation: 7it [00:00, 77.54it/s]
# Running evaluation: 7it [00:00, 80.33it/s]
# Running evaluation: 7it [00:00, 79.17it/s]
# Running evaluation: 7it [00:00, 81.41it/s]
# Running evaluation: 7it [00:00, 79.72it/s]
# Running evaluation: 7it [00:00, 79.14it/s]
# Running evaluation: 7it [00:00, 80.45it/s]
# Running evaluation: 7it [00:00, 78.01it/s]
# Running evaluation: 7it [00:00, 81.45it/s]
# Running evaluation: 7it [00:00, 79.78it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 14.19it/s]
# Running evaluation: 7it [00:00, 79.61it/s]
# Running evaluation: 7it [00:00, 77.63it/s]
# Running evaluation: 7it [00:00, 77.69it/s]
# Running evaluation: 7it [00:00, 80.24it/s]
# Running evaluation: 7it [00:00, 79.96it/s]
# Running evaluation: 7it [00:00, 75.77it/s]
# Running evaluation: 7it [00:00, 80.46it/s]
# Running evaluation: 7it [00:00, 77.83it/s]
# Running evaluation: 7it [00:00, 80.37it/s]
# Running evaluation: 7it [00:00, 76.33it/s]
# Running evaluation: 7it [00:00, 82.34it/s]
# Running evaluation: 7it [00:00, 80.53it/s]
# Running evaluation: 7it [00:00, 81.64it/s]
# Running evaluation: 7it [00:00, 81.51it/s]
# Running evaluation: 7it [00:00, 79.25it/s]
# Running evaluation: 7it [00:00, 80.94it/s]
# Running evaluation: 7it [00:00, 76.47it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 81.18it/s]
# Running evaluation: 7it [00:00, 82.88it/s]
# Running evaluation: 7it [00:00, 78.79it/s]
# Running evaluation: 7it [00:00, 81.93it/s]
# Running evaluation: 7it [00:00, 79.60it/s]
# Running evaluation: 7it [00:00, 80.99it/s]
# Running evaluation: 7it [00:00, 79.73it/s]
# Running evaluation: 7it [00:00, 80.80it/s]
# Running evaluation: 7it [00:00, 80.50it/s]
# Running evaluation: 7it [00:00, 78.18it/s]
# Running evaluation: 7it [00:00, 75.35it/s]
# Running evaluation: 7it [00:00, 79.02it/s]
# Running evaluation: 7it [00:00, 77.58it/s]
# Running evaluation: 7it [00:00, 80.62it/s]
# Running evaluation: 7it [00:00, 79.04it/s]
# Running evaluation: 7it [00:00, 80.89it/s]
# Running evaluation: 7it [00:00, 79.46it/s]
# Running evaluation: 7it [00:00, 79.97it/s]
# Running evaluation: 7it [00:00, 79.49it/s]
# Running evaluation: 7it [00:00, 79.95it/s]
# Running evaluation: 7it [00:00, 80.03it/s]
# Running evaluation: 7it [00:00, 81.02it/s]
# Running evaluation: 7it [00:00, 79.53it/s]
# Running evaluation: 7it [00:00, 75.84it/s]
# Running evaluation: 7it [00:00, 79.75it/s]
# Running evaluation: 7it [00:00, 80.29it/s]
# Running evaluation: 7it [00:00, 78.70it/s]
# Running evaluation: 7it [00:00, 81.01it/s]
# Running evaluation: 7it [00:00, 80.14it/s]
# Running evaluation: 7it [00:00, 80.61it/s]
# Running evaluation: 7it [00:00, 78.31it/s]
# Running evaluation: 7it [00:00, 79.51it/s]
# Running evaluation: 7it [00:00, 80.10it/s]
# Running evaluation: 7it [00:00, 74.76it/s]
# Running evaluation: 7it [00:00, 80.75it/s]
# Running evaluation: 7it [00:00, 78.89it/s]
# Running evaluation: 7it [00:00, 81.95it/s]
# Running evaluation: 7it [00:00, 78.66it/s]
# Running evaluation: 7it [00:00, 81.84it/s]
# Running evaluation: 7it [00:00, 78.22it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 78.82it/s]
# Running evaluation: 7it [00:00, 79.95it/s]
# Running evaluation: 7it [00:00, 79.74it/s]
# Running evaluation: 7it [00:00, 78.19it/s]
# Running evaluation: 7it [00:00, 80.80it/s]
# Running evaluation: 7it [00:00, 78.00it/s]
# Running evaluation: 7it [00:00, 80.89it/s]
# Running evaluation: 7it [00:00, 76.65it/s]
# Running evaluation: 7it [00:00, 81.64it/s]
# Running evaluation: 7it [00:00, 81.26it/s]
# Running evaluation: 7it [00:00, 82.81it/s]
# Running evaluation: 7it [00:00, 80.61it/s]
# Running evaluation: 7it [00:00, 82.00it/s]
# Running evaluation: 7it [00:00, 77.52it/s]
# Running evaluation: 7it [00:00, 77.36it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 79.56it/s]
# Running evaluation: 7it [00:00, 80.60it/s]
# Running evaluation: 7it [00:00, 81.19it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 79.72it/s]
# Running evaluation: 7it [00:00, 80.84it/s]
# Running evaluation: 7it [00:00, 73.16it/s]
# Running evaluation: 7it [00:00, 79.48it/s]
# Running evaluation: 7it [00:00, 81.49it/s]
# Running evaluation: 7it [00:00, 78.80it/s]
# Running evaluation: 7it [00:00, 77.30it/s]
# Running evaluation: 7it [00:00, 77.28it/s]
# Running evaluation: 7it [00:00, 80.20it/s]
# Running evaluation: 7it [00:00, 81.58it/s]
# Running evaluation: 7it [00:00, 78.56it/s]
# Running evaluation: 7it [00:00, 81.27it/s]
# Running evaluation: 7it [00:00, 79.73it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 81.10it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 77.09it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 80.95it/s]
# Running evaluation: 7it [00:00, 80.93it/s]
# Running evaluation: 7it [00:00, 77.71it/s]
# Running evaluation: 7it [00:00, 81.70it/s]
# Running evaluation: 7it [00:00, 81.93it/s]
# Running evaluation: 7it [00:00, 80.49it/s]
# Running evaluation: 7it [00:00, 80.56it/s]
# Running evaluation: 7it [00:00, 79.14it/s]
# Running evaluation: 7it [00:00, 79.91it/s]
# Running evaluation: 7it [00:00, 82.41it/s]
# Running evaluation: 7it [00:00, 78.32it/s]
# Running evaluation: 7it [00:00, 81.02it/s]
# Running evaluation: 7it [00:00, 76.67it/s]
# Running evaluation: 7it [00:00, 80.81it/s]
# Running evaluation: 7it [00:00, 79.55it/s]
# Running evaluation: 7it [00:00, 79.22it/s]
# Running evaluation: 7it [00:00, 81.31it/s]
# Running evaluation: 7it [00:00, 79.40it/s]
# Running evaluation: 7it [00:00, 79.31it/s]
# Running evaluation: 7it [00:00, 74.28it/s]
# Running evaluation: 7it [00:00, 81.79it/s]
# Running evaluation: 7it [00:00, 79.69it/s]
# Running evaluation: 7it [00:00, 81.98it/s]
# Running evaluation: 7it [00:00, 80.25it/s]
# Running evaluation: 7it [00:00, 80.28it/s]
# Running evaluation: 7it [00:00, 77.76it/s]
# Running evaluation: 7it [00:00, 81.00it/s]
# Running evaluation: 7it [00:00, 80.85it/s]
# Running evaluation: 7it [00:00, 80.93it/s]
# Running evaluation: 7it [00:00, 81.51it/s]
# Running evaluation: 7it [00:00, 79.56it/s]
# Running evaluation: 7it [00:00, 78.86it/s]
# Running evaluation: 7it [00:00, 80.07it/s]
# Running evaluation: 7it [00:00, 79.76it/s]
# Running evaluation: 7it [00:00, 79.87it/s]
# Running evaluation: 7it [00:00, 79.97it/s]
# Running evaluation: 7it [00:00, 79.79it/s]
# Running evaluation: 7it [00:00, 78.19it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 80.73it/s]
# Running evaluation: 7it [00:00, 81.00it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 78.35it/s]
# Running evaluation: 7it [00:00, 81.66it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 82.05it/s]
# Running evaluation: 7it [00:00, 81.30it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 79.98it/s]
# Running evaluation: 7it [00:00, 83.12it/s]
# Running evaluation: 7it [00:00, 72.37it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 78.01it/s]
# Running evaluation: 7it [00:00, 78.60it/s]
# Running evaluation: 7it [00:00, 81.84it/s]
# Running evaluation: 7it [00:00, 81.37it/s]
# Running evaluation: 7it [00:00, 78.92it/s]
# Running evaluation: 7it [00:00, 80.69it/s]
# Running evaluation: 7it [00:00, 80.82it/s]
# Running evaluation: 7it [00:00, 76.69it/s]
# Running evaluation: 7it [00:00, 81.82it/s]
# Running evaluation: 7it [00:00, 80.90it/s]
# Running evaluation: 7it [00:00, 80.70it/s]
# Running evaluation: 7it [00:00, 81.85it/s]
# Running evaluation: 7it [00:00, 74.87it/s]
# Running evaluation: 7it [00:00, 80.33it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 80.59it/s]
# Running evaluation: 7it [00:00, 80.98it/s]
# Running evaluation: 7it [00:00, 81.87it/s]
# Running evaluation: 7it [00:00, 80.36it/s]
# Running evaluation: 7it [00:00, 81.53it/s]
# Running evaluation: 7it [00:00, 81.53it/s]
# Running evaluation: 7it [00:00, 79.32it/s]
# Running evaluation: 7it [00:00, 81.10it/s]
# Running evaluation: 7it [00:00, 77.81it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 80.56it/s]
# Running evaluation: 7it [00:00, 80.96it/s]
# Running evaluation: 7it [00:00, 82.54it/s]
# Running evaluation: 7it [00:00, 78.54it/s]
# Running evaluation: 7it [00:00, 82.62it/s]
# Running evaluation: 7it [00:00, 77.93it/s]
# Running evaluation: 7it [00:00, 75.01it/s]
# Running evaluation: 7it [00:00, 79.32it/s]
# Running evaluation: 7it [00:00, 81.52it/s]
# Running evaluation: 7it [00:00, 80.14it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 81.50it/s]
# Running evaluation: 7it [00:00, 80.07it/s]
# Running evaluation: 7it [00:00, 81.22it/s]
# Running evaluation: 7it [00:00, 80.26it/s]
# Running evaluation: 7it [00:00, 80.75it/s]
# Running evaluation: 7it [00:00, 75.83it/s]
# Running evaluation: 7it [00:00, 81.75it/s]
# Running evaluation: 7it [00:00, 80.86it/s]
# Running evaluation: 7it [00:00, 81.16it/s]
# Running evaluation: 7it [00:00, 81.00it/s]
# Running evaluation: 7it [00:00, 81.87it/s]
# Running evaluation: 7it [00:00, 81.81it/s]
# Running evaluation: 7it [00:00, 79.14it/s]
# Running evaluation: 7it [00:00, 81.35it/s]
# Running evaluation: 7it [00:00, 81.56it/s]
# Running evaluation: 7it [00:00, 76.83it/s]
# Running evaluation: 7it [00:00, 80.72it/s]
# Running evaluation: 7it [00:00, 79.55it/s]
# Running evaluation: 7it [00:00, 82.11it/s]
# Running evaluation: 7it [00:00, 77.51it/s]
# Running evaluation: 7it [00:00, 82.90it/s]
# Running evaluation: 7it [00:00, 80.34it/s]
# Running evaluation: 7it [00:00, 81.14it/s]
# Running evaluation: 7it [00:00, 79.24it/s]
# Running evaluation: 7it [00:00, 76.98it/s]
# Running evaluation: 7it [00:00, 78.74it/s]
# Running evaluation: 7it [00:00, 79.92it/s]
# Running evaluation: 7it [00:00, 81.51it/s]
# Running evaluation: 7it [00:00, 81.43it/s]
# Running evaluation: 7it [00:00, 79.47it/s]
# Running evaluation: 7it [00:00, 80.38it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 76.88it/s]
# Running evaluation: 7it [00:00, 80.48it/s]
# Running evaluation: 7it [00:00, 77.31it/s]
# Running evaluation: 7it [00:00, 79.95it/s]
# Running evaluation: 7it [00:00, 80.89it/s]
# Running evaluation: 7it [00:00, 81.79it/s]
# Running evaluation: 7it [00:00, 81.58it/s]
# Running evaluation: 7it [00:00, 82.17it/s]
# Running evaluation: 7it [00:00, 78.48it/s]
# Running evaluation: 7it [00:00, 81.94it/s]
# Running evaluation: 7it [00:00, 79.24it/s]
# Running evaluation: 7it [00:00, 80.83it/s]
# Running evaluation: 7it [00:00, 79.84it/s]
# Running evaluation: 7it [00:00, 81.61it/s]
# Running evaluation: 7it [00:00, 80.19it/s]
# Running evaluation: 7it [00:00, 80.19it/s]
# Running evaluation: 7it [00:00, 80.66it/s]
# Running evaluation: 7it [00:00, 77.10it/s]
# Running evaluation: 7it [00:00, 80.56it/s]
# Running evaluation: 7it [00:00, 80.72it/s]
# Running evaluation: 7it [00:00, 81.00it/s]
# Running evaluation: 7it [00:00, 80.68it/s]
# Running evaluation: 7it [00:00, 81.70it/s]
# Running evaluation: 7it [00:00, 80.25it/s]
# Running evaluation: 7it [00:00, 81.02it/s]
# Running evaluation: 7it [00:00, 80.64it/s]
# Running evaluation: 7it [00:00, 81.16it/s]
# Running evaluation: 7it [00:00, 81.21it/s]
# Running evaluation: 7it [00:00, 78.49it/s]
# Running evaluation: 7it [00:00, 81.59it/s]
# Running evaluation: 7it [00:00, 81.25it/s]
# Running evaluation: 7it [00:00, 81.87it/s]
# Running evaluation: 7it [00:00, 81.72it/s]
# Running evaluation: 7it [00:00, 81.87it/s]
# Running evaluation: 7it [00:00, 80.49it/s]
# Running evaluation: 7it [00:00, 80.94it/s]
# Running evaluation: 7it [00:00, 80.82it/s]
# Running evaluation: 7it [00:00, 81.05it/s]
# Running evaluation: 7it [00:00, 80.92it/s]
# Running evaluation: 7it [00:00, 78.93it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 79.44it/s]
# Running evaluation: 7it [00:00, 79.71it/s]
# Running evaluation: 7it [00:00, 81.12it/s]
# Running evaluation: 7it [00:00, 80.08it/s]
# Running evaluation: 7it [00:00, 81.99it/s]
# Running evaluation: 7it [00:00, 79.45it/s]
# Running evaluation: 7it [00:00, 81.61it/s]
# Running evaluation: 7it [00:00, 77.91it/s]
# Running evaluation: 7it [00:00, 81.60it/s]
# Running evaluation: 7it [00:00, 80.85it/s]
# Running evaluation: 7it [00:00, 82.01it/s]
# Running evaluation: 7it [00:00, 80.77it/s]
# Running evaluation: 7it [00:00, 81.04it/s]
# Running evaluation: 7it [00:00, 82.76it/s]
# Running evaluation: 7it [00:00, 79.99it/s]
# Running evaluation: 7it [00:00, 81.48it/s]
# Running evaluation: 7it [00:00, 79.42it/s]
# Running evaluation: 7it [00:00, 80.56it/s]
# Running evaluation: 7it [00:00, 79.89it/s]
# Running evaluation: 7it [00:00, 81.80it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 79.69it/s]
# Running evaluation: 7it [00:00, 80.21it/s]
# Running evaluation: 7it [00:00, 80.69it/s]
# Running evaluation: 7it [00:00, 81.81it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 81.65it/s]
# Running evaluation: 7it [00:00, 77.85it/s]
# Running evaluation: 7it [00:00, 79.23it/s]
# Running evaluation: 7it [00:00, 78.34it/s]
# Running evaluation: 7it [00:00, 80.00it/s]
# Running evaluation: 7it [00:00, 80.22it/s]
# Running evaluation: 7it [00:00, 81.92it/s]
# Running evaluation: 7it [00:00, 82.31it/s]
# Running evaluation: 7it [00:00, 79.27it/s]
# Running evaluation: 7it [00:00, 81.70it/s]
# Running evaluation: 7it [00:00, 78.25it/s]
# Running evaluation: 7it [00:00, 81.14it/s]
# Running evaluation: 7it [00:00, 79.86it/s]
# Running evaluation: 7it [00:00, 80.66it/s]
# Running evaluation: 7it [00:00, 82.07it/s]
# Running evaluation: 7it [00:00, 79.85it/s]
# Running evaluation: 7it [00:00, 81.55it/s]
# Running evaluation: 7it [00:00, 77.84it/s]
# Running evaluation: 7it [00:00, 79.05it/s]
# Running evaluation: 7it [00:00, 77.33it/s]
# Running evaluation: 7it [00:00, 81.51it/s]
# Running evaluation: 7it [00:00, 77.17it/s]
# Running evaluation: 7it [00:00, 79.80it/s]
# Running evaluation: 7it [00:00, 81.64it/s]
# Running evaluation: 7it [00:00, 81.30it/s]
# Running evaluation: 7it [00:00, 80.03it/s]
# Running evaluation: 7it [00:00, 81.04it/s]
# Running evaluation: 7it [00:00, 79.47it/s]
# Running evaluation: 7it [00:00, 80.94it/s]
# Running evaluation: 7it [00:00, 79.09it/s]
# Running evaluation: 7it [00:00, 78.33it/s]
# Running evaluation: 7it [00:00, 78.89it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 79.12it/s]
# Running evaluation: 7it [00:00, 80.91it/s]
# Running evaluation: 7it [00:00, 79.44it/s]
# Running evaluation: 7it [00:00, 78.30it/s]
# Running evaluation: 7it [00:00, 80.25it/s]
# Running evaluation: 7it [00:00, 80.73it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 81.36it/s]
# Running evaluation: 7it [00:00, 81.50it/s]
# Running evaluation: 7it [00:00, 81.36it/s]
# Running evaluation: 7it [00:00, 78.97it/s]
# Running evaluation: 7it [00:00, 78.34it/s]
# Running evaluation: 7it [00:00, 78.00it/s]
# Running evaluation: 7it [00:00, 81.09it/s]
# Running evaluation: 7it [00:00, 78.59it/s]
# Running evaluation: 7it [00:00, 79.37it/s]
# Running evaluation: 7it [00:00, 77.94it/s]
# Running evaluation: 7it [00:00, 82.23it/s]
# Running evaluation: 7it [00:00, 79.64it/s]
# Running evaluation: 7it [00:00, 80.74it/s]
# Running evaluation: 7it [00:00, 80.32it/s]
# Running evaluation: 7it [00:00, 80.93it/s]
# Running evaluation: 7it [00:00, 80.79it/s]
# Running evaluation: 7it [00:00, 81.83it/s]
# Running evaluation: 7it [00:00, 81.62it/s]
# Running evaluation: 7it [00:00, 81.57it/s]
# Running evaluation: 7it [00:00, 78.40it/s]
# Running evaluation: 7it [00:00, 77.89it/s]
# Running evaluation: 7it [00:00, 80.97it/s]
# Running evaluation: 7it [00:00, 79.10it/s]
# Running evaluation: 7it [00:00, 78.28it/s]
# Running evaluation: 7it [00:00, 78.05it/s]
# Running evaluation: 7it [00:00, 80.76it/s]
# Running evaluation: 7it [00:00, 81.30it/s]
# Running evaluation: 7it [00:00, 81.35it/s]
# Running evaluation: 7it [00:00, 81.82it/s]
# Running evaluation: 7it [00:00, 78.70it/s]
# Running evaluation: 7it [00:00, 82.41it/s]
# Running evaluation: 7it [00:00, 75.33it/s]
# Running evaluation: 7it [00:00, 80.23it/s]
# Running evaluation: 7it [00:00, 80.10it/s]
# Running evaluation: 7it [00:00, 80.69it/s]
# Running evaluation: 7it [00:00, 79.91it/s]
# Running evaluation: 7it [00:00, 43.29it/s]

# %%
print("CRPS: {}".format(agg_metric["mean_wQuantileLoss"]))
print("ND: {}".format(agg_metric["ND"]))
print("NRMSE: {}".format(agg_metric["NRMSE"]))
print("MSE: {}".format(agg_metric["MSE"]))
# Out:
# CRPS: 0.1635974209589031
# ND: 0.212101589986686
# NRMSE: 0.501161413906153
# MSE: 0.000688862127735606

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()
